# %%
'''
Demos written and developed by: Andrew E. Oriani 2020 EMAIL: oriani@uchicago.edu

'''
from PyInventor import *
import numpy as np
from numpy import pi, cos, sin, sqrt, log
import math
import glob
import time
import datetime

#Import plotting libraries for later
import matplotlib
from matplotlib import pyplot as plt

from matplotlib import cm
import matplotlib as mpl
from matplotlib.colors import BoundaryNorm 
from matplotlib.ticker import MaxNLocator

import pandas as pd

import pyEPR
from pyEPR import ansys as HFSS
from pyEPR.core_distributed_analysis import CalcObject

import scipy
from scipy import constants as const

from pint import UnitRegistry
ureg = UnitRegistry()
Q = ureg.Quantity
import os
import re as regex

# Field integrals code
import sys
sys.path.append('../python/src')
import field_integrals as fint

# %% [markdown]
# ## Eigenmode solver read from existing HFSS aedt file

# %%
'''
HFSS eigenmode simulation Creation:

This sets up a standard eigenmode simulation without the qubit, just the bare cavity created above. It calculates
the mode frequencies, loss (with boundary impedances set) and the electric and magnetic surface participation 
ratios (S_e, S_m)

'''



# Project and HFSS design names for the bare waveguide model
dd = datetime.datetime.today().strftime('%y%m%d')
solution_type = 'eigenmode'
overwrite = False
ref_name = 'geometric_coupling_sweeps'
project_name=f'{ref_name}'

# Switch between degenerate and non-degenerate cavities
design_name=f'geometric_coupling_normal_nondegen'
design_name=f'geometric_coupling_normal_degen'

#use file location path:
HFSS_path=os.getcwd()

full_path=HFSS_path+'\\HFSS\\'+project_name+'.aedt'

HFSS_app=HFSS.HfssApp()
HFSS_desktop=HFSS_app.get_app_desktop()

project=HFSS_desktop.open_project(full_path)

if project==None:
    project=HFSS_desktop.new_project()
    project.save(full_path)
    
project.save(full_path)
project.make_active()
    
if design_name in project.get_design_names():
    if overwrite==True:
        project.delete_design(design_name)
        project.save()
        
        # Setup a driven modal design type
        if solution_type == 'driven_modal':
            EM_design=project.new_dm_design(design_name)
        elif solution_type == 'eigenmode':
            EM_design=project.new_em_design(design_name)
        else:
            raise ValueError(f'Solution type ({solution_type}) not recognized.')
    else:
        EM_design=project.get_design(design_name)
        
else:
    if solution_type == 'driven_modal':
        EM_design=project.new_dm_design(design_name)
    elif solution_type == 'eigenmode':
        EM_design=project.new_em_design(design_name)
    else:
        raise ValueError(f'Solution type ({solution_type}) not recognized.')
        
EM_design.make_active()
model=HFSS.HfssModeler(EM_design)

project=HFSS_desktop.open_project(full_path)

if project==None:
    project=HFSS_desktop.new_project()
    project.save(full_path)
    
project.make_active()
    
if design_name in project.get_design_names():
    if overwrite==True:
        project.delete_design(design_name)
        project.save()
        EM_design=project.new_em_design(design_name)
    else:
        EM_design=project.get_design(design_name)
        
else:
    EM_design=project.new_em_design(design_name)
        
EM_design.make_active()
model=HFSS.HfssModeler(EM_design)
# Out:
# project_name: geometric_coupling_sweeps
# path: Z:\tcav\ipynbs\HFSS\geometric_coupling_sweeps.aedt
# project_name: geometric_coupling_sweeps
# path: Z:\tcav\ipynbs\HFSS\geometric_coupling_sweeps.aedt

# %%
def set_axes_fonts(ax, fsize):
    """
    Set axes font sizes because it should be abstracted away
    """
    for tick in ax.get_xticklabels():
        tick.set_fontsize(fsize)
    for tick in ax.get_yticklabels():
        tick.set_fontsize(fsize)

def set_xaxis_rot(ax, angle=45):
    """
    Rotate the x-axis labels
    """
        
    for tick in ax.get_xticklabels():
        tick.set_rotation(angle)

def set_leg_outside(ax, fsize):
    """
    Sets the legend location outside
    """
    
    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    
    # Put a legend to the right of the current axis
    hdls, legs = ax.get_legend_handles_labels()
    leg = ax.legend(hdls, legs, loc='center left', bbox_to_anchor=(1, 0.5), \
                    fontsize=fsize, framealpha=0.)

    return leg

# %%
def plot_2d_cmap(x, y, z, fname,                                                
                 xstr='', ystr='',                                              
                 tstr='', cbar_str='',                                          
                 cmap=cm.inferno,
                 xyscales={'x' : 'linear', 'y': 'linear'},
                 interp_zeros=False,
                interp_std_dev=10,
                image_rot_angle=0,
                norm_type='linear',
                zref=None, 
                fsize=30,
                tsize=36):
    """                                                                         
    Plot 2D colormap data such that                                             
                                                                                
         -----------------------                                                
         |                     |                                                
         |                     |                                                
    y    |          z          |                                                
         |                     |                                                
         |                     |                                                
         -----------------------                                                
                                                                                
                    x                                                           
                                                                                
    Parameters:                                                                 
    ----------                                                                  
                                                                                
    x, y:       independent variables                                           
    z:          resulting data, z = z(x, y)                                     
    fname:      output figure filename, relative path with file extension       
    xstr:       x-axis label                                                    
    ystr:       y-axis label                                                    
    tstr:       title label                                                     
    cbar_str:   lable for color bar                                             
    cmap:       colormap to use on the 2D figure output                         
                                                                                
    """
    # Interpolate the data
    if interp_zeros:
        hot_pixels, z = fix_outlier_pixels(z, tolerance=interp_std_dev)
    
    # Setup the color map, normalizations, etc
    if norm_type == 'linear':
        norm = mpl.colors.Normalize(z.min(), z.max())
    elif norm_type == 'log':
        if zref:
            norm = mpl.colors.LogNorm(min(zref), max(zref))
        else:
            norm = mpl.colors.Normalize(min(zref), max(zref))    
    elif (norm_type == 'ref') and zref:
        norm = mpl.colors.Normalize(min(zref), max(zref))
    else:
        raise ValueError(f'norm_type ({norm_type}) not recognized')                                         
                                                                                
    # Setup the figure and axes                                                 
    fig, ax = plt.subplots(1, 1, figsize=(10, 8), tight_layout=True)
    
    # Set the scale bar and levels
    if (norm_type == 'ref') and zref:
        levels = MaxNLocator(nbins=20).tick_values(min(zref), max(zref))
    else:
        levels = MaxNLocator(nbins=20).tick_values(z.min(), z.max())
    if image_rot_angle:
        z = scipy.ndimage.rotate(z, image_rot_angle, reshape=True)
    #plt1 = ax.imshow(z, cmap=cmap, norm=norm)
    plt1 = ax.pcolormesh(x, y, z, cmap=cmap, norm=norm)
    ax.set_xlabel(xstr, fontsize=fsize)                                         
    ax.set_ylabel(ystr, fontsize=fsize)                                         
    ax.set_title(tstr, fontsize=tsize)
    
    # Rotate the xlabels. Set both x and y labels to headers[1:]
    ax.set_xscale(xyscales['x'])
    ax.set_yscale(xyscales['y'])
    # set_xaxis_rot(ax, 45)
                                                                                
    # Set the axis tick labels to a reasonable size                             
    set_axes_fonts(ax, fsize)                                                   
                                                                                
    # Set the color bar, offset the title slightly from top                     
    cbar = fig.colorbar(plt1, ax=ax)                                            
    cbar.ax.set_title(cbar_str, fontsize=fsize, y=1.025)                        
    cbar.ax.tick_params(labelsize=fsize)                                        
                                                                                
    # Write the results to file
    print(f'Writing {fname} ...')
    fig.savefig(fname, format='pdf', transparent=True)

# %% [markdown]
# ## Read the electric field data to perform the integrals

# %%
# Setup the pyEPR project
Nmodes = 4
pinfo = pyEPR.ProjectInfo(HFSS_path+'\\HFSS',  
                         project_name,
                         design_name)
# Setup for EPR anaylsis
eprh = pyEPR.DistributedAnalysis(pinfo)

# Read off the inductances and x-offsets from the variations
variations = eprh.solutions.list_variations()

vstr = 'rcoupler'
vunits = 'mm'
Ljstrs = []; Lj_vals = []
#xoffstrs = []; xoff_vals = []
for v in variations:
    Ljstrs.append(regex.findall(f'{vstr}=\'(.*?{vunits})', v)[0].replace('.', 'p'))
    Lj_vals.append(float(regex.findall(f'{vstr}=\'(.*?){vunits}', v)[0]))
# Out:
# INFO 12:02PM [connect]: Connecting to Ansys Desktop API...
# INFO 12:02PM [load_ansys_project]: 	File path to HFSS project found.
# INFO 12:02PM [load_ansys_project]: 	Opened Ansys App
# INFO 12:02PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 12:02PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    Z:/tcav/ipynbs/HFSS/
# 	Project:   geometric_coupling_sweeps
# INFO 12:02PM [connect]: 	Opened active design
# 	Design:    geometric_coupling_normal_degen [Solution type: Eigenmode]
# INFO 12:02PM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:02PM [connect]: 	Connection to Ansys established successfully. 😀
# Design "geometric_coupling_normal_degen" info:
# 	# eigenmodes    4
# 	# variations    13

# %%
Lj_sort_idxs = np.argsort(Lj_vals)
Lj_vals = np.unique(np.asarray(Lj_vals)[Lj_sort_idxs])
Ljstrs = np.asarray(Ljstrs)[Lj_sort_idxs]

# %%
Lj_sort_idxs
# Out:
# array([ 0,  7,  4,  8,  1,  9,  5, 10,  2, 11,  6, 12,  3], dtype=int64)

# %%
Lj_vals
# Out:
# array([1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5])

# %%
Ljstrs
# Out:
# array(['1p5mm', '2mm', '2p5mm', '3mm', '3p5mm', '4mm', '4p5mm', '5mm',
#        '5p5mm', '6mm', '6p5mm', '7mm', '7p5mm'], dtype='<U5')

# %%
vstrs = [f'rcoupler_{l}' for l in Ljstrs]

# %%
vstrs
# Out:
# ['rcoupler_1p5mm',
#  'rcoupler_2mm',
#  'rcoupler_2p5mm',
#  'rcoupler_3mm',
#  'rcoupler_3p5mm',
#  'rcoupler_4mm',
#  'rcoupler_4p5mm',
#  'rcoupler_5mm',
#  'rcoupler_5p5mm',
#  'rcoupler_6mm',
#  'rcoupler_6p5mm',
#  'rcoupler_7mm',
#  'rcoupler_7p5mm']

# %%
vars_sorted = np.asarray(eprh.variations)[Lj_sort_idxs]

# %%
[eprh._get_lv(v) for v in vars_sorted]
# Out:
# [['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '1.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '2mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '2.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '3mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '3.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '4mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '4.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '5.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '6mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '6.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '7mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm'],
#  ['cav_offset:=',
#   '5mm',
#   'hcav_a:=',
#   '75mm',
#   'hcav_b:=',
#   '75mm',
#   'hcoupler:=',
#   '10mm',
#   'lpost_a:=',
#   '7.5mm',
#   'lpost_b:=',
#   '7.5mm',
#   'rcav_a:=',
#   '15mm',
#   'rcav_b:=',
#   '15mm',
#   'rcoupler:=',
#   '7.5mm',
#   'rpost_a:=',
#   '3mm',
#   'rpost_b:=',
#   '3mm']]

# %% [markdown]
# ## Need to manually create Vector_E plot in GUI first
# * TODO: Create a new field plot, then export the field data with ansys.py

# %%
# Build a string for each variation to label the output files
Nmodes = 2
for idx, v in enumerate(vars_sorted):
    # Set the variation
    eprh.set_variation(v)
    lv = eprh._get_lv(v)
    print(f'Variation: {vstrs[idx]}')
    for kp in range(Nmodes):
        # Set the solution to mode kp
        eprh.solutions.set_mode(kp+1)
        # time.sleep(0.5)
        print(f'Mode-{kp+1}')
        des = EM_design._design
        omod = des.GetModule('FieldsReporter')
        omod.ExportFieldPlot("Vector_E1", False, f"Z:\\tcav\\data\\efields_two_post_cpl_only_mode_{kp+1}_{vstrs[idx]}.aedtplt")
print('Finished writing field data to file.')
# Out:
# Variation: rcoupler_1p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_2mm
# Mode-1
# Mode-2
# Variation: rcoupler_2p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_3mm
# Mode-1
# Mode-2
# Variation: rcoupler_3p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_4mm
# Mode-1
# Mode-2
# Variation: rcoupler_4p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_5mm
# Mode-1
# Mode-2
# Variation: rcoupler_5p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_6mm
# Mode-1
# Mode-2
# Variation: rcoupler_6p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_7mm
# Mode-1
# Mode-2
# Variation: rcoupler_7p5mm
# Mode-1
# Mode-2
# Finished writing field data to file.

# %% [markdown]
# ## Need to manually create Vector_H (90 degrees phase) plot in GUI first

# %%
# Build a string for each variation to label the output files
Nmodes = 2
for idx, v in enumerate(vars_sorted):
    # Set the variation
    eprh.set_variation(v)
    lv = eprh._get_lv(v)
    print(f'Variation: {vstrs[idx]}')
    for kp in range(Nmodes):
        # Set the solution to mode kp
        eprh.solutions.set_mode(kp+1)
        # time.sleep(0.5)
        print(f'Mode-{kp+1}')
        des = EM_design._design
        omod = des.GetModule('FieldsReporter')
        omod.ExportFieldPlot("Vector_H1", False, f"Z:\\tcav\\data\\hfields_two_post_cpl_only_mode_{kp+1}_{vstrs[idx]}.aedtplt")
print('Finished writing field data to file.')
# Out:
# Variation: rcoupler_1p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_2mm
# Mode-1
# Mode-2
# Variation: rcoupler_2p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_3mm
# Mode-1
# Mode-2
# Variation: rcoupler_3p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_4mm
# Mode-1
# Mode-2
# Variation: rcoupler_4p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_5mm
# Mode-1
# Mode-2
# Variation: rcoupler_5p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_6mm
# Mode-1
# Mode-2
# Variation: rcoupler_6p5mm
# Mode-1
# Mode-2
# Variation: rcoupler_7mm
# Mode-1
# Mode-2
# Variation: rcoupler_7p5mm
# Mode-1
# Mode-2
# Finished writing field data to file.

# %% [markdown]
# ## Get the currents from pyEPR

# %%
Ikkp = np.zeros([len(vars_sorted), len(vars_sorted), Nmodes, Nmodes])
jj_area = (50e-6)**2
for k in range(Nmodes):
    for kp in range(Nmodes):
        for idx, v in enumerate(vars_sorted):
            for idx0, v0 in enumerate(vars_sorted):
                # Set the solution to mode k
                eprh.solutions.set_mode(k+1)
                calc = CalcObject([], eprh.setup)
                calc = calc.getQty('Jsurf').mag().integrate_surf(name ='jj')
                
                # Set the variation to v
                eprh.set_variation(v)
                lv = eprh._get_lv(v)
                Ik = calc.evaluate(lv=lv, phase=90.) / jj_area
                
                # Set the solution to mode kp
                eprh.solutions.set_mode(kp+1)
                calc = CalcObject([], eprh.setup)
                calc = calc.getQty('Jsurf').mag().integrate_surf(name ='jj')
                
                # Set the variation to v0
                eprh.set_variation(v0)
                lv0 = eprh._get_lv(v0)
                Ikp = calc.evaluate(lv=lv0, phase=90.) / jj_area
            
                print(f'(k, kp): ({k+1}, {kp+1}), (LJ, LJ0): ({v}, {v0})')
                Ikkp[idx, idx0, k, kp] = Ik * Ikp
# Out:
# (k, kp): (1, 1), (LJ, LJ0): (0, 0)
# (k, kp): (1, 1), (LJ, LJ0): (0, 1)
# (k, kp): (1, 1), (LJ, LJ0): (0, 2)
# (k, kp): (1, 1), (LJ, LJ0): (0, 3)
# (k, kp): (1, 1), (LJ, LJ0): (0, 4)
# (k, kp): (1, 1), (LJ, LJ0): (0, 5)
# (k, kp): (1, 1), (LJ, LJ0): (0, 6)
# (k, kp): (1, 1), (LJ, LJ0): (0, 7)
# (k, kp): (1, 1), (LJ, LJ0): (0, 8)
# (k, kp): (1, 1), (LJ, LJ0): (0, 9)
# (k, kp): (1, 1), (LJ, LJ0): (1, 0)
# (k, kp): (1, 1), (LJ, LJ0): (1, 1)
# (k, kp): (1, 1), (LJ, LJ0): (1, 2)
# (k, kp): (1, 1), (LJ, LJ0): (1, 3)
# (k, kp): (1, 1), (LJ, LJ0): (1, 4)
# (k, kp): (1, 1), (LJ, LJ0): (1, 5)
# (k, kp): (1, 1), (LJ, LJ0): (1, 6)
# (k, kp): (1, 1), (LJ, LJ0): (1, 7)
# (k, kp): (1, 1), (LJ, LJ0): (1, 8)
# (k, kp): (1, 1), (LJ, LJ0): (1, 9)
# (k, kp): (1, 1), (LJ, LJ0): (2, 0)
# (k, kp): (1, 1), (LJ, LJ0): (2, 1)
# (k, kp): (1, 1), (LJ, LJ0): (2, 2)
# (k, kp): (1, 1), (LJ, LJ0): (2, 3)
# (k, kp): (1, 1), (LJ, LJ0): (2, 4)
# (k, kp): (1, 1), (LJ, LJ0): (2, 5)
# (k, kp): (1, 1), (LJ, LJ0): (2, 6)
# (k, kp): (1, 1), (LJ, LJ0): (2, 7)
# (k, kp): (1, 1), (LJ, LJ0): (2, 8)
# (k, kp): (1, 1), (LJ, LJ0): (2, 9)
# (k, kp): (1, 1), (LJ, LJ0): (3, 0)
# (k, kp): (1, 1), (LJ, LJ0): (3, 1)
# (k, kp): (1, 1), (LJ, LJ0): (3, 2)
# (k, kp): (1, 1), (LJ, LJ0): (3, 3)
# (k, kp): (1, 1), (LJ, LJ0): (3, 4)
# (k, kp): (1, 1), (LJ, LJ0): (3, 5)
# (k, kp): (1, 1), (LJ, LJ0): (3, 6)
# (k, kp): (1, 1), (LJ, LJ0): (3, 7)
# (k, kp): (1, 1), (LJ, LJ0): (3, 8)
# (k, kp): (1, 1), (LJ, LJ0): (3, 9)
# (k, kp): (1, 1), (LJ, LJ0): (4, 0)
# (k, kp): (1, 1), (LJ, LJ0): (4, 1)
# (k, kp): (1, 1), (LJ, LJ0): (4, 2)
# (k, kp): (1, 1), (LJ, LJ0): (4, 3)
# (k, kp): (1, 1), (LJ, LJ0): (4, 4)
# (k, kp): (1, 1), (LJ, LJ0): (4, 5)
# (k, kp): (1, 1), (LJ, LJ0): (4, 6)
# (k, kp): (1, 1), (LJ, LJ0): (4, 7)
# (k, kp): (1, 1), (LJ, LJ0): (4, 8)
# (k, kp): (1, 1), (LJ, LJ0): (4, 9)
# (k, kp): (1, 1), (LJ, LJ0): (5, 0)
# (k, kp): (1, 1), (LJ, LJ0): (5, 1)
# (k, kp): (1, 1), (LJ, LJ0): (5, 2)
# (k, kp): (1, 1), (LJ, LJ0): (5, 3)
# (k, kp): (1, 1), (LJ, LJ0): (5, 4)
# (k, kp): (1, 1), (LJ, LJ0): (5, 5)
# (k, kp): (1, 1), (LJ, LJ0): (5, 6)
# (k, kp): (1, 1), (LJ, LJ0): (5, 7)
# (k, kp): (1, 1), (LJ, LJ0): (5, 8)
# (k, kp): (1, 1), (LJ, LJ0): (5, 9)
# (k, kp): (1, 1), (LJ, LJ0): (6, 0)
# (k, kp): (1, 1), (LJ, LJ0): (6, 1)
# (k, kp): (1, 1), (LJ, LJ0): (6, 2)
# (k, kp): (1, 1), (LJ, LJ0): (6, 3)
# (k, kp): (1, 1), (LJ, LJ0): (6, 4)
# (k, kp): (1, 1), (LJ, LJ0): (6, 5)
# (k, kp): (1, 1), (LJ, LJ0): (6, 6)
# (k, kp): (1, 1), (LJ, LJ0): (6, 7)
# (k, kp): (1, 1), (LJ, LJ0): (6, 8)
# (k, kp): (1, 1), (LJ, LJ0): (6, 9)
# (k, kp): (1, 1), (LJ, LJ0): (7, 0)
# (k, kp): (1, 1), (LJ, LJ0): (7, 1)
# (k, kp): (1, 1), (LJ, LJ0): (7, 2)
# (k, kp): (1, 1), (LJ, LJ0): (7, 3)
# (k, kp): (1, 1), (LJ, LJ0): (7, 4)
# (k, kp): (1, 1), (LJ, LJ0): (7, 5)
# (k, kp): (1, 1), (LJ, LJ0): (7, 6)
# (k, kp): (1, 1), (LJ, LJ0): (7, 7)
# (k, kp): (1, 1), (LJ, LJ0): (7, 8)
# (k, kp): (1, 1), (LJ, LJ0): (7, 9)
# (k, kp): (1, 1), (LJ, LJ0): (8, 0)
# (k, kp): (1, 1), (LJ, LJ0): (8, 1)
# (k, kp): (1, 1), (LJ, LJ0): (8, 2)
# (k, kp): (1, 1), (LJ, LJ0): (8, 3)
# (k, kp): (1, 1), (LJ, LJ0): (8, 4)
# (k, kp): (1, 1), (LJ, LJ0): (8, 5)
# (k, kp): (1, 1), (LJ, LJ0): (8, 6)
# (k, kp): (1, 1), (LJ, LJ0): (8, 7)
# (k, kp): (1, 1), (LJ, LJ0): (8, 8)
# (k, kp): (1, 1), (LJ, LJ0): (8, 9)
# (k, kp): (1, 1), (LJ, LJ0): (9, 0)
# (k, kp): (1, 1), (LJ, LJ0): (9, 1)
# (k, kp): (1, 1), (LJ, LJ0): (9, 2)
# (k, kp): (1, 1), (LJ, LJ0): (9, 3)
# (k, kp): (1, 1), (LJ, LJ0): (9, 4)
# (k, kp): (1, 1), (LJ, LJ0): (9, 5)
# (k, kp): (1, 1), (LJ, LJ0): (9, 6)
# (k, kp): (1, 1), (LJ, LJ0): (9, 7)
# (k, kp): (1, 1), (LJ, LJ0): (9, 8)
# (k, kp): (1, 1), (LJ, LJ0): (9, 9)
# (k, kp): (1, 2), (LJ, LJ0): (0, 0)
# (k, kp): (1, 2), (LJ, LJ0): (0, 1)
# (k, kp): (1, 2), (LJ, LJ0): (0, 2)
# (k, kp): (1, 2), (LJ, LJ0): (0, 3)
# (k, kp): (1, 2), (LJ, LJ0): (0, 4)
# (k, kp): (1, 2), (LJ, LJ0): (0, 5)
# (k, kp): (1, 2), (LJ, LJ0): (0, 6)
# (k, kp): (1, 2), (LJ, LJ0): (0, 7)
# (k, kp): (1, 2), (LJ, LJ0): (0, 8)
# (k, kp): (1, 2), (LJ, LJ0): (0, 9)
# (k, kp): (1, 2), (LJ, LJ0): (1, 0)
# (k, kp): (1, 2), (LJ, LJ0): (1, 1)
# (k, kp): (1, 2), (LJ, LJ0): (1, 2)
# (k, kp): (1, 2), (LJ, LJ0): (1, 3)
# (k, kp): (1, 2), (LJ, LJ0): (1, 4)
# (k, kp): (1, 2), (LJ, LJ0): (1, 5)
# (k, kp): (1, 2), (LJ, LJ0): (1, 6)
# (k, kp): (1, 2), (LJ, LJ0): (1, 7)
# (k, kp): (1, 2), (LJ, LJ0): (1, 8)
# (k, kp): (1, 2), (LJ, LJ0): (1, 9)
# (k, kp): (1, 2), (LJ, LJ0): (2, 0)
# (k, kp): (1, 2), (LJ, LJ0): (2, 1)
# (k, kp): (1, 2), (LJ, LJ0): (2, 2)
# (k, kp): (1, 2), (LJ, LJ0): (2, 3)
# (k, kp): (1, 2), (LJ, LJ0): (2, 4)
# (k, kp): (1, 2), (LJ, LJ0): (2, 5)
# (k, kp): (1, 2), (LJ, LJ0): (2, 6)
# (k, kp): (1, 2), (LJ, LJ0): (2, 7)
# (k, kp): (1, 2), (LJ, LJ0): (2, 8)
# (k, kp): (1, 2), (LJ, LJ0): (2, 9)
# (k, kp): (1, 2), (LJ, LJ0): (3, 0)
# (k, kp): (1, 2), (LJ, LJ0): (3, 1)
# (k, kp): (1, 2), (LJ, LJ0): (3, 2)
# (k, kp): (1, 2), (LJ, LJ0): (3, 3)
# (k, kp): (1, 2), (LJ, LJ0): (3, 4)
# (k, kp): (1, 2), (LJ, LJ0): (3, 5)
# (k, kp): (1, 2), (LJ, LJ0): (3, 6)
# (k, kp): (1, 2), (LJ, LJ0): (3, 7)
# (k, kp): (1, 2), (LJ, LJ0): (3, 8)
# (k, kp): (1, 2), (LJ, LJ0): (3, 9)
# (k, kp): (1, 2), (LJ, LJ0): (4, 0)
# (k, kp): (1, 2), (LJ, LJ0): (4, 1)
# (k, kp): (1, 2), (LJ, LJ0): (4, 2)
# (k, kp): (1, 2), (LJ, LJ0): (4, 3)
# (k, kp): (1, 2), (LJ, LJ0): (4, 4)
# (k, kp): (1, 2), (LJ, LJ0): (4, 5)
# (k, kp): (1, 2), (LJ, LJ0): (4, 6)
# (k, kp): (1, 2), (LJ, LJ0): (4, 7)
# (k, kp): (1, 2), (LJ, LJ0): (4, 8)
# (k, kp): (1, 2), (LJ, LJ0): (4, 9)
# (k, kp): (1, 2), (LJ, LJ0): (5, 0)
# (k, kp): (1, 2), (LJ, LJ0): (5, 1)
# (k, kp): (1, 2), (LJ, LJ0): (5, 2)
# (k, kp): (1, 2), (LJ, LJ0): (5, 3)
# (k, kp): (1, 2), (LJ, LJ0): (5, 4)
# (k, kp): (1, 2), (LJ, LJ0): (5, 5)
# (k, kp): (1, 2), (LJ, LJ0): (5, 6)
# (k, kp): (1, 2), (LJ, LJ0): (5, 7)
# (k, kp): (1, 2), (LJ, LJ0): (5, 8)
# (k, kp): (1, 2), (LJ, LJ0): (5, 9)
# (k, kp): (1, 2), (LJ, LJ0): (6, 0)
# (k, kp): (1, 2), (LJ, LJ0): (6, 1)
# (k, kp): (1, 2), (LJ, LJ0): (6, 2)
# (k, kp): (1, 2), (LJ, LJ0): (6, 3)
# (k, kp): (1, 2), (LJ, LJ0): (6, 4)
# (k, kp): (1, 2), (LJ, LJ0): (6, 5)
# (k, kp): (1, 2), (LJ, LJ0): (6, 6)
# (k, kp): (1, 2), (LJ, LJ0): (6, 7)
# (k, kp): (1, 2), (LJ, LJ0): (6, 8)
# (k, kp): (1, 2), (LJ, LJ0): (6, 9)
# (k, kp): (1, 2), (LJ, LJ0): (7, 0)
# (k, kp): (1, 2), (LJ, LJ0): (7, 1)
# (k, kp): (1, 2), (LJ, LJ0): (7, 2)
# (k, kp): (1, 2), (LJ, LJ0): (7, 3)
# (k, kp): (1, 2), (LJ, LJ0): (7, 4)
# (k, kp): (1, 2), (LJ, LJ0): (7, 5)
# (k, kp): (1, 2), (LJ, LJ0): (7, 6)
# (k, kp): (1, 2), (LJ, LJ0): (7, 7)
# (k, kp): (1, 2), (LJ, LJ0): (7, 8)
# (k, kp): (1, 2), (LJ, LJ0): (7, 9)
# (k, kp): (1, 2), (LJ, LJ0): (8, 0)
# (k, kp): (1, 2), (LJ, LJ0): (8, 1)
# (k, kp): (1, 2), (LJ, LJ0): (8, 2)
# (k, kp): (1, 2), (LJ, LJ0): (8, 3)
# (k, kp): (1, 2), (LJ, LJ0): (8, 4)
# (k, kp): (1, 2), (LJ, LJ0): (8, 5)
# (k, kp): (1, 2), (LJ, LJ0): (8, 6)
# (k, kp): (1, 2), (LJ, LJ0): (8, 7)
# (k, kp): (1, 2), (LJ, LJ0): (8, 8)
# (k, kp): (1, 2), (LJ, LJ0): (8, 9)
# (k, kp): (1, 2), (LJ, LJ0): (9, 0)
# (k, kp): (1, 2), (LJ, LJ0): (9, 1)
# (k, kp): (1, 2), (LJ, LJ0): (9, 2)
# (k, kp): (1, 2), (LJ, LJ0): (9, 3)
# (k, kp): (1, 2), (LJ, LJ0): (9, 4)
# (k, kp): (1, 2), (LJ, LJ0): (9, 5)
# (k, kp): (1, 2), (LJ, LJ0): (9, 6)
# (k, kp): (1, 2), (LJ, LJ0): (9, 7)
# (k, kp): (1, 2), (LJ, LJ0): (9, 8)
# (k, kp): (1, 2), (LJ, LJ0): (9, 9)
# (k, kp): (2, 1), (LJ, LJ0): (0, 0)
# (k, kp): (2, 1), (LJ, LJ0): (0, 1)
# (k, kp): (2, 1), (LJ, LJ0): (0, 2)
# (k, kp): (2, 1), (LJ, LJ0): (0, 3)
# (k, kp): (2, 1), (LJ, LJ0): (0, 4)
# (k, kp): (2, 1), (LJ, LJ0): (0, 5)
# (k, kp): (2, 1), (LJ, LJ0): (0, 6)
# (k, kp): (2, 1), (LJ, LJ0): (0, 7)
# (k, kp): (2, 1), (LJ, LJ0): (0, 8)
# (k, kp): (2, 1), (LJ, LJ0): (0, 9)
# (k, kp): (2, 1), (LJ, LJ0): (1, 0)
# (k, kp): (2, 1), (LJ, LJ0): (1, 1)
# (k, kp): (2, 1), (LJ, LJ0): (1, 2)
# (k, kp): (2, 1), (LJ, LJ0): (1, 3)
# (k, kp): (2, 1), (LJ, LJ0): (1, 4)
# (k, kp): (2, 1), (LJ, LJ0): (1, 5)
# (k, kp): (2, 1), (LJ, LJ0): (1, 6)
# (k, kp): (2, 1), (LJ, LJ0): (1, 7)
# (k, kp): (2, 1), (LJ, LJ0): (1, 8)
# (k, kp): (2, 1), (LJ, LJ0): (1, 9)
# (k, kp): (2, 1), (LJ, LJ0): (2, 0)
# (k, kp): (2, 1), (LJ, LJ0): (2, 1)
# (k, kp): (2, 1), (LJ, LJ0): (2, 2)
# (k, kp): (2, 1), (LJ, LJ0): (2, 3)
# (k, kp): (2, 1), (LJ, LJ0): (2, 4)
# (k, kp): (2, 1), (LJ, LJ0): (2, 5)
# (k, kp): (2, 1), (LJ, LJ0): (2, 6)
# (k, kp): (2, 1), (LJ, LJ0): (2, 7)
# (k, kp): (2, 1), (LJ, LJ0): (2, 8)
# (k, kp): (2, 1), (LJ, LJ0): (2, 9)
# (k, kp): (2, 1), (LJ, LJ0): (3, 0)
# (k, kp): (2, 1), (LJ, LJ0): (3, 1)
# (k, kp): (2, 1), (LJ, LJ0): (3, 2)
# (k, kp): (2, 1), (LJ, LJ0): (3, 3)
# (k, kp): (2, 1), (LJ, LJ0): (3, 4)
# (k, kp): (2, 1), (LJ, LJ0): (3, 5)
# (k, kp): (2, 1), (LJ, LJ0): (3, 6)
# (k, kp): (2, 1), (LJ, LJ0): (3, 7)
# (k, kp): (2, 1), (LJ, LJ0): (3, 8)
# (k, kp): (2, 1), (LJ, LJ0): (3, 9)
# (k, kp): (2, 1), (LJ, LJ0): (4, 0)
# (k, kp): (2, 1), (LJ, LJ0): (4, 1)
# (k, kp): (2, 1), (LJ, LJ0): (4, 2)
# (k, kp): (2, 1), (LJ, LJ0): (4, 3)
# (k, kp): (2, 1), (LJ, LJ0): (4, 4)
# (k, kp): (2, 1), (LJ, LJ0): (4, 5)
# (k, kp): (2, 1), (LJ, LJ0): (4, 6)
# (k, kp): (2, 1), (LJ, LJ0): (4, 7)
# (k, kp): (2, 1), (LJ, LJ0): (4, 8)
# (k, kp): (2, 1), (LJ, LJ0): (4, 9)
# (k, kp): (2, 1), (LJ, LJ0): (5, 0)
# (k, kp): (2, 1), (LJ, LJ0): (5, 1)
# (k, kp): (2, 1), (LJ, LJ0): (5, 2)
# (k, kp): (2, 1), (LJ, LJ0): (5, 3)
# (k, kp): (2, 1), (LJ, LJ0): (5, 4)
# (k, kp): (2, 1), (LJ, LJ0): (5, 5)
# (k, kp): (2, 1), (LJ, LJ0): (5, 6)
# (k, kp): (2, 1), (LJ, LJ0): (5, 7)
# (k, kp): (2, 1), (LJ, LJ0): (5, 8)
# (k, kp): (2, 1), (LJ, LJ0): (5, 9)
# (k, kp): (2, 1), (LJ, LJ0): (6, 0)
# (k, kp): (2, 1), (LJ, LJ0): (6, 1)
# (k, kp): (2, 1), (LJ, LJ0): (6, 2)
# (k, kp): (2, 1), (LJ, LJ0): (6, 3)
# (k, kp): (2, 1), (LJ, LJ0): (6, 4)
# (k, kp): (2, 1), (LJ, LJ0): (6, 5)
# (k, kp): (2, 1), (LJ, LJ0): (6, 6)
# (k, kp): (2, 1), (LJ, LJ0): (6, 7)
# (k, kp): (2, 1), (LJ, LJ0): (6, 8)
# (k, kp): (2, 1), (LJ, LJ0): (6, 9)
# (k, kp): (2, 1), (LJ, LJ0): (7, 0)
# (k, kp): (2, 1), (LJ, LJ0): (7, 1)
# (k, kp): (2, 1), (LJ, LJ0): (7, 2)
# (k, kp): (2, 1), (LJ, LJ0): (7, 3)
# (k, kp): (2, 1), (LJ, LJ0): (7, 4)
# (k, kp): (2, 1), (LJ, LJ0): (7, 5)
# (k, kp): (2, 1), (LJ, LJ0): (7, 6)
# (k, kp): (2, 1), (LJ, LJ0): (7, 7)
# (k, kp): (2, 1), (LJ, LJ0): (7, 8)
# (k, kp): (2, 1), (LJ, LJ0): (7, 9)
# (k, kp): (2, 1), (LJ, LJ0): (8, 0)
# (k, kp): (2, 1), (LJ, LJ0): (8, 1)
# (k, kp): (2, 1), (LJ, LJ0): (8, 2)
# (k, kp): (2, 1), (LJ, LJ0): (8, 3)
# (k, kp): (2, 1), (LJ, LJ0): (8, 4)
# (k, kp): (2, 1), (LJ, LJ0): (8, 5)
# (k, kp): (2, 1), (LJ, LJ0): (8, 6)
# (k, kp): (2, 1), (LJ, LJ0): (8, 7)
# (k, kp): (2, 1), (LJ, LJ0): (8, 8)
# (k, kp): (2, 1), (LJ, LJ0): (8, 9)
# (k, kp): (2, 1), (LJ, LJ0): (9, 0)
# (k, kp): (2, 1), (LJ, LJ0): (9, 1)
# (k, kp): (2, 1), (LJ, LJ0): (9, 2)
# (k, kp): (2, 1), (LJ, LJ0): (9, 3)
# (k, kp): (2, 1), (LJ, LJ0): (9, 4)
# (k, kp): (2, 1), (LJ, LJ0): (9, 5)
# (k, kp): (2, 1), (LJ, LJ0): (9, 6)
# (k, kp): (2, 1), (LJ, LJ0): (9, 7)
# (k, kp): (2, 1), (LJ, LJ0): (9, 8)
# (k, kp): (2, 1), (LJ, LJ0): (9, 9)
# (k, kp): (2, 2), (LJ, LJ0): (0, 0)
# (k, kp): (2, 2), (LJ, LJ0): (0, 1)
# (k, kp): (2, 2), (LJ, LJ0): (0, 2)
# (k, kp): (2, 2), (LJ, LJ0): (0, 3)
# (k, kp): (2, 2), (LJ, LJ0): (0, 4)
# (k, kp): (2, 2), (LJ, LJ0): (0, 5)
# (k, kp): (2, 2), (LJ, LJ0): (0, 6)
# (k, kp): (2, 2), (LJ, LJ0): (0, 7)
# (k, kp): (2, 2), (LJ, LJ0): (0, 8)
# (k, kp): (2, 2), (LJ, LJ0): (0, 9)
# (k, kp): (2, 2), (LJ, LJ0): (1, 0)
# (k, kp): (2, 2), (LJ, LJ0): (1, 1)
# (k, kp): (2, 2), (LJ, LJ0): (1, 2)
# (k, kp): (2, 2), (LJ, LJ0): (1, 3)
# (k, kp): (2, 2), (LJ, LJ0): (1, 4)
# (k, kp): (2, 2), (LJ, LJ0): (1, 5)
# (k, kp): (2, 2), (LJ, LJ0): (1, 6)
# (k, kp): (2, 2), (LJ, LJ0): (1, 7)
# (k, kp): (2, 2), (LJ, LJ0): (1, 8)
# (k, kp): (2, 2), (LJ, LJ0): (1, 9)
# (k, kp): (2, 2), (LJ, LJ0): (2, 0)
# (k, kp): (2, 2), (LJ, LJ0): (2, 1)
# (k, kp): (2, 2), (LJ, LJ0): (2, 2)
# (k, kp): (2, 2), (LJ, LJ0): (2, 3)
# (k, kp): (2, 2), (LJ, LJ0): (2, 4)
# (k, kp): (2, 2), (LJ, LJ0): (2, 5)
# (k, kp): (2, 2), (LJ, LJ0): (2, 6)
# (k, kp): (2, 2), (LJ, LJ0): (2, 7)
# (k, kp): (2, 2), (LJ, LJ0): (2, 8)
# (k, kp): (2, 2), (LJ, LJ0): (2, 9)
# (k, kp): (2, 2), (LJ, LJ0): (3, 0)
# (k, kp): (2, 2), (LJ, LJ0): (3, 1)
# (k, kp): (2, 2), (LJ, LJ0): (3, 2)
# (k, kp): (2, 2), (LJ, LJ0): (3, 3)
# (k, kp): (2, 2), (LJ, LJ0): (3, 4)
# (k, kp): (2, 2), (LJ, LJ0): (3, 5)
# (k, kp): (2, 2), (LJ, LJ0): (3, 6)
# (k, kp): (2, 2), (LJ, LJ0): (3, 7)
# (k, kp): (2, 2), (LJ, LJ0): (3, 8)
# (k, kp): (2, 2), (LJ, LJ0): (3, 9)
# (k, kp): (2, 2), (LJ, LJ0): (4, 0)
# (k, kp): (2, 2), (LJ, LJ0): (4, 1)
# (k, kp): (2, 2), (LJ, LJ0): (4, 2)
# (k, kp): (2, 2), (LJ, LJ0): (4, 3)
# (k, kp): (2, 2), (LJ, LJ0): (4, 4)
# (k, kp): (2, 2), (LJ, LJ0): (4, 5)
# (k, kp): (2, 2), (LJ, LJ0): (4, 6)
# (k, kp): (2, 2), (LJ, LJ0): (4, 7)
# (k, kp): (2, 2), (LJ, LJ0): (4, 8)
# (k, kp): (2, 2), (LJ, LJ0): (4, 9)
# (k, kp): (2, 2), (LJ, LJ0): (5, 0)
# (k, kp): (2, 2), (LJ, LJ0): (5, 1)
# (k, kp): (2, 2), (LJ, LJ0): (5, 2)
# (k, kp): (2, 2), (LJ, LJ0): (5, 3)
# (k, kp): (2, 2), (LJ, LJ0): (5, 4)
# (k, kp): (2, 2), (LJ, LJ0): (5, 5)
# (k, kp): (2, 2), (LJ, LJ0): (5, 6)
# (k, kp): (2, 2), (LJ, LJ0): (5, 7)
# (k, kp): (2, 2), (LJ, LJ0): (5, 8)
# (k, kp): (2, 2), (LJ, LJ0): (5, 9)
# (k, kp): (2, 2), (LJ, LJ0): (6, 0)
# (k, kp): (2, 2), (LJ, LJ0): (6, 1)
# (k, kp): (2, 2), (LJ, LJ0): (6, 2)
# (k, kp): (2, 2), (LJ, LJ0): (6, 3)
# (k, kp): (2, 2), (LJ, LJ0): (6, 4)
# (k, kp): (2, 2), (LJ, LJ0): (6, 5)
# (k, kp): (2, 2), (LJ, LJ0): (6, 6)
# (k, kp): (2, 2), (LJ, LJ0): (6, 7)
# (k, kp): (2, 2), (LJ, LJ0): (6, 8)
# (k, kp): (2, 2), (LJ, LJ0): (6, 9)
# (k, kp): (2, 2), (LJ, LJ0): (7, 0)
# (k, kp): (2, 2), (LJ, LJ0): (7, 1)
# (k, kp): (2, 2), (LJ, LJ0): (7, 2)
# (k, kp): (2, 2), (LJ, LJ0): (7, 3)
# (k, kp): (2, 2), (LJ, LJ0): (7, 4)
# (k, kp): (2, 2), (LJ, LJ0): (7, 5)
# (k, kp): (2, 2), (LJ, LJ0): (7, 6)
# (k, kp): (2, 2), (LJ, LJ0): (7, 7)
# (k, kp): (2, 2), (LJ, LJ0): (7, 8)
# (k, kp): (2, 2), (LJ, LJ0): (7, 9)
# (k, kp): (2, 2), (LJ, LJ0): (8, 0)
# (k, kp): (2, 2), (LJ, LJ0): (8, 1)
# (k, kp): (2, 2), (LJ, LJ0): (8, 2)
# (k, kp): (2, 2), (LJ, LJ0): (8, 3)
# (k, kp): (2, 2), (LJ, LJ0): (8, 4)
# (k, kp): (2, 2), (LJ, LJ0): (8, 5)
# (k, kp): (2, 2), (LJ, LJ0): (8, 6)
# (k, kp): (2, 2), (LJ, LJ0): (8, 7)
# (k, kp): (2, 2), (LJ, LJ0): (8, 8)
# (k, kp): (2, 2), (LJ, LJ0): (8, 9)
# (k, kp): (2, 2), (LJ, LJ0): (9, 0)
# (k, kp): (2, 2), (LJ, LJ0): (9, 1)
# (k, kp): (2, 2), (LJ, LJ0): (9, 2)
# (k, kp): (2, 2), (LJ, LJ0): (9, 3)
# (k, kp): (2, 2), (LJ, LJ0): (9, 4)
# (k, kp): (2, 2), (LJ, LJ0): (9, 5)
# (k, kp): (2, 2), (LJ, LJ0): (9, 6)
# (k, kp): (2, 2), (LJ, LJ0): (9, 7)
# (k, kp): (2, 2), (LJ, LJ0): (9, 8)
# (k, kp): (2, 2), (LJ, LJ0): (9, 9)

# %%
Ikkp[:, :, 0, 0].shape
# Out:
# (10, 10)

# %%
from importlib import reload
reload(fint)
# Out:
# <module 'field_integrals' from 'Z:\\tcav\\ipynbs\\../python/src\\field_integrals.py'>

# %%
glob.glob(f'../data/hfields_two_post_cpl_only_mode_1_{vstr}_1p5mm.aedtplt')
# Out:
# ['../data/hfields_two_post_cpl_only_mode_1_rcoupler_1p5mm.aedtplt']

# %%
# Single point of entry inputs to class
Nmodes = 2
modes = np.linspace(1, Nmodes, Nmodes, dtype=int)
print(f'modes: {modes}')
# LJs = np.asarray([0.1, 1., 10., 100.])
# LJstrs = ['0p1', '1', '10']

# Instantiate the class object
data_path = f'../data'
myfields = fint.FieldIntegrals(Lj_vals, Ljstrs,
                               modes, data_path, debug=True,
                               has_updated_fields=True,
                               has_normalized_fields=False,
                               normalize_fields=True,
                               drop_max_field=1,
                               filename_format = f'hfields_two_post_cpl_only_mode_%d_{vstr}_%s.aedtplt',
                               timeout_limit=30.)
abscissa, efields = myfields.load_fields(return_fields=True)
keys = list(efields.keys())

Bkkp = myfields.overlap_matrix_points(fname=None, cidxs=[0, 1],
                                      drop_points=1,#'../data/Akkp_nondegenerate_flutes_{dd}.csv',
                                      return_matrix=True)
# Out:
# modes: [1 2]
# load_fields(): 490.422 s
# Running kkp1_1_LJLJp_1p5mm_1p5mm ...
# Dropping field at [8, 37075] ...
# Running kkp1_1_LJLJp_1p5mm_2mm ...
# Running kkp1_1_LJLJp_1p5mm_2p5mm ...
# Running kkp1_1_LJLJp_1p5mm_3mm ...
# Running kkp1_1_LJLJp_1p5mm_3p5mm ...
# Running kkp1_1_LJLJp_1p5mm_4mm ...
# Running kkp1_1_LJLJp_1p5mm_4p5mm ...
# Running kkp1_1_LJLJp_1p5mm_5mm ...
# Running kkp1_1_LJLJp_1p5mm_5p5mm ...
# Running kkp1_1_LJLJp_1p5mm_6mm ...
# Running kkp1_1_LJLJp_1p5mm_6p5mm ...
# Running kkp1_1_LJLJp_1p5mm_7mm ...
# Running kkp1_1_LJLJp_1p5mm_7p5mm ...
# Running kkp1_1_LJLJp_2mm_1p5mm ...
# Running kkp1_1_LJLJp_2mm_2mm ...
# Running kkp1_1_LJLJp_2mm_2p5mm ...
# Running kkp1_1_LJLJp_2mm_3mm ...
# Running kkp1_1_LJLJp_2mm_3p5mm ...
# Running kkp1_1_LJLJp_2mm_4mm ...
# Running kkp1_1_LJLJp_2mm_4p5mm ...
# Running kkp1_1_LJLJp_2mm_5mm ...
# Running kkp1_1_LJLJp_2mm_5p5mm ...
# Running kkp1_1_LJLJp_2mm_6mm ...
# Running kkp1_1_LJLJp_2mm_6p5mm ...
# Running kkp1_1_LJLJp_2mm_7mm ...
# Running kkp1_1_LJLJp_2mm_7p5mm ...
# Running kkp1_1_LJLJp_2p5mm_1p5mm ...
# Running kkp1_1_LJLJp_2p5mm_2mm ...
# Running kkp1_1_LJLJp_2p5mm_2p5mm ...
# Running kkp1_1_LJLJp_2p5mm_3mm ...
# Running kkp1_1_LJLJp_2p5mm_3p5mm ...
# Running kkp1_1_LJLJp_2p5mm_4mm ...
# Running kkp1_1_LJLJp_2p5mm_4p5mm ...
# Running kkp1_1_LJLJp_2p5mm_5mm ...
# Running kkp1_1_LJLJp_2p5mm_5p5mm ...
# Running kkp1_1_LJLJp_2p5mm_6mm ...
# Running kkp1_1_LJLJp_2p5mm_6p5mm ...
# Running kkp1_1_LJLJp_2p5mm_7mm ...
# Running kkp1_1_LJLJp_2p5mm_7p5mm ...
# Running kkp1_1_LJLJp_3mm_1p5mm ...
# Running kkp1_1_LJLJp_3mm_2mm ...
# Running kkp1_1_LJLJp_3mm_2p5mm ...
# Running kkp1_1_LJLJp_3mm_3mm ...
# Running kkp1_1_LJLJp_3mm_3p5mm ...
# Running kkp1_1_LJLJp_3mm_4mm ...
# Running kkp1_1_LJLJp_3mm_4p5mm ...
# Running kkp1_1_LJLJp_3mm_5mm ...
# Running kkp1_1_LJLJp_3mm_5p5mm ...
# Running kkp1_1_LJLJp_3mm_6mm ...
# Running kkp1_1_LJLJp_3mm_6p5mm ...
# Running kkp1_1_LJLJp_3mm_7mm ...
# Running kkp1_1_LJLJp_3mm_7p5mm ...
# Running kkp1_1_LJLJp_3p5mm_1p5mm ...
# Running kkp1_1_LJLJp_3p5mm_2mm ...
# Running kkp1_1_LJLJp_3p5mm_2p5mm ...
# Running kkp1_1_LJLJp_3p5mm_3mm ...
# Running kkp1_1_LJLJp_3p5mm_3p5mm ...
# Running kkp1_1_LJLJp_3p5mm_4mm ...
# Running kkp1_1_LJLJp_3p5mm_4p5mm ...
# Running kkp1_1_LJLJp_3p5mm_5mm ...
# Running kkp1_1_LJLJp_3p5mm_5p5mm ...
# Running kkp1_1_LJLJp_3p5mm_6mm ...
# Running kkp1_1_LJLJp_3p5mm_6p5mm ...
# Running kkp1_1_LJLJp_3p5mm_7mm ...
# Running kkp1_1_LJLJp_3p5mm_7p5mm ...
# Running kkp1_1_LJLJp_4mm_1p5mm ...
# Running kkp1_1_LJLJp_4mm_2mm ...
# Running kkp1_1_LJLJp_4mm_2p5mm ...
# Running kkp1_1_LJLJp_4mm_3mm ...
# Running kkp1_1_LJLJp_4mm_3p5mm ...
# Running kkp1_1_LJLJp_4mm_4mm ...
# Running kkp1_1_LJLJp_4mm_4p5mm ...
# Running kkp1_1_LJLJp_4mm_5mm ...
# Running kkp1_1_LJLJp_4mm_5p5mm ...
# Running kkp1_1_LJLJp_4mm_6mm ...
# Running kkp1_1_LJLJp_4mm_6p5mm ...
# Running kkp1_1_LJLJp_4mm_7mm ...
# Running kkp1_1_LJLJp_4mm_7p5mm ...
# Running kkp1_1_LJLJp_4p5mm_1p5mm ...
# Running kkp1_1_LJLJp_4p5mm_2mm ...
# Running kkp1_1_LJLJp_4p5mm_2p5mm ...
# Running kkp1_1_LJLJp_4p5mm_3mm ...
# Running kkp1_1_LJLJp_4p5mm_3p5mm ...
# Running kkp1_1_LJLJp_4p5mm_4mm ...
# Running kkp1_1_LJLJp_4p5mm_4p5mm ...
# Running kkp1_1_LJLJp_4p5mm_5mm ...
# Running kkp1_1_LJLJp_4p5mm_5p5mm ...
# Running kkp1_1_LJLJp_4p5mm_6mm ...
# Running kkp1_1_LJLJp_4p5mm_6p5mm ...
# Running kkp1_1_LJLJp_4p5mm_7mm ...
# Running kkp1_1_LJLJp_4p5mm_7p5mm ...
# Running kkp1_1_LJLJp_5mm_1p5mm ...
# Running kkp1_1_LJLJp_5mm_2mm ...
# Running kkp1_1_LJLJp_5mm_2p5mm ...
# Running kkp1_1_LJLJp_5mm_3mm ...
# Running kkp1_1_LJLJp_5mm_3p5mm ...
# Running kkp1_1_LJLJp_5mm_4mm ...
# Running kkp1_1_LJLJp_5mm_4p5mm ...
# Running kkp1_1_LJLJp_5mm_5mm ...
# Running kkp1_1_LJLJp_5mm_5p5mm ...
# Running kkp1_1_LJLJp_5mm_6mm ...
# Running kkp1_1_LJLJp_5mm_6p5mm ...
# Running kkp1_1_LJLJp_5mm_7mm ...
# Running kkp1_1_LJLJp_5mm_7p5mm ...
# Running kkp1_1_LJLJp_5p5mm_1p5mm ...
# Running kkp1_1_LJLJp_5p5mm_2mm ...
# Running kkp1_1_LJLJp_5p5mm_2p5mm ...
# Running kkp1_1_LJLJp_5p5mm_3mm ...
# Running kkp1_1_LJLJp_5p5mm_3p5mm ...
# Running kkp1_1_LJLJp_5p5mm_4mm ...
# Running kkp1_1_LJLJp_5p5mm_4p5mm ...
# Running kkp1_1_LJLJp_5p5mm_5mm ...
# Running kkp1_1_LJLJp_5p5mm_5p5mm ...
# Running kkp1_1_LJLJp_5p5mm_6mm ...
# Running kkp1_1_LJLJp_5p5mm_6p5mm ...
# Running kkp1_1_LJLJp_5p5mm_7mm ...
# Running kkp1_1_LJLJp_5p5mm_7p5mm ...
# Running kkp1_1_LJLJp_6mm_1p5mm ...
# Running kkp1_1_LJLJp_6mm_2mm ...
# Running kkp1_1_LJLJp_6mm_2p5mm ...
# Running kkp1_1_LJLJp_6mm_3mm ...
# Running kkp1_1_LJLJp_6mm_3p5mm ...
# Running kkp1_1_LJLJp_6mm_4mm ...
# Running kkp1_1_LJLJp_6mm_4p5mm ...
# Running kkp1_1_LJLJp_6mm_5mm ...
# Running kkp1_1_LJLJp_6mm_5p5mm ...
# Running kkp1_1_LJLJp_6mm_6mm ...
# Running kkp1_1_LJLJp_6mm_6p5mm ...
# Running kkp1_1_LJLJp_6mm_7mm ...
# Running kkp1_1_LJLJp_6mm_7p5mm ...
# Running kkp1_1_LJLJp_6p5mm_1p5mm ...
# Running kkp1_1_LJLJp_6p5mm_2mm ...
# Running kkp1_1_LJLJp_6p5mm_2p5mm ...
# Running kkp1_1_LJLJp_6p5mm_3mm ...
# Running kkp1_1_LJLJp_6p5mm_3p5mm ...
# Running kkp1_1_LJLJp_6p5mm_4mm ...
# Running kkp1_1_LJLJp_6p5mm_4p5mm ...
# Running kkp1_1_LJLJp_6p5mm_5mm ...
# Running kkp1_1_LJLJp_6p5mm_5p5mm ...
# Running kkp1_1_LJLJp_6p5mm_6mm ...
# Running kkp1_1_LJLJp_6p5mm_6p5mm ...
# Running kkp1_1_LJLJp_6p5mm_7mm ...
# Running kkp1_1_LJLJp_6p5mm_7p5mm ...
# Running kkp1_1_LJLJp_7mm_1p5mm ...
# Running kkp1_1_LJLJp_7mm_2mm ...
# Running kkp1_1_LJLJp_7mm_2p5mm ...
# Running kkp1_1_LJLJp_7mm_3mm ...
# Running kkp1_1_LJLJp_7mm_3p5mm ...
# Running kkp1_1_LJLJp_7mm_4mm ...
# Running kkp1_1_LJLJp_7mm_4p5mm ...
# Running kkp1_1_LJLJp_7mm_5mm ...
# Running kkp1_1_LJLJp_7mm_5p5mm ...
# Running kkp1_1_LJLJp_7mm_6mm ...
# Running kkp1_1_LJLJp_7mm_6p5mm ...
# Running kkp1_1_LJLJp_7mm_7mm ...
# Running kkp1_1_LJLJp_7mm_7p5mm ...
# Running kkp1_1_LJLJp_7p5mm_1p5mm ...
# Running kkp1_1_LJLJp_7p5mm_2mm ...
# Running kkp1_1_LJLJp_7p5mm_2p5mm ...
# Running kkp1_1_LJLJp_7p5mm_3mm ...
# Running kkp1_1_LJLJp_7p5mm_3p5mm ...
# Running kkp1_1_LJLJp_7p5mm_4mm ...
# Running kkp1_1_LJLJp_7p5mm_4p5mm ...
# Running kkp1_1_LJLJp_7p5mm_5mm ...
# Running kkp1_1_LJLJp_7p5mm_5p5mm ...
# Running kkp1_1_LJLJp_7p5mm_6mm ...
# Running kkp1_1_LJLJp_7p5mm_6p5mm ...
# Running kkp1_1_LJLJp_7p5mm_7mm ...
# Running kkp1_1_LJLJp_7p5mm_7p5mm ...
# Running kkp1_2_LJLJp_1p5mm_1p5mm ...
# Running kkp1_2_LJLJp_1p5mm_2mm ...
# Running kkp1_2_LJLJp_1p5mm_2p5mm ...
# Running kkp1_2_LJLJp_1p5mm_3mm ...
# Running kkp1_2_LJLJp_1p5mm_3p5mm ...
# Running kkp1_2_LJLJp_1p5mm_4mm ...
# Running kkp1_2_LJLJp_1p5mm_4p5mm ...
# Running kkp1_2_LJLJp_1p5mm_5mm ...
# Running kkp1_2_LJLJp_1p5mm_5p5mm ...
# Running kkp1_2_LJLJp_1p5mm_6mm ...
# Running kkp1_2_LJLJp_1p5mm_6p5mm ...
# Running kkp1_2_LJLJp_1p5mm_7mm ...
# Running kkp1_2_LJLJp_1p5mm_7p5mm ...
# Running kkp1_2_LJLJp_2mm_1p5mm ...
# Running kkp1_2_LJLJp_2mm_2mm ...
# Running kkp1_2_LJLJp_2mm_2p5mm ...
# Running kkp1_2_LJLJp_2mm_3mm ...
# Running kkp1_2_LJLJp_2mm_3p5mm ...
# Running kkp1_2_LJLJp_2mm_4mm ...
# Running kkp1_2_LJLJp_2mm_4p5mm ...
# Running kkp1_2_LJLJp_2mm_5mm ...
# Running kkp1_2_LJLJp_2mm_5p5mm ...
# Running kkp1_2_LJLJp_2mm_6mm ...
# Running kkp1_2_LJLJp_2mm_6p5mm ...
# Running kkp1_2_LJLJp_2mm_7mm ...
# Running kkp1_2_LJLJp_2mm_7p5mm ...
# Running kkp1_2_LJLJp_2p5mm_1p5mm ...
# Running kkp1_2_LJLJp_2p5mm_2mm ...
# Running kkp1_2_LJLJp_2p5mm_2p5mm ...
# Running kkp1_2_LJLJp_2p5mm_3mm ...
# Running kkp1_2_LJLJp_2p5mm_3p5mm ...
# Running kkp1_2_LJLJp_2p5mm_4mm ...
# Running kkp1_2_LJLJp_2p5mm_4p5mm ...
# Running kkp1_2_LJLJp_2p5mm_5mm ...
# Running kkp1_2_LJLJp_2p5mm_5p5mm ...
# Running kkp1_2_LJLJp_2p5mm_6mm ...
# Running kkp1_2_LJLJp_2p5mm_6p5mm ...
# Running kkp1_2_LJLJp_2p5mm_7mm ...
# Running kkp1_2_LJLJp_2p5mm_7p5mm ...
# Running kkp1_2_LJLJp_3mm_1p5mm ...
# Running kkp1_2_LJLJp_3mm_2mm ...
# Running kkp1_2_LJLJp_3mm_2p5mm ...
# Running kkp1_2_LJLJp_3mm_3mm ...
# Running kkp1_2_LJLJp_3mm_3p5mm ...
# Running kkp1_2_LJLJp_3mm_4mm ...
# Running kkp1_2_LJLJp_3mm_4p5mm ...
# Running kkp1_2_LJLJp_3mm_5mm ...
# Running kkp1_2_LJLJp_3mm_5p5mm ...
# Running kkp1_2_LJLJp_3mm_6mm ...
# Running kkp1_2_LJLJp_3mm_6p5mm ...
# Running kkp1_2_LJLJp_3mm_7mm ...
# Running kkp1_2_LJLJp_3mm_7p5mm ...
# Running kkp1_2_LJLJp_3p5mm_1p5mm ...
# Running kkp1_2_LJLJp_3p5mm_2mm ...
# Running kkp1_2_LJLJp_3p5mm_2p5mm ...
# Running kkp1_2_LJLJp_3p5mm_3mm ...
# Running kkp1_2_LJLJp_3p5mm_3p5mm ...
# Running kkp1_2_LJLJp_3p5mm_4mm ...
# Running kkp1_2_LJLJp_3p5mm_4p5mm ...
# Running kkp1_2_LJLJp_3p5mm_5mm ...
# Running kkp1_2_LJLJp_3p5mm_5p5mm ...
# Running kkp1_2_LJLJp_3p5mm_6mm ...
# Running kkp1_2_LJLJp_3p5mm_6p5mm ...
# Running kkp1_2_LJLJp_3p5mm_7mm ...
# Running kkp1_2_LJLJp_3p5mm_7p5mm ...
# Running kkp1_2_LJLJp_4mm_1p5mm ...
# Running kkp1_2_LJLJp_4mm_2mm ...
# Running kkp1_2_LJLJp_4mm_2p5mm ...
# Running kkp1_2_LJLJp_4mm_3mm ...
# Running kkp1_2_LJLJp_4mm_3p5mm ...
# Running kkp1_2_LJLJp_4mm_4mm ...
# Running kkp1_2_LJLJp_4mm_4p5mm ...
# Running kkp1_2_LJLJp_4mm_5mm ...
# Running kkp1_2_LJLJp_4mm_5p5mm ...
# Running kkp1_2_LJLJp_4mm_6mm ...
# Running kkp1_2_LJLJp_4mm_6p5mm ...
# Running kkp1_2_LJLJp_4mm_7mm ...
# Running kkp1_2_LJLJp_4mm_7p5mm ...
# Running kkp1_2_LJLJp_4p5mm_1p5mm ...
# Running kkp1_2_LJLJp_4p5mm_2mm ...
# Running kkp1_2_LJLJp_4p5mm_2p5mm ...
# Running kkp1_2_LJLJp_4p5mm_3mm ...
# Running kkp1_2_LJLJp_4p5mm_3p5mm ...
# Running kkp1_2_LJLJp_4p5mm_4mm ...
# Running kkp1_2_LJLJp_4p5mm_4p5mm ...
# Running kkp1_2_LJLJp_4p5mm_5mm ...
# Running kkp1_2_LJLJp_4p5mm_5p5mm ...
# Running kkp1_2_LJLJp_4p5mm_6mm ...
# Running kkp1_2_LJLJp_4p5mm_6p5mm ...
# Running kkp1_2_LJLJp_4p5mm_7mm ...
# Running kkp1_2_LJLJp_4p5mm_7p5mm ...
# Running kkp1_2_LJLJp_5mm_1p5mm ...
# Running kkp1_2_LJLJp_5mm_2mm ...
# Running kkp1_2_LJLJp_5mm_2p5mm ...
# Running kkp1_2_LJLJp_5mm_3mm ...
# Running kkp1_2_LJLJp_5mm_3p5mm ...
# Running kkp1_2_LJLJp_5mm_4mm ...
# Running kkp1_2_LJLJp_5mm_4p5mm ...
# Running kkp1_2_LJLJp_5mm_5mm ...
# Running kkp1_2_LJLJp_5mm_5p5mm ...
# Running kkp1_2_LJLJp_5mm_6mm ...
# Running kkp1_2_LJLJp_5mm_6p5mm ...
# Running kkp1_2_LJLJp_5mm_7mm ...
# Running kkp1_2_LJLJp_5mm_7p5mm ...
# Running kkp1_2_LJLJp_5p5mm_1p5mm ...
# Running kkp1_2_LJLJp_5p5mm_2mm ...
# Running kkp1_2_LJLJp_5p5mm_2p5mm ...
# Running kkp1_2_LJLJp_5p5mm_3mm ...
# Running kkp1_2_LJLJp_5p5mm_3p5mm ...
# Running kkp1_2_LJLJp_5p5mm_4mm ...
# Running kkp1_2_LJLJp_5p5mm_4p5mm ...
# Running kkp1_2_LJLJp_5p5mm_5mm ...
# Running kkp1_2_LJLJp_5p5mm_5p5mm ...
# Running kkp1_2_LJLJp_5p5mm_6mm ...
# Running kkp1_2_LJLJp_5p5mm_6p5mm ...
# Running kkp1_2_LJLJp_5p5mm_7mm ...
# Running kkp1_2_LJLJp_5p5mm_7p5mm ...
# Running kkp1_2_LJLJp_6mm_1p5mm ...
# Running kkp1_2_LJLJp_6mm_2mm ...
# Running kkp1_2_LJLJp_6mm_2p5mm ...
# Running kkp1_2_LJLJp_6mm_3mm ...
# Running kkp1_2_LJLJp_6mm_3p5mm ...
# Running kkp1_2_LJLJp_6mm_4mm ...
# Running kkp1_2_LJLJp_6mm_4p5mm ...
# Running kkp1_2_LJLJp_6mm_5mm ...
# Running kkp1_2_LJLJp_6mm_5p5mm ...
# Running kkp1_2_LJLJp_6mm_6mm ...
# Running kkp1_2_LJLJp_6mm_6p5mm ...
# Running kkp1_2_LJLJp_6mm_7mm ...
# Running kkp1_2_LJLJp_6mm_7p5mm ...
# Running kkp1_2_LJLJp_6p5mm_1p5mm ...
# Running kkp1_2_LJLJp_6p5mm_2mm ...
# Running kkp1_2_LJLJp_6p5mm_2p5mm ...
# Running kkp1_2_LJLJp_6p5mm_3mm ...
# Running kkp1_2_LJLJp_6p5mm_3p5mm ...
# Running kkp1_2_LJLJp_6p5mm_4mm ...
# Running kkp1_2_LJLJp_6p5mm_4p5mm ...
# Running kkp1_2_LJLJp_6p5mm_5mm ...
# Running kkp1_2_LJLJp_6p5mm_5p5mm ...
# Running kkp1_2_LJLJp_6p5mm_6mm ...
# Running kkp1_2_LJLJp_6p5mm_6p5mm ...
# Running kkp1_2_LJLJp_6p5mm_7mm ...
# Running kkp1_2_LJLJp_6p5mm_7p5mm ...
# Running kkp1_2_LJLJp_7mm_1p5mm ...
# Running kkp1_2_LJLJp_7mm_2mm ...
# Running kkp1_2_LJLJp_7mm_2p5mm ...
# Running kkp1_2_LJLJp_7mm_3mm ...
# Running kkp1_2_LJLJp_7mm_3p5mm ...
# Running kkp1_2_LJLJp_7mm_4mm ...
# Running kkp1_2_LJLJp_7mm_4p5mm ...
# Running kkp1_2_LJLJp_7mm_5mm ...
# Running kkp1_2_LJLJp_7mm_5p5mm ...
# Running kkp1_2_LJLJp_7mm_6mm ...
# Running kkp1_2_LJLJp_7mm_6p5mm ...
# Running kkp1_2_LJLJp_7mm_7mm ...
# Running kkp1_2_LJLJp_7mm_7p5mm ...
# Running kkp1_2_LJLJp_7p5mm_1p5mm ...
# Running kkp1_2_LJLJp_7p5mm_2mm ...
# Running kkp1_2_LJLJp_7p5mm_2p5mm ...
# Running kkp1_2_LJLJp_7p5mm_3mm ...
# Running kkp1_2_LJLJp_7p5mm_3p5mm ...
# Running kkp1_2_LJLJp_7p5mm_4mm ...
# Running kkp1_2_LJLJp_7p5mm_4p5mm ...
# Running kkp1_2_LJLJp_7p5mm_5mm ...
# Running kkp1_2_LJLJp_7p5mm_5p5mm ...
# Running kkp1_2_LJLJp_7p5mm_6mm ...
# Running kkp1_2_LJLJp_7p5mm_6p5mm ...
# Running kkp1_2_LJLJp_7p5mm_7mm ...
# Running kkp1_2_LJLJp_7p5mm_7p5mm ...
# Running kkp2_1_LJLJp_1p5mm_1p5mm ...
# Running kkp2_1_LJLJp_1p5mm_2mm ...
# Running kkp2_1_LJLJp_1p5mm_2p5mm ...
# Running kkp2_1_LJLJp_1p5mm_3mm ...
# Running kkp2_1_LJLJp_1p5mm_3p5mm ...
# Running kkp2_1_LJLJp_1p5mm_4mm ...
# Running kkp2_1_LJLJp_1p5mm_4p5mm ...
# Running kkp2_1_LJLJp_1p5mm_5mm ...
# Running kkp2_1_LJLJp_1p5mm_5p5mm ...
# Running kkp2_1_LJLJp_1p5mm_6mm ...
# Running kkp2_1_LJLJp_1p5mm_6p5mm ...
# Running kkp2_1_LJLJp_1p5mm_7mm ...
# Running kkp2_1_LJLJp_1p5mm_7p5mm ...
# Running kkp2_1_LJLJp_2mm_1p5mm ...
# Running kkp2_1_LJLJp_2mm_2mm ...
# Running kkp2_1_LJLJp_2mm_2p5mm ...
# Running kkp2_1_LJLJp_2mm_3mm ...
# Running kkp2_1_LJLJp_2mm_3p5mm ...
# Running kkp2_1_LJLJp_2mm_4mm ...
# Running kkp2_1_LJLJp_2mm_4p5mm ...
# Running kkp2_1_LJLJp_2mm_5mm ...
# Running kkp2_1_LJLJp_2mm_5p5mm ...
# Running kkp2_1_LJLJp_2mm_6mm ...
# Running kkp2_1_LJLJp_2mm_6p5mm ...
# Running kkp2_1_LJLJp_2mm_7mm ...
# Running kkp2_1_LJLJp_2mm_7p5mm ...
# Running kkp2_1_LJLJp_2p5mm_1p5mm ...
# Running kkp2_1_LJLJp_2p5mm_2mm ...
# Running kkp2_1_LJLJp_2p5mm_2p5mm ...
# Running kkp2_1_LJLJp_2p5mm_3mm ...
# Running kkp2_1_LJLJp_2p5mm_3p5mm ...
# Running kkp2_1_LJLJp_2p5mm_4mm ...
# Running kkp2_1_LJLJp_2p5mm_4p5mm ...
# Running kkp2_1_LJLJp_2p5mm_5mm ...
# Running kkp2_1_LJLJp_2p5mm_5p5mm ...
# Running kkp2_1_LJLJp_2p5mm_6mm ...
# Running kkp2_1_LJLJp_2p5mm_6p5mm ...
# Running kkp2_1_LJLJp_2p5mm_7mm ...
# Running kkp2_1_LJLJp_2p5mm_7p5mm ...
# Running kkp2_1_LJLJp_3mm_1p5mm ...
# Running kkp2_1_LJLJp_3mm_2mm ...
# Running kkp2_1_LJLJp_3mm_2p5mm ...
# Running kkp2_1_LJLJp_3mm_3mm ...
# Running kkp2_1_LJLJp_3mm_3p5mm ...
# Running kkp2_1_LJLJp_3mm_4mm ...
# Running kkp2_1_LJLJp_3mm_4p5mm ...
# Running kkp2_1_LJLJp_3mm_5mm ...
# Running kkp2_1_LJLJp_3mm_5p5mm ...
# Running kkp2_1_LJLJp_3mm_6mm ...
# Running kkp2_1_LJLJp_3mm_6p5mm ...
# Running kkp2_1_LJLJp_3mm_7mm ...
# Running kkp2_1_LJLJp_3mm_7p5mm ...
# Running kkp2_1_LJLJp_3p5mm_1p5mm ...
# Running kkp2_1_LJLJp_3p5mm_2mm ...
# Running kkp2_1_LJLJp_3p5mm_2p5mm ...
# Running kkp2_1_LJLJp_3p5mm_3mm ...
# Running kkp2_1_LJLJp_3p5mm_3p5mm ...
# Running kkp2_1_LJLJp_3p5mm_4mm ...
# Running kkp2_1_LJLJp_3p5mm_4p5mm ...
# Running kkp2_1_LJLJp_3p5mm_5mm ...
# Running kkp2_1_LJLJp_3p5mm_5p5mm ...
# Running kkp2_1_LJLJp_3p5mm_6mm ...
# Running kkp2_1_LJLJp_3p5mm_6p5mm ...
# Running kkp2_1_LJLJp_3p5mm_7mm ...
# Running kkp2_1_LJLJp_3p5mm_7p5mm ...
# Running kkp2_1_LJLJp_4mm_1p5mm ...
# Running kkp2_1_LJLJp_4mm_2mm ...
# Running kkp2_1_LJLJp_4mm_2p5mm ...
# Running kkp2_1_LJLJp_4mm_3mm ...
# Running kkp2_1_LJLJp_4mm_3p5mm ...
# Running kkp2_1_LJLJp_4mm_4mm ...
# Running kkp2_1_LJLJp_4mm_4p5mm ...
# Running kkp2_1_LJLJp_4mm_5mm ...
# Running kkp2_1_LJLJp_4mm_5p5mm ...
# Running kkp2_1_LJLJp_4mm_6mm ...
# Running kkp2_1_LJLJp_4mm_6p5mm ...
# Running kkp2_1_LJLJp_4mm_7mm ...
# Running kkp2_1_LJLJp_4mm_7p5mm ...
# Running kkp2_1_LJLJp_4p5mm_1p5mm ...
# Running kkp2_1_LJLJp_4p5mm_2mm ...
# Running kkp2_1_LJLJp_4p5mm_2p5mm ...
# Running kkp2_1_LJLJp_4p5mm_3mm ...
# Running kkp2_1_LJLJp_4p5mm_3p5mm ...
# Running kkp2_1_LJLJp_4p5mm_4mm ...
# Running kkp2_1_LJLJp_4p5mm_4p5mm ...
# Running kkp2_1_LJLJp_4p5mm_5mm ...
# Running kkp2_1_LJLJp_4p5mm_5p5mm ...
# Running kkp2_1_LJLJp_4p5mm_6mm ...
# Running kkp2_1_LJLJp_4p5mm_6p5mm ...
# Running kkp2_1_LJLJp_4p5mm_7mm ...
# Running kkp2_1_LJLJp_4p5mm_7p5mm ...
# Running kkp2_1_LJLJp_5mm_1p5mm ...
# Running kkp2_1_LJLJp_5mm_2mm ...
# Running kkp2_1_LJLJp_5mm_2p5mm ...
# Running kkp2_1_LJLJp_5mm_3mm ...
# Running kkp2_1_LJLJp_5mm_3p5mm ...
# Running kkp2_1_LJLJp_5mm_4mm ...
# Running kkp2_1_LJLJp_5mm_4p5mm ...
# Running kkp2_1_LJLJp_5mm_5mm ...
# Running kkp2_1_LJLJp_5mm_5p5mm ...
# Running kkp2_1_LJLJp_5mm_6mm ...
# Running kkp2_1_LJLJp_5mm_6p5mm ...
# Running kkp2_1_LJLJp_5mm_7mm ...
# Running kkp2_1_LJLJp_5mm_7p5mm ...
# Running kkp2_1_LJLJp_5p5mm_1p5mm ...
# Running kkp2_1_LJLJp_5p5mm_2mm ...
# Running kkp2_1_LJLJp_5p5mm_2p5mm ...
# Running kkp2_1_LJLJp_5p5mm_3mm ...
# Running kkp2_1_LJLJp_5p5mm_3p5mm ...
# Running kkp2_1_LJLJp_5p5mm_4mm ...
# Running kkp2_1_LJLJp_5p5mm_4p5mm ...
# Running kkp2_1_LJLJp_5p5mm_5mm ...
# Running kkp2_1_LJLJp_5p5mm_5p5mm ...
# Running kkp2_1_LJLJp_5p5mm_6mm ...
# Running kkp2_1_LJLJp_5p5mm_6p5mm ...
# Running kkp2_1_LJLJp_5p5mm_7mm ...
# Running kkp2_1_LJLJp_5p5mm_7p5mm ...
# Running kkp2_1_LJLJp_6mm_1p5mm ...
# Running kkp2_1_LJLJp_6mm_2mm ...
# Running kkp2_1_LJLJp_6mm_2p5mm ...
# Running kkp2_1_LJLJp_6mm_3mm ...
# Running kkp2_1_LJLJp_6mm_3p5mm ...
# Running kkp2_1_LJLJp_6mm_4mm ...
# Running kkp2_1_LJLJp_6mm_4p5mm ...
# Running kkp2_1_LJLJp_6mm_5mm ...
# Running kkp2_1_LJLJp_6mm_5p5mm ...
# Running kkp2_1_LJLJp_6mm_6mm ...
# Running kkp2_1_LJLJp_6mm_6p5mm ...
# Running kkp2_1_LJLJp_6mm_7mm ...
# Running kkp2_1_LJLJp_6mm_7p5mm ...
# Running kkp2_1_LJLJp_6p5mm_1p5mm ...
# Running kkp2_1_LJLJp_6p5mm_2mm ...
# Running kkp2_1_LJLJp_6p5mm_2p5mm ...
# Running kkp2_1_LJLJp_6p5mm_3mm ...
# Running kkp2_1_LJLJp_6p5mm_3p5mm ...
# Running kkp2_1_LJLJp_6p5mm_4mm ...
# Running kkp2_1_LJLJp_6p5mm_4p5mm ...
# Running kkp2_1_LJLJp_6p5mm_5mm ...
# Running kkp2_1_LJLJp_6p5mm_5p5mm ...
# Running kkp2_1_LJLJp_6p5mm_6mm ...
# Running kkp2_1_LJLJp_6p5mm_6p5mm ...
# Running kkp2_1_LJLJp_6p5mm_7mm ...
# Running kkp2_1_LJLJp_6p5mm_7p5mm ...
# Running kkp2_1_LJLJp_7mm_1p5mm ...
# Running kkp2_1_LJLJp_7mm_2mm ...
# Running kkp2_1_LJLJp_7mm_2p5mm ...
# Running kkp2_1_LJLJp_7mm_3mm ...
# Running kkp2_1_LJLJp_7mm_3p5mm ...
# Running kkp2_1_LJLJp_7mm_4mm ...
# Running kkp2_1_LJLJp_7mm_4p5mm ...
# Running kkp2_1_LJLJp_7mm_5mm ...
# Running kkp2_1_LJLJp_7mm_5p5mm ...
# Running kkp2_1_LJLJp_7mm_6mm ...
# Running kkp2_1_LJLJp_7mm_6p5mm ...
# Running kkp2_1_LJLJp_7mm_7mm ...
# Running kkp2_1_LJLJp_7mm_7p5mm ...
# Running kkp2_1_LJLJp_7p5mm_1p5mm ...
# Running kkp2_1_LJLJp_7p5mm_2mm ...
# Running kkp2_1_LJLJp_7p5mm_2p5mm ...
# Running kkp2_1_LJLJp_7p5mm_3mm ...
# Running kkp2_1_LJLJp_7p5mm_3p5mm ...
# Running kkp2_1_LJLJp_7p5mm_4mm ...
# Running kkp2_1_LJLJp_7p5mm_4p5mm ...
# Running kkp2_1_LJLJp_7p5mm_5mm ...
# Running kkp2_1_LJLJp_7p5mm_5p5mm ...
# Running kkp2_1_LJLJp_7p5mm_6mm ...
# Running kkp2_1_LJLJp_7p5mm_6p5mm ...
# Running kkp2_1_LJLJp_7p5mm_7mm ...
# Running kkp2_1_LJLJp_7p5mm_7p5mm ...
# Running kkp2_2_LJLJp_1p5mm_1p5mm ...
# Running kkp2_2_LJLJp_1p5mm_2mm ...
# Running kkp2_2_LJLJp_1p5mm_2p5mm ...
# Running kkp2_2_LJLJp_1p5mm_3mm ...
# Running kkp2_2_LJLJp_1p5mm_3p5mm ...
# Running kkp2_2_LJLJp_1p5mm_4mm ...
# Running kkp2_2_LJLJp_1p5mm_4p5mm ...
# Running kkp2_2_LJLJp_1p5mm_5mm ...
# Running kkp2_2_LJLJp_1p5mm_5p5mm ...
# Running kkp2_2_LJLJp_1p5mm_6mm ...
# Running kkp2_2_LJLJp_1p5mm_6p5mm ...
# Running kkp2_2_LJLJp_1p5mm_7mm ...
# Running kkp2_2_LJLJp_1p5mm_7p5mm ...
# Running kkp2_2_LJLJp_2mm_1p5mm ...
# Running kkp2_2_LJLJp_2mm_2mm ...
# Running kkp2_2_LJLJp_2mm_2p5mm ...
# Running kkp2_2_LJLJp_2mm_3mm ...
# Running kkp2_2_LJLJp_2mm_3p5mm ...
# Running kkp2_2_LJLJp_2mm_4mm ...
# Running kkp2_2_LJLJp_2mm_4p5mm ...
# Running kkp2_2_LJLJp_2mm_5mm ...
# Running kkp2_2_LJLJp_2mm_5p5mm ...
# Running kkp2_2_LJLJp_2mm_6mm ...
# Running kkp2_2_LJLJp_2mm_6p5mm ...
# Running kkp2_2_LJLJp_2mm_7mm ...
# Running kkp2_2_LJLJp_2mm_7p5mm ...
# Running kkp2_2_LJLJp_2p5mm_1p5mm ...
# Running kkp2_2_LJLJp_2p5mm_2mm ...
# Running kkp2_2_LJLJp_2p5mm_2p5mm ...
# Running kkp2_2_LJLJp_2p5mm_3mm ...
# Running kkp2_2_LJLJp_2p5mm_3p5mm ...
# Running kkp2_2_LJLJp_2p5mm_4mm ...
# Running kkp2_2_LJLJp_2p5mm_4p5mm ...
# Running kkp2_2_LJLJp_2p5mm_5mm ...
# Running kkp2_2_LJLJp_2p5mm_5p5mm ...
# Running kkp2_2_LJLJp_2p5mm_6mm ...
# Running kkp2_2_LJLJp_2p5mm_6p5mm ...
# Running kkp2_2_LJLJp_2p5mm_7mm ...
# Running kkp2_2_LJLJp_2p5mm_7p5mm ...
# Running kkp2_2_LJLJp_3mm_1p5mm ...
# Running kkp2_2_LJLJp_3mm_2mm ...
# Running kkp2_2_LJLJp_3mm_2p5mm ...
# Running kkp2_2_LJLJp_3mm_3mm ...
# Running kkp2_2_LJLJp_3mm_3p5mm ...
# Running kkp2_2_LJLJp_3mm_4mm ...
# Running kkp2_2_LJLJp_3mm_4p5mm ...
# Running kkp2_2_LJLJp_3mm_5mm ...
# Running kkp2_2_LJLJp_3mm_5p5mm ...
# Running kkp2_2_LJLJp_3mm_6mm ...
# Running kkp2_2_LJLJp_3mm_6p5mm ...
# Running kkp2_2_LJLJp_3mm_7mm ...
# Running kkp2_2_LJLJp_3mm_7p5mm ...
# Running kkp2_2_LJLJp_3p5mm_1p5mm ...
# Running kkp2_2_LJLJp_3p5mm_2mm ...
# Running kkp2_2_LJLJp_3p5mm_2p5mm ...
# Running kkp2_2_LJLJp_3p5mm_3mm ...
# Running kkp2_2_LJLJp_3p5mm_3p5mm ...
# Running kkp2_2_LJLJp_3p5mm_4mm ...
# Running kkp2_2_LJLJp_3p5mm_4p5mm ...
# Running kkp2_2_LJLJp_3p5mm_5mm ...
# Running kkp2_2_LJLJp_3p5mm_5p5mm ...
# Running kkp2_2_LJLJp_3p5mm_6mm ...
# Running kkp2_2_LJLJp_3p5mm_6p5mm ...
# Running kkp2_2_LJLJp_3p5mm_7mm ...
# Running kkp2_2_LJLJp_3p5mm_7p5mm ...
# Running kkp2_2_LJLJp_4mm_1p5mm ...
# Running kkp2_2_LJLJp_4mm_2mm ...
# Running kkp2_2_LJLJp_4mm_2p5mm ...
# Running kkp2_2_LJLJp_4mm_3mm ...
# Running kkp2_2_LJLJp_4mm_3p5mm ...
# Running kkp2_2_LJLJp_4mm_4mm ...
# Running kkp2_2_LJLJp_4mm_4p5mm ...
# Running kkp2_2_LJLJp_4mm_5mm ...
# Running kkp2_2_LJLJp_4mm_5p5mm ...
# Running kkp2_2_LJLJp_4mm_6mm ...
# Running kkp2_2_LJLJp_4mm_6p5mm ...
# Running kkp2_2_LJLJp_4mm_7mm ...
# Running kkp2_2_LJLJp_4mm_7p5mm ...
# Running kkp2_2_LJLJp_4p5mm_1p5mm ...
# Running kkp2_2_LJLJp_4p5mm_2mm ...
# Running kkp2_2_LJLJp_4p5mm_2p5mm ...
# Running kkp2_2_LJLJp_4p5mm_3mm ...
# Running kkp2_2_LJLJp_4p5mm_3p5mm ...
# Running kkp2_2_LJLJp_4p5mm_4mm ...
# Running kkp2_2_LJLJp_4p5mm_4p5mm ...
# Running kkp2_2_LJLJp_4p5mm_5mm ...
# Running kkp2_2_LJLJp_4p5mm_5p5mm ...
# Running kkp2_2_LJLJp_4p5mm_6mm ...
# Running kkp2_2_LJLJp_4p5mm_6p5mm ...
# Running kkp2_2_LJLJp_4p5mm_7mm ...
# Running kkp2_2_LJLJp_4p5mm_7p5mm ...
# Running kkp2_2_LJLJp_5mm_1p5mm ...
# Running kkp2_2_LJLJp_5mm_2mm ...
# Running kkp2_2_LJLJp_5mm_2p5mm ...
# Running kkp2_2_LJLJp_5mm_3mm ...
# Running kkp2_2_LJLJp_5mm_3p5mm ...
# Running kkp2_2_LJLJp_5mm_4mm ...
# Running kkp2_2_LJLJp_5mm_4p5mm ...
# Running kkp2_2_LJLJp_5mm_5mm ...
# Running kkp2_2_LJLJp_5mm_5p5mm ...
# Running kkp2_2_LJLJp_5mm_6mm ...
# Running kkp2_2_LJLJp_5mm_6p5mm ...
# Running kkp2_2_LJLJp_5mm_7mm ...
# Running kkp2_2_LJLJp_5mm_7p5mm ...
# Running kkp2_2_LJLJp_5p5mm_1p5mm ...
# Running kkp2_2_LJLJp_5p5mm_2mm ...
# Running kkp2_2_LJLJp_5p5mm_2p5mm ...
# Running kkp2_2_LJLJp_5p5mm_3mm ...
# Running kkp2_2_LJLJp_5p5mm_3p5mm ...
# Running kkp2_2_LJLJp_5p5mm_4mm ...
# Running kkp2_2_LJLJp_5p5mm_4p5mm ...
# Running kkp2_2_LJLJp_5p5mm_5mm ...
# Running kkp2_2_LJLJp_5p5mm_5p5mm ...
# Running kkp2_2_LJLJp_5p5mm_6mm ...
# Running kkp2_2_LJLJp_5p5mm_6p5mm ...
# Running kkp2_2_LJLJp_5p5mm_7mm ...
# Running kkp2_2_LJLJp_5p5mm_7p5mm ...
# Running kkp2_2_LJLJp_6mm_1p5mm ...
# Running kkp2_2_LJLJp_6mm_2mm ...
# Running kkp2_2_LJLJp_6mm_2p5mm ...
# Running kkp2_2_LJLJp_6mm_3mm ...
# Running kkp2_2_LJLJp_6mm_3p5mm ...
# Running kkp2_2_LJLJp_6mm_4mm ...
# Running kkp2_2_LJLJp_6mm_4p5mm ...
# Running kkp2_2_LJLJp_6mm_5mm ...
# Running kkp2_2_LJLJp_6mm_5p5mm ...
# Running kkp2_2_LJLJp_6mm_6mm ...
# Running kkp2_2_LJLJp_6mm_6p5mm ...
# Running kkp2_2_LJLJp_6mm_7mm ...
# Running kkp2_2_LJLJp_6mm_7p5mm ...
# Running kkp2_2_LJLJp_6p5mm_1p5mm ...
# Running kkp2_2_LJLJp_6p5mm_2mm ...
# Running kkp2_2_LJLJp_6p5mm_2p5mm ...
# Running kkp2_2_LJLJp_6p5mm_3mm ...
# Running kkp2_2_LJLJp_6p5mm_3p5mm ...
# Running kkp2_2_LJLJp_6p5mm_4mm ...
# Running kkp2_2_LJLJp_6p5mm_4p5mm ...
# Running kkp2_2_LJLJp_6p5mm_5mm ...
# Running kkp2_2_LJLJp_6p5mm_5p5mm ...
# Running kkp2_2_LJLJp_6p5mm_6mm ...
# Running kkp2_2_LJLJp_6p5mm_6p5mm ...
# Running kkp2_2_LJLJp_6p5mm_7mm ...
# Running kkp2_2_LJLJp_6p5mm_7p5mm ...
# Running kkp2_2_LJLJp_7mm_1p5mm ...
# Running kkp2_2_LJLJp_7mm_2mm ...
# Running kkp2_2_LJLJp_7mm_2p5mm ...
# Running kkp2_2_LJLJp_7mm_3mm ...
# Running kkp2_2_LJLJp_7mm_3p5mm ...
# Running kkp2_2_LJLJp_7mm_4mm ...
# Running kkp2_2_LJLJp_7mm_4p5mm ...
# Running kkp2_2_LJLJp_7mm_5mm ...
# Running kkp2_2_LJLJp_7mm_5p5mm ...
# Running kkp2_2_LJLJp_7mm_6mm ...
# Running kkp2_2_LJLJp_7mm_6p5mm ...
# Running kkp2_2_LJLJp_7mm_7mm ...
# Running kkp2_2_LJLJp_7mm_7p5mm ...
# Running kkp2_2_LJLJp_7p5mm_1p5mm ...
# Running kkp2_2_LJLJp_7p5mm_2mm ...
# Running kkp2_2_LJLJp_7p5mm_2p5mm ...
# Running kkp2_2_LJLJp_7p5mm_3mm ...
# Running kkp2_2_LJLJp_7p5mm_3p5mm ...
# Running kkp2_2_LJLJp_7p5mm_4mm ...
# Running kkp2_2_LJLJp_7p5mm_4p5mm ...
# Running kkp2_2_LJLJp_7p5mm_5mm ...
# Running kkp2_2_LJLJp_7p5mm_5p5mm ...
# Running kkp2_2_LJLJp_7p5mm_6mm ...
# Running kkp2_2_LJLJp_7p5mm_6p5mm ...
# Running kkp2_2_LJLJp_7p5mm_7mm ...
# Running kkp2_2_LJLJp_7p5mm_7p5mm ...
# overlap_matrix_points(): 1425.78 s

# %% [markdown]
# ## Call the field integral code

# %%
# Single point of entry inputs to class
Nmodes = 2
modes = np.linspace(1, Nmodes, Nmodes, dtype=int)
print(f'modes: {modes}')
# LJs = np.asarray([0.1, 1., 10., 100.])
# LJstrs = ['0p1', '1', '10']

# Instantiate the class object
data_path = f'../data'
myfields = fint.FieldIntegrals(Lj_vals, Ljstrs,
                               modes, data_path, debug=True,
                               has_updated_fields=True,
                               has_normalized_fields=False,
                               normalize_fields=True,
                               drop_max_field=1,
                               filename_format = f'efields_two_post_cpl_only_mode_%d_{vstr}_%s.aedtplt',
                               timeout_limit=30.)
abscissa, efields = myfields.load_fields(return_fields=True)
keys = list(efields.keys())

Akkp = myfields.overlap_matrix_points(fname=None, cidxs=[0, 1],
                                      drop_points=1,#'../data/Akkp_nondegenerate_flutes_{dd}.csv',
                                      return_matrix=True)
# Out:
# modes: [1 2]
# load_fields(): 494.709 s
# Running kkp1_1_LJLJp_1p5mm_1p5mm ...
# Dropping field at [8, 15871] ...
# Running kkp1_1_LJLJp_1p5mm_2mm ...
# Running kkp1_1_LJLJp_1p5mm_2p5mm ...
# Running kkp1_1_LJLJp_1p5mm_3mm ...
# Running kkp1_1_LJLJp_1p5mm_3p5mm ...
# Running kkp1_1_LJLJp_1p5mm_4mm ...
# Running kkp1_1_LJLJp_1p5mm_4p5mm ...
# Running kkp1_1_LJLJp_1p5mm_5mm ...
# Running kkp1_1_LJLJp_1p5mm_5p5mm ...
# Running kkp1_1_LJLJp_1p5mm_6mm ...
# Running kkp1_1_LJLJp_1p5mm_6p5mm ...
# Running kkp1_1_LJLJp_1p5mm_7mm ...
# Running kkp1_1_LJLJp_1p5mm_7p5mm ...
# Running kkp1_1_LJLJp_2mm_1p5mm ...
# Running kkp1_1_LJLJp_2mm_2mm ...
# Running kkp1_1_LJLJp_2mm_2p5mm ...
# Running kkp1_1_LJLJp_2mm_3mm ...
# Running kkp1_1_LJLJp_2mm_3p5mm ...
# Running kkp1_1_LJLJp_2mm_4mm ...
# Running kkp1_1_LJLJp_2mm_4p5mm ...
# Running kkp1_1_LJLJp_2mm_5mm ...
# Running kkp1_1_LJLJp_2mm_5p5mm ...
# Running kkp1_1_LJLJp_2mm_6mm ...
# Running kkp1_1_LJLJp_2mm_6p5mm ...
# Running kkp1_1_LJLJp_2mm_7mm ...
# Running kkp1_1_LJLJp_2mm_7p5mm ...
# Running kkp1_1_LJLJp_2p5mm_1p5mm ...
# Running kkp1_1_LJLJp_2p5mm_2mm ...
# Running kkp1_1_LJLJp_2p5mm_2p5mm ...
# Running kkp1_1_LJLJp_2p5mm_3mm ...
# Running kkp1_1_LJLJp_2p5mm_3p5mm ...
# Running kkp1_1_LJLJp_2p5mm_4mm ...
# Running kkp1_1_LJLJp_2p5mm_4p5mm ...
# Running kkp1_1_LJLJp_2p5mm_5mm ...
# Running kkp1_1_LJLJp_2p5mm_5p5mm ...
# Running kkp1_1_LJLJp_2p5mm_6mm ...
# Running kkp1_1_LJLJp_2p5mm_6p5mm ...
# Running kkp1_1_LJLJp_2p5mm_7mm ...
# Running kkp1_1_LJLJp_2p5mm_7p5mm ...
# Running kkp1_1_LJLJp_3mm_1p5mm ...
# Running kkp1_1_LJLJp_3mm_2mm ...
# Running kkp1_1_LJLJp_3mm_2p5mm ...
# Running kkp1_1_LJLJp_3mm_3mm ...
# Running kkp1_1_LJLJp_3mm_3p5mm ...
# Running kkp1_1_LJLJp_3mm_4mm ...
# Running kkp1_1_LJLJp_3mm_4p5mm ...
# Running kkp1_1_LJLJp_3mm_5mm ...
# Running kkp1_1_LJLJp_3mm_5p5mm ...
# Running kkp1_1_LJLJp_3mm_6mm ...
# Running kkp1_1_LJLJp_3mm_6p5mm ...
# Running kkp1_1_LJLJp_3mm_7mm ...
# Running kkp1_1_LJLJp_3mm_7p5mm ...
# Running kkp1_1_LJLJp_3p5mm_1p5mm ...
# Running kkp1_1_LJLJp_3p5mm_2mm ...
# Running kkp1_1_LJLJp_3p5mm_2p5mm ...
# Running kkp1_1_LJLJp_3p5mm_3mm ...
# Running kkp1_1_LJLJp_3p5mm_3p5mm ...
# Running kkp1_1_LJLJp_3p5mm_4mm ...
# Running kkp1_1_LJLJp_3p5mm_4p5mm ...
# Running kkp1_1_LJLJp_3p5mm_5mm ...
# Running kkp1_1_LJLJp_3p5mm_5p5mm ...
# Running kkp1_1_LJLJp_3p5mm_6mm ...
# Running kkp1_1_LJLJp_3p5mm_6p5mm ...
# Running kkp1_1_LJLJp_3p5mm_7mm ...
# Running kkp1_1_LJLJp_3p5mm_7p5mm ...
# Running kkp1_1_LJLJp_4mm_1p5mm ...
# Running kkp1_1_LJLJp_4mm_2mm ...
# Running kkp1_1_LJLJp_4mm_2p5mm ...
# Running kkp1_1_LJLJp_4mm_3mm ...
# Running kkp1_1_LJLJp_4mm_3p5mm ...
# Running kkp1_1_LJLJp_4mm_4mm ...
# Running kkp1_1_LJLJp_4mm_4p5mm ...
# Running kkp1_1_LJLJp_4mm_5mm ...
# Running kkp1_1_LJLJp_4mm_5p5mm ...
# Running kkp1_1_LJLJp_4mm_6mm ...
# Running kkp1_1_LJLJp_4mm_6p5mm ...
# Running kkp1_1_LJLJp_4mm_7mm ...
# Running kkp1_1_LJLJp_4mm_7p5mm ...
# Running kkp1_1_LJLJp_4p5mm_1p5mm ...
# Running kkp1_1_LJLJp_4p5mm_2mm ...
# Running kkp1_1_LJLJp_4p5mm_2p5mm ...
# Running kkp1_1_LJLJp_4p5mm_3mm ...
# Running kkp1_1_LJLJp_4p5mm_3p5mm ...
# Running kkp1_1_LJLJp_4p5mm_4mm ...
# Running kkp1_1_LJLJp_4p5mm_4p5mm ...
# Running kkp1_1_LJLJp_4p5mm_5mm ...
# Running kkp1_1_LJLJp_4p5mm_5p5mm ...
# Running kkp1_1_LJLJp_4p5mm_6mm ...
# Running kkp1_1_LJLJp_4p5mm_6p5mm ...
# Running kkp1_1_LJLJp_4p5mm_7mm ...
# Running kkp1_1_LJLJp_4p5mm_7p5mm ...
# Running kkp1_1_LJLJp_5mm_1p5mm ...
# Running kkp1_1_LJLJp_5mm_2mm ...
# Running kkp1_1_LJLJp_5mm_2p5mm ...
# Running kkp1_1_LJLJp_5mm_3mm ...
# Running kkp1_1_LJLJp_5mm_3p5mm ...
# Running kkp1_1_LJLJp_5mm_4mm ...
# Running kkp1_1_LJLJp_5mm_4p5mm ...
# Running kkp1_1_LJLJp_5mm_5mm ...
# Running kkp1_1_LJLJp_5mm_5p5mm ...
# Running kkp1_1_LJLJp_5mm_6mm ...
# Running kkp1_1_LJLJp_5mm_6p5mm ...
# Running kkp1_1_LJLJp_5mm_7mm ...
# Running kkp1_1_LJLJp_5mm_7p5mm ...
# Running kkp1_1_LJLJp_5p5mm_1p5mm ...
# Running kkp1_1_LJLJp_5p5mm_2mm ...
# Running kkp1_1_LJLJp_5p5mm_2p5mm ...
# Running kkp1_1_LJLJp_5p5mm_3mm ...
# Running kkp1_1_LJLJp_5p5mm_3p5mm ...
# Running kkp1_1_LJLJp_5p5mm_4mm ...
# Running kkp1_1_LJLJp_5p5mm_4p5mm ...
# Running kkp1_1_LJLJp_5p5mm_5mm ...
# Running kkp1_1_LJLJp_5p5mm_5p5mm ...
# Running kkp1_1_LJLJp_5p5mm_6mm ...
# Running kkp1_1_LJLJp_5p5mm_6p5mm ...
# Running kkp1_1_LJLJp_5p5mm_7mm ...
# Running kkp1_1_LJLJp_5p5mm_7p5mm ...
# Running kkp1_1_LJLJp_6mm_1p5mm ...
# Running kkp1_1_LJLJp_6mm_2mm ...
# Running kkp1_1_LJLJp_6mm_2p5mm ...
# Running kkp1_1_LJLJp_6mm_3mm ...
# Running kkp1_1_LJLJp_6mm_3p5mm ...
# Running kkp1_1_LJLJp_6mm_4mm ...
# Running kkp1_1_LJLJp_6mm_4p5mm ...
# Running kkp1_1_LJLJp_6mm_5mm ...
# Running kkp1_1_LJLJp_6mm_5p5mm ...
# Running kkp1_1_LJLJp_6mm_6mm ...
# Running kkp1_1_LJLJp_6mm_6p5mm ...
# Running kkp1_1_LJLJp_6mm_7mm ...
# Running kkp1_1_LJLJp_6mm_7p5mm ...
# Running kkp1_1_LJLJp_6p5mm_1p5mm ...
# Running kkp1_1_LJLJp_6p5mm_2mm ...
# Running kkp1_1_LJLJp_6p5mm_2p5mm ...
# Running kkp1_1_LJLJp_6p5mm_3mm ...
# Running kkp1_1_LJLJp_6p5mm_3p5mm ...
# Running kkp1_1_LJLJp_6p5mm_4mm ...
# Running kkp1_1_LJLJp_6p5mm_4p5mm ...
# Running kkp1_1_LJLJp_6p5mm_5mm ...
# Running kkp1_1_LJLJp_6p5mm_5p5mm ...
# Running kkp1_1_LJLJp_6p5mm_6mm ...
# Running kkp1_1_LJLJp_6p5mm_6p5mm ...
# Running kkp1_1_LJLJp_6p5mm_7mm ...
# Running kkp1_1_LJLJp_6p5mm_7p5mm ...
# Running kkp1_1_LJLJp_7mm_1p5mm ...
# Running kkp1_1_LJLJp_7mm_2mm ...
# Running kkp1_1_LJLJp_7mm_2p5mm ...
# Running kkp1_1_LJLJp_7mm_3mm ...
# Running kkp1_1_LJLJp_7mm_3p5mm ...
# Running kkp1_1_LJLJp_7mm_4mm ...
# Running kkp1_1_LJLJp_7mm_4p5mm ...
# Running kkp1_1_LJLJp_7mm_5mm ...
# Running kkp1_1_LJLJp_7mm_5p5mm ...
# Running kkp1_1_LJLJp_7mm_6mm ...
# Running kkp1_1_LJLJp_7mm_6p5mm ...
# Running kkp1_1_LJLJp_7mm_7mm ...
# Running kkp1_1_LJLJp_7mm_7p5mm ...
# Running kkp1_1_LJLJp_7p5mm_1p5mm ...
# Running kkp1_1_LJLJp_7p5mm_2mm ...
# Running kkp1_1_LJLJp_7p5mm_2p5mm ...
# Running kkp1_1_LJLJp_7p5mm_3mm ...
# Running kkp1_1_LJLJp_7p5mm_3p5mm ...
# Running kkp1_1_LJLJp_7p5mm_4mm ...
# Running kkp1_1_LJLJp_7p5mm_4p5mm ...
# Running kkp1_1_LJLJp_7p5mm_5mm ...
# Running kkp1_1_LJLJp_7p5mm_5p5mm ...
# Running kkp1_1_LJLJp_7p5mm_6mm ...
# Running kkp1_1_LJLJp_7p5mm_6p5mm ...
# Running kkp1_1_LJLJp_7p5mm_7mm ...
# Running kkp1_1_LJLJp_7p5mm_7p5mm ...
# Running kkp1_2_LJLJp_1p5mm_1p5mm ...
# Running kkp1_2_LJLJp_1p5mm_2mm ...
# Running kkp1_2_LJLJp_1p5mm_2p5mm ...
# Running kkp1_2_LJLJp_1p5mm_3mm ...
# Running kkp1_2_LJLJp_1p5mm_3p5mm ...
# Running kkp1_2_LJLJp_1p5mm_4mm ...
# Running kkp1_2_LJLJp_1p5mm_4p5mm ...
# Running kkp1_2_LJLJp_1p5mm_5mm ...
# Running kkp1_2_LJLJp_1p5mm_5p5mm ...
# Running kkp1_2_LJLJp_1p5mm_6mm ...
# Running kkp1_2_LJLJp_1p5mm_6p5mm ...
# Running kkp1_2_LJLJp_1p5mm_7mm ...
# Running kkp1_2_LJLJp_1p5mm_7p5mm ...
# Running kkp1_2_LJLJp_2mm_1p5mm ...
# Running kkp1_2_LJLJp_2mm_2mm ...
# Running kkp1_2_LJLJp_2mm_2p5mm ...
# Running kkp1_2_LJLJp_2mm_3mm ...
# Running kkp1_2_LJLJp_2mm_3p5mm ...
# Running kkp1_2_LJLJp_2mm_4mm ...
# Running kkp1_2_LJLJp_2mm_4p5mm ...
# Running kkp1_2_LJLJp_2mm_5mm ...
# Running kkp1_2_LJLJp_2mm_5p5mm ...
# Running kkp1_2_LJLJp_2mm_6mm ...
# Running kkp1_2_LJLJp_2mm_6p5mm ...
# Running kkp1_2_LJLJp_2mm_7mm ...
# Running kkp1_2_LJLJp_2mm_7p5mm ...
# Running kkp1_2_LJLJp_2p5mm_1p5mm ...
# Running kkp1_2_LJLJp_2p5mm_2mm ...
# Running kkp1_2_LJLJp_2p5mm_2p5mm ...
# Running kkp1_2_LJLJp_2p5mm_3mm ...
# Running kkp1_2_LJLJp_2p5mm_3p5mm ...
# Running kkp1_2_LJLJp_2p5mm_4mm ...
# Running kkp1_2_LJLJp_2p5mm_4p5mm ...
# Running kkp1_2_LJLJp_2p5mm_5mm ...
# Running kkp1_2_LJLJp_2p5mm_5p5mm ...
# Running kkp1_2_LJLJp_2p5mm_6mm ...
# Running kkp1_2_LJLJp_2p5mm_6p5mm ...
# Running kkp1_2_LJLJp_2p5mm_7mm ...
# Running kkp1_2_LJLJp_2p5mm_7p5mm ...
# Running kkp1_2_LJLJp_3mm_1p5mm ...
# Running kkp1_2_LJLJp_3mm_2mm ...
# Running kkp1_2_LJLJp_3mm_2p5mm ...
# Running kkp1_2_LJLJp_3mm_3mm ...
# Running kkp1_2_LJLJp_3mm_3p5mm ...
# Running kkp1_2_LJLJp_3mm_4mm ...
# Running kkp1_2_LJLJp_3mm_4p5mm ...
# Running kkp1_2_LJLJp_3mm_5mm ...
# Running kkp1_2_LJLJp_3mm_5p5mm ...
# Running kkp1_2_LJLJp_3mm_6mm ...
# Running kkp1_2_LJLJp_3mm_6p5mm ...
# Running kkp1_2_LJLJp_3mm_7mm ...
# Running kkp1_2_LJLJp_3mm_7p5mm ...
# Running kkp1_2_LJLJp_3p5mm_1p5mm ...
# Running kkp1_2_LJLJp_3p5mm_2mm ...
# Running kkp1_2_LJLJp_3p5mm_2p5mm ...
# Running kkp1_2_LJLJp_3p5mm_3mm ...
# Running kkp1_2_LJLJp_3p5mm_3p5mm ...
# Running kkp1_2_LJLJp_3p5mm_4mm ...
# Running kkp1_2_LJLJp_3p5mm_4p5mm ...
# Running kkp1_2_LJLJp_3p5mm_5mm ...
# Running kkp1_2_LJLJp_3p5mm_5p5mm ...
# Running kkp1_2_LJLJp_3p5mm_6mm ...
# Running kkp1_2_LJLJp_3p5mm_6p5mm ...
# Running kkp1_2_LJLJp_3p5mm_7mm ...
# Running kkp1_2_LJLJp_3p5mm_7p5mm ...
# Running kkp1_2_LJLJp_4mm_1p5mm ...
# Running kkp1_2_LJLJp_4mm_2mm ...
# Running kkp1_2_LJLJp_4mm_2p5mm ...
# Running kkp1_2_LJLJp_4mm_3mm ...
# Running kkp1_2_LJLJp_4mm_3p5mm ...
# Running kkp1_2_LJLJp_4mm_4mm ...
# Running kkp1_2_LJLJp_4mm_4p5mm ...
# Running kkp1_2_LJLJp_4mm_5mm ...
# Running kkp1_2_LJLJp_4mm_5p5mm ...
# Running kkp1_2_LJLJp_4mm_6mm ...
# Running kkp1_2_LJLJp_4mm_6p5mm ...
# Running kkp1_2_LJLJp_4mm_7mm ...
# Running kkp1_2_LJLJp_4mm_7p5mm ...
# Running kkp1_2_LJLJp_4p5mm_1p5mm ...
# Running kkp1_2_LJLJp_4p5mm_2mm ...
# Running kkp1_2_LJLJp_4p5mm_2p5mm ...
# Running kkp1_2_LJLJp_4p5mm_3mm ...
# Running kkp1_2_LJLJp_4p5mm_3p5mm ...
# Running kkp1_2_LJLJp_4p5mm_4mm ...
# Running kkp1_2_LJLJp_4p5mm_4p5mm ...
# Running kkp1_2_LJLJp_4p5mm_5mm ...
# Running kkp1_2_LJLJp_4p5mm_5p5mm ...
# Running kkp1_2_LJLJp_4p5mm_6mm ...
# Running kkp1_2_LJLJp_4p5mm_6p5mm ...
# Running kkp1_2_LJLJp_4p5mm_7mm ...
# Running kkp1_2_LJLJp_4p5mm_7p5mm ...
# Running kkp1_2_LJLJp_5mm_1p5mm ...
# Running kkp1_2_LJLJp_5mm_2mm ...
# Running kkp1_2_LJLJp_5mm_2p5mm ...
# Running kkp1_2_LJLJp_5mm_3mm ...
# Running kkp1_2_LJLJp_5mm_3p5mm ...
# Running kkp1_2_LJLJp_5mm_4mm ...
# Running kkp1_2_LJLJp_5mm_4p5mm ...
# Running kkp1_2_LJLJp_5mm_5mm ...
# Running kkp1_2_LJLJp_5mm_5p5mm ...
# Running kkp1_2_LJLJp_5mm_6mm ...
# Running kkp1_2_LJLJp_5mm_6p5mm ...
# Running kkp1_2_LJLJp_5mm_7mm ...
# Running kkp1_2_LJLJp_5mm_7p5mm ...
# Running kkp1_2_LJLJp_5p5mm_1p5mm ...
# Running kkp1_2_LJLJp_5p5mm_2mm ...
# Running kkp1_2_LJLJp_5p5mm_2p5mm ...
# Running kkp1_2_LJLJp_5p5mm_3mm ...
# Running kkp1_2_LJLJp_5p5mm_3p5mm ...
# Running kkp1_2_LJLJp_5p5mm_4mm ...
# Running kkp1_2_LJLJp_5p5mm_4p5mm ...
# Running kkp1_2_LJLJp_5p5mm_5mm ...
# Running kkp1_2_LJLJp_5p5mm_5p5mm ...
# Running kkp1_2_LJLJp_5p5mm_6mm ...
# Running kkp1_2_LJLJp_5p5mm_6p5mm ...
# Running kkp1_2_LJLJp_5p5mm_7mm ...
# Running kkp1_2_LJLJp_5p5mm_7p5mm ...
# Running kkp1_2_LJLJp_6mm_1p5mm ...
# Running kkp1_2_LJLJp_6mm_2mm ...
# Running kkp1_2_LJLJp_6mm_2p5mm ...
# Running kkp1_2_LJLJp_6mm_3mm ...
# Running kkp1_2_LJLJp_6mm_3p5mm ...
# Running kkp1_2_LJLJp_6mm_4mm ...
# Running kkp1_2_LJLJp_6mm_4p5mm ...
# Running kkp1_2_LJLJp_6mm_5mm ...
# Running kkp1_2_LJLJp_6mm_5p5mm ...
# Running kkp1_2_LJLJp_6mm_6mm ...
# Running kkp1_2_LJLJp_6mm_6p5mm ...
# Running kkp1_2_LJLJp_6mm_7mm ...
# Running kkp1_2_LJLJp_6mm_7p5mm ...
# Running kkp1_2_LJLJp_6p5mm_1p5mm ...
# Running kkp1_2_LJLJp_6p5mm_2mm ...
# Running kkp1_2_LJLJp_6p5mm_2p5mm ...
# Running kkp1_2_LJLJp_6p5mm_3mm ...
# Running kkp1_2_LJLJp_6p5mm_3p5mm ...
# Running kkp1_2_LJLJp_6p5mm_4mm ...
# Running kkp1_2_LJLJp_6p5mm_4p5mm ...
# Running kkp1_2_LJLJp_6p5mm_5mm ...
# Running kkp1_2_LJLJp_6p5mm_5p5mm ...
# Running kkp1_2_LJLJp_6p5mm_6mm ...
# Running kkp1_2_LJLJp_6p5mm_6p5mm ...
# Running kkp1_2_LJLJp_6p5mm_7mm ...
# Running kkp1_2_LJLJp_6p5mm_7p5mm ...
# Running kkp1_2_LJLJp_7mm_1p5mm ...
# Running kkp1_2_LJLJp_7mm_2mm ...
# Running kkp1_2_LJLJp_7mm_2p5mm ...
# Running kkp1_2_LJLJp_7mm_3mm ...
# Running kkp1_2_LJLJp_7mm_3p5mm ...
# Running kkp1_2_LJLJp_7mm_4mm ...
# Running kkp1_2_LJLJp_7mm_4p5mm ...
# Running kkp1_2_LJLJp_7mm_5mm ...
# Running kkp1_2_LJLJp_7mm_5p5mm ...
# Running kkp1_2_LJLJp_7mm_6mm ...
# Running kkp1_2_LJLJp_7mm_6p5mm ...
# Running kkp1_2_LJLJp_7mm_7mm ...
# Running kkp1_2_LJLJp_7mm_7p5mm ...
# Running kkp1_2_LJLJp_7p5mm_1p5mm ...
# Running kkp1_2_LJLJp_7p5mm_2mm ...
# Running kkp1_2_LJLJp_7p5mm_2p5mm ...
# Running kkp1_2_LJLJp_7p5mm_3mm ...
# Running kkp1_2_LJLJp_7p5mm_3p5mm ...
# Running kkp1_2_LJLJp_7p5mm_4mm ...
# Running kkp1_2_LJLJp_7p5mm_4p5mm ...
# Running kkp1_2_LJLJp_7p5mm_5mm ...
# Running kkp1_2_LJLJp_7p5mm_5p5mm ...
# Running kkp1_2_LJLJp_7p5mm_6mm ...
# Running kkp1_2_LJLJp_7p5mm_6p5mm ...
# Running kkp1_2_LJLJp_7p5mm_7mm ...
# Running kkp1_2_LJLJp_7p5mm_7p5mm ...
# Running kkp2_1_LJLJp_1p5mm_1p5mm ...
# Running kkp2_1_LJLJp_1p5mm_2mm ...
# Running kkp2_1_LJLJp_1p5mm_2p5mm ...
# Running kkp2_1_LJLJp_1p5mm_3mm ...
# Running kkp2_1_LJLJp_1p5mm_3p5mm ...
# Running kkp2_1_LJLJp_1p5mm_4mm ...
# Running kkp2_1_LJLJp_1p5mm_4p5mm ...
# Running kkp2_1_LJLJp_1p5mm_5mm ...
# Running kkp2_1_LJLJp_1p5mm_5p5mm ...
# Running kkp2_1_LJLJp_1p5mm_6mm ...
# Running kkp2_1_LJLJp_1p5mm_6p5mm ...
# Running kkp2_1_LJLJp_1p5mm_7mm ...
# Running kkp2_1_LJLJp_1p5mm_7p5mm ...
# Running kkp2_1_LJLJp_2mm_1p5mm ...
# Running kkp2_1_LJLJp_2mm_2mm ...
# Running kkp2_1_LJLJp_2mm_2p5mm ...
# Running kkp2_1_LJLJp_2mm_3mm ...
# Running kkp2_1_LJLJp_2mm_3p5mm ...
# Running kkp2_1_LJLJp_2mm_4mm ...
# Running kkp2_1_LJLJp_2mm_4p5mm ...
# Running kkp2_1_LJLJp_2mm_5mm ...
# Running kkp2_1_LJLJp_2mm_5p5mm ...
# Running kkp2_1_LJLJp_2mm_6mm ...
# Running kkp2_1_LJLJp_2mm_6p5mm ...
# Running kkp2_1_LJLJp_2mm_7mm ...
# Running kkp2_1_LJLJp_2mm_7p5mm ...
# Running kkp2_1_LJLJp_2p5mm_1p5mm ...
# Running kkp2_1_LJLJp_2p5mm_2mm ...
# Running kkp2_1_LJLJp_2p5mm_2p5mm ...
# Running kkp2_1_LJLJp_2p5mm_3mm ...
# Running kkp2_1_LJLJp_2p5mm_3p5mm ...
# Running kkp2_1_LJLJp_2p5mm_4mm ...
# Running kkp2_1_LJLJp_2p5mm_4p5mm ...
# Running kkp2_1_LJLJp_2p5mm_5mm ...
# Running kkp2_1_LJLJp_2p5mm_5p5mm ...
# Running kkp2_1_LJLJp_2p5mm_6mm ...
# Running kkp2_1_LJLJp_2p5mm_6p5mm ...
# Running kkp2_1_LJLJp_2p5mm_7mm ...
# Running kkp2_1_LJLJp_2p5mm_7p5mm ...
# Running kkp2_1_LJLJp_3mm_1p5mm ...
# Running kkp2_1_LJLJp_3mm_2mm ...
# Running kkp2_1_LJLJp_3mm_2p5mm ...
# Running kkp2_1_LJLJp_3mm_3mm ...
# Running kkp2_1_LJLJp_3mm_3p5mm ...
# Running kkp2_1_LJLJp_3mm_4mm ...
# Running kkp2_1_LJLJp_3mm_4p5mm ...
# Running kkp2_1_LJLJp_3mm_5mm ...
# Running kkp2_1_LJLJp_3mm_5p5mm ...
# Running kkp2_1_LJLJp_3mm_6mm ...
# Running kkp2_1_LJLJp_3mm_6p5mm ...
# Running kkp2_1_LJLJp_3mm_7mm ...
# Running kkp2_1_LJLJp_3mm_7p5mm ...
# Running kkp2_1_LJLJp_3p5mm_1p5mm ...
# Running kkp2_1_LJLJp_3p5mm_2mm ...
# Running kkp2_1_LJLJp_3p5mm_2p5mm ...
# Running kkp2_1_LJLJp_3p5mm_3mm ...
# Running kkp2_1_LJLJp_3p5mm_3p5mm ...
# Running kkp2_1_LJLJp_3p5mm_4mm ...
# Running kkp2_1_LJLJp_3p5mm_4p5mm ...
# Running kkp2_1_LJLJp_3p5mm_5mm ...
# Running kkp2_1_LJLJp_3p5mm_5p5mm ...
# Running kkp2_1_LJLJp_3p5mm_6mm ...
# Running kkp2_1_LJLJp_3p5mm_6p5mm ...
# Running kkp2_1_LJLJp_3p5mm_7mm ...
# Running kkp2_1_LJLJp_3p5mm_7p5mm ...
# Running kkp2_1_LJLJp_4mm_1p5mm ...
# Running kkp2_1_LJLJp_4mm_2mm ...
# Running kkp2_1_LJLJp_4mm_2p5mm ...
# Running kkp2_1_LJLJp_4mm_3mm ...
# Running kkp2_1_LJLJp_4mm_3p5mm ...
# Running kkp2_1_LJLJp_4mm_4mm ...
# Running kkp2_1_LJLJp_4mm_4p5mm ...
# Running kkp2_1_LJLJp_4mm_5mm ...
# Running kkp2_1_LJLJp_4mm_5p5mm ...
# Running kkp2_1_LJLJp_4mm_6mm ...
# Running kkp2_1_LJLJp_4mm_6p5mm ...
# Running kkp2_1_LJLJp_4mm_7mm ...
# Running kkp2_1_LJLJp_4mm_7p5mm ...
# Running kkp2_1_LJLJp_4p5mm_1p5mm ...
# Running kkp2_1_LJLJp_4p5mm_2mm ...
# Running kkp2_1_LJLJp_4p5mm_2p5mm ...
# Running kkp2_1_LJLJp_4p5mm_3mm ...
# Running kkp2_1_LJLJp_4p5mm_3p5mm ...
# Running kkp2_1_LJLJp_4p5mm_4mm ...
# Running kkp2_1_LJLJp_4p5mm_4p5mm ...
# Running kkp2_1_LJLJp_4p5mm_5mm ...
# Running kkp2_1_LJLJp_4p5mm_5p5mm ...
# Running kkp2_1_LJLJp_4p5mm_6mm ...
# Running kkp2_1_LJLJp_4p5mm_6p5mm ...
# Running kkp2_1_LJLJp_4p5mm_7mm ...
# Running kkp2_1_LJLJp_4p5mm_7p5mm ...
# Running kkp2_1_LJLJp_5mm_1p5mm ...
# Running kkp2_1_LJLJp_5mm_2mm ...
# Running kkp2_1_LJLJp_5mm_2p5mm ...
# Running kkp2_1_LJLJp_5mm_3mm ...
# Running kkp2_1_LJLJp_5mm_3p5mm ...
# Running kkp2_1_LJLJp_5mm_4mm ...
# Running kkp2_1_LJLJp_5mm_4p5mm ...
# Running kkp2_1_LJLJp_5mm_5mm ...
# Running kkp2_1_LJLJp_5mm_5p5mm ...
# Running kkp2_1_LJLJp_5mm_6mm ...
# Running kkp2_1_LJLJp_5mm_6p5mm ...
# Running kkp2_1_LJLJp_5mm_7mm ...
# Running kkp2_1_LJLJp_5mm_7p5mm ...
# Running kkp2_1_LJLJp_5p5mm_1p5mm ...
# Running kkp2_1_LJLJp_5p5mm_2mm ...
# Running kkp2_1_LJLJp_5p5mm_2p5mm ...
# Running kkp2_1_LJLJp_5p5mm_3mm ...
# Running kkp2_1_LJLJp_5p5mm_3p5mm ...
# Running kkp2_1_LJLJp_5p5mm_4mm ...
# Running kkp2_1_LJLJp_5p5mm_4p5mm ...
# Running kkp2_1_LJLJp_5p5mm_5mm ...
# Running kkp2_1_LJLJp_5p5mm_5p5mm ...
# Running kkp2_1_LJLJp_5p5mm_6mm ...
# Running kkp2_1_LJLJp_5p5mm_6p5mm ...
# Running kkp2_1_LJLJp_5p5mm_7mm ...
# Running kkp2_1_LJLJp_5p5mm_7p5mm ...
# Running kkp2_1_LJLJp_6mm_1p5mm ...
# Running kkp2_1_LJLJp_6mm_2mm ...
# Running kkp2_1_LJLJp_6mm_2p5mm ...
# Running kkp2_1_LJLJp_6mm_3mm ...
# Running kkp2_1_LJLJp_6mm_3p5mm ...
# Running kkp2_1_LJLJp_6mm_4mm ...
# Running kkp2_1_LJLJp_6mm_4p5mm ...
# Running kkp2_1_LJLJp_6mm_5mm ...
# Running kkp2_1_LJLJp_6mm_5p5mm ...
# Running kkp2_1_LJLJp_6mm_6mm ...
# Running kkp2_1_LJLJp_6mm_6p5mm ...
# Running kkp2_1_LJLJp_6mm_7mm ...
# Running kkp2_1_LJLJp_6mm_7p5mm ...
# Running kkp2_1_LJLJp_6p5mm_1p5mm ...
# Running kkp2_1_LJLJp_6p5mm_2mm ...
# Running kkp2_1_LJLJp_6p5mm_2p5mm ...
# Running kkp2_1_LJLJp_6p5mm_3mm ...
# Running kkp2_1_LJLJp_6p5mm_3p5mm ...
# Running kkp2_1_LJLJp_6p5mm_4mm ...
# Running kkp2_1_LJLJp_6p5mm_4p5mm ...
# Running kkp2_1_LJLJp_6p5mm_5mm ...
# Running kkp2_1_LJLJp_6p5mm_5p5mm ...
# Running kkp2_1_LJLJp_6p5mm_6mm ...
# Running kkp2_1_LJLJp_6p5mm_6p5mm ...
# Running kkp2_1_LJLJp_6p5mm_7mm ...
# Running kkp2_1_LJLJp_6p5mm_7p5mm ...
# Running kkp2_1_LJLJp_7mm_1p5mm ...
# Running kkp2_1_LJLJp_7mm_2mm ...
# Running kkp2_1_LJLJp_7mm_2p5mm ...
# Running kkp2_1_LJLJp_7mm_3mm ...
# Running kkp2_1_LJLJp_7mm_3p5mm ...
# Running kkp2_1_LJLJp_7mm_4mm ...
# Running kkp2_1_LJLJp_7mm_4p5mm ...
# Running kkp2_1_LJLJp_7mm_5mm ...
# Running kkp2_1_LJLJp_7mm_5p5mm ...
# Running kkp2_1_LJLJp_7mm_6mm ...
# Running kkp2_1_LJLJp_7mm_6p5mm ...
# Running kkp2_1_LJLJp_7mm_7mm ...
# Running kkp2_1_LJLJp_7mm_7p5mm ...
# Running kkp2_1_LJLJp_7p5mm_1p5mm ...
# Running kkp2_1_LJLJp_7p5mm_2mm ...
# Running kkp2_1_LJLJp_7p5mm_2p5mm ...
# Running kkp2_1_LJLJp_7p5mm_3mm ...
# Running kkp2_1_LJLJp_7p5mm_3p5mm ...
# Running kkp2_1_LJLJp_7p5mm_4mm ...
# Running kkp2_1_LJLJp_7p5mm_4p5mm ...
# Running kkp2_1_LJLJp_7p5mm_5mm ...
# Running kkp2_1_LJLJp_7p5mm_5p5mm ...
# Running kkp2_1_LJLJp_7p5mm_6mm ...
# Running kkp2_1_LJLJp_7p5mm_6p5mm ...
# Running kkp2_1_LJLJp_7p5mm_7mm ...
# Running kkp2_1_LJLJp_7p5mm_7p5mm ...
# Running kkp2_2_LJLJp_1p5mm_1p5mm ...
# Running kkp2_2_LJLJp_1p5mm_2mm ...
# Running kkp2_2_LJLJp_1p5mm_2p5mm ...
# Running kkp2_2_LJLJp_1p5mm_3mm ...
# Running kkp2_2_LJLJp_1p5mm_3p5mm ...
# Running kkp2_2_LJLJp_1p5mm_4mm ...
# Running kkp2_2_LJLJp_1p5mm_4p5mm ...
# Running kkp2_2_LJLJp_1p5mm_5mm ...
# Running kkp2_2_LJLJp_1p5mm_5p5mm ...
# Running kkp2_2_LJLJp_1p5mm_6mm ...
# Running kkp2_2_LJLJp_1p5mm_6p5mm ...
# Running kkp2_2_LJLJp_1p5mm_7mm ...
# Running kkp2_2_LJLJp_1p5mm_7p5mm ...
# Running kkp2_2_LJLJp_2mm_1p5mm ...
# Running kkp2_2_LJLJp_2mm_2mm ...
# Running kkp2_2_LJLJp_2mm_2p5mm ...
# Running kkp2_2_LJLJp_2mm_3mm ...
# Running kkp2_2_LJLJp_2mm_3p5mm ...
# Running kkp2_2_LJLJp_2mm_4mm ...
# Running kkp2_2_LJLJp_2mm_4p5mm ...
# Running kkp2_2_LJLJp_2mm_5mm ...
# Running kkp2_2_LJLJp_2mm_5p5mm ...
# Running kkp2_2_LJLJp_2mm_6mm ...
# Running kkp2_2_LJLJp_2mm_6p5mm ...
# Running kkp2_2_LJLJp_2mm_7mm ...
# Running kkp2_2_LJLJp_2mm_7p5mm ...
# Running kkp2_2_LJLJp_2p5mm_1p5mm ...
# Running kkp2_2_LJLJp_2p5mm_2mm ...
# Running kkp2_2_LJLJp_2p5mm_2p5mm ...
# Running kkp2_2_LJLJp_2p5mm_3mm ...
# Running kkp2_2_LJLJp_2p5mm_3p5mm ...
# Running kkp2_2_LJLJp_2p5mm_4mm ...
# Running kkp2_2_LJLJp_2p5mm_4p5mm ...
# Running kkp2_2_LJLJp_2p5mm_5mm ...
# Running kkp2_2_LJLJp_2p5mm_5p5mm ...
# Running kkp2_2_LJLJp_2p5mm_6mm ...
# Running kkp2_2_LJLJp_2p5mm_6p5mm ...
# Running kkp2_2_LJLJp_2p5mm_7mm ...
# Running kkp2_2_LJLJp_2p5mm_7p5mm ...
# Running kkp2_2_LJLJp_3mm_1p5mm ...
# Running kkp2_2_LJLJp_3mm_2mm ...
# Running kkp2_2_LJLJp_3mm_2p5mm ...
# Running kkp2_2_LJLJp_3mm_3mm ...
# Running kkp2_2_LJLJp_3mm_3p5mm ...
# Running kkp2_2_LJLJp_3mm_4mm ...
# Running kkp2_2_LJLJp_3mm_4p5mm ...
# Running kkp2_2_LJLJp_3mm_5mm ...
# Running kkp2_2_LJLJp_3mm_5p5mm ...
# Running kkp2_2_LJLJp_3mm_6mm ...
# Running kkp2_2_LJLJp_3mm_6p5mm ...
# Running kkp2_2_LJLJp_3mm_7mm ...
# Running kkp2_2_LJLJp_3mm_7p5mm ...
# Running kkp2_2_LJLJp_3p5mm_1p5mm ...
# Running kkp2_2_LJLJp_3p5mm_2mm ...
# Running kkp2_2_LJLJp_3p5mm_2p5mm ...
# Running kkp2_2_LJLJp_3p5mm_3mm ...
# Running kkp2_2_LJLJp_3p5mm_3p5mm ...
# Running kkp2_2_LJLJp_3p5mm_4mm ...
# Running kkp2_2_LJLJp_3p5mm_4p5mm ...
# Running kkp2_2_LJLJp_3p5mm_5mm ...
# Running kkp2_2_LJLJp_3p5mm_5p5mm ...
# Running kkp2_2_LJLJp_3p5mm_6mm ...
# Running kkp2_2_LJLJp_3p5mm_6p5mm ...
# Running kkp2_2_LJLJp_3p5mm_7mm ...
# Running kkp2_2_LJLJp_3p5mm_7p5mm ...
# Running kkp2_2_LJLJp_4mm_1p5mm ...
# Running kkp2_2_LJLJp_4mm_2mm ...
# Running kkp2_2_LJLJp_4mm_2p5mm ...
# Running kkp2_2_LJLJp_4mm_3mm ...
# Running kkp2_2_LJLJp_4mm_3p5mm ...
# Running kkp2_2_LJLJp_4mm_4mm ...
# Running kkp2_2_LJLJp_4mm_4p5mm ...
# Running kkp2_2_LJLJp_4mm_5mm ...
# Running kkp2_2_LJLJp_4mm_5p5mm ...
# Running kkp2_2_LJLJp_4mm_6mm ...
# Running kkp2_2_LJLJp_4mm_6p5mm ...
# Running kkp2_2_LJLJp_4mm_7mm ...
# Running kkp2_2_LJLJp_4mm_7p5mm ...
# Running kkp2_2_LJLJp_4p5mm_1p5mm ...
# Running kkp2_2_LJLJp_4p5mm_2mm ...
# Running kkp2_2_LJLJp_4p5mm_2p5mm ...
# Running kkp2_2_LJLJp_4p5mm_3mm ...
# Running kkp2_2_LJLJp_4p5mm_3p5mm ...
# Running kkp2_2_LJLJp_4p5mm_4mm ...
# Running kkp2_2_LJLJp_4p5mm_4p5mm ...
# Running kkp2_2_LJLJp_4p5mm_5mm ...
# Running kkp2_2_LJLJp_4p5mm_5p5mm ...
# Running kkp2_2_LJLJp_4p5mm_6mm ...
# Running kkp2_2_LJLJp_4p5mm_6p5mm ...
# Running kkp2_2_LJLJp_4p5mm_7mm ...
# Running kkp2_2_LJLJp_4p5mm_7p5mm ...
# Running kkp2_2_LJLJp_5mm_1p5mm ...
# Running kkp2_2_LJLJp_5mm_2mm ...
# Running kkp2_2_LJLJp_5mm_2p5mm ...
# Running kkp2_2_LJLJp_5mm_3mm ...
# Running kkp2_2_LJLJp_5mm_3p5mm ...
# Running kkp2_2_LJLJp_5mm_4mm ...
# Running kkp2_2_LJLJp_5mm_4p5mm ...
# Running kkp2_2_LJLJp_5mm_5mm ...
# Running kkp2_2_LJLJp_5mm_5p5mm ...
# Running kkp2_2_LJLJp_5mm_6mm ...
# Running kkp2_2_LJLJp_5mm_6p5mm ...
# Running kkp2_2_LJLJp_5mm_7mm ...
# Running kkp2_2_LJLJp_5mm_7p5mm ...
# Running kkp2_2_LJLJp_5p5mm_1p5mm ...
# Running kkp2_2_LJLJp_5p5mm_2mm ...
# Running kkp2_2_LJLJp_5p5mm_2p5mm ...
# Running kkp2_2_LJLJp_5p5mm_3mm ...
# Running kkp2_2_LJLJp_5p5mm_3p5mm ...
# Running kkp2_2_LJLJp_5p5mm_4mm ...
# Running kkp2_2_LJLJp_5p5mm_4p5mm ...
# Running kkp2_2_LJLJp_5p5mm_5mm ...
# Running kkp2_2_LJLJp_5p5mm_5p5mm ...
# Running kkp2_2_LJLJp_5p5mm_6mm ...
# Running kkp2_2_LJLJp_5p5mm_6p5mm ...
# Running kkp2_2_LJLJp_5p5mm_7mm ...
# Running kkp2_2_LJLJp_5p5mm_7p5mm ...
# Running kkp2_2_LJLJp_6mm_1p5mm ...
# Running kkp2_2_LJLJp_6mm_2mm ...
# Running kkp2_2_LJLJp_6mm_2p5mm ...
# Running kkp2_2_LJLJp_6mm_3mm ...
# Running kkp2_2_LJLJp_6mm_3p5mm ...
# Running kkp2_2_LJLJp_6mm_4mm ...
# Running kkp2_2_LJLJp_6mm_4p5mm ...
# Running kkp2_2_LJLJp_6mm_5mm ...
# Running kkp2_2_LJLJp_6mm_5p5mm ...
# Running kkp2_2_LJLJp_6mm_6mm ...
# Running kkp2_2_LJLJp_6mm_6p5mm ...
# Running kkp2_2_LJLJp_6mm_7mm ...
# Running kkp2_2_LJLJp_6mm_7p5mm ...
# Running kkp2_2_LJLJp_6p5mm_1p5mm ...
# Running kkp2_2_LJLJp_6p5mm_2mm ...
# Running kkp2_2_LJLJp_6p5mm_2p5mm ...
# Running kkp2_2_LJLJp_6p5mm_3mm ...
# Running kkp2_2_LJLJp_6p5mm_3p5mm ...
# Running kkp2_2_LJLJp_6p5mm_4mm ...
# Running kkp2_2_LJLJp_6p5mm_4p5mm ...
# Running kkp2_2_LJLJp_6p5mm_5mm ...
# Running kkp2_2_LJLJp_6p5mm_5p5mm ...
# Running kkp2_2_LJLJp_6p5mm_6mm ...
# Running kkp2_2_LJLJp_6p5mm_6p5mm ...
# Running kkp2_2_LJLJp_6p5mm_7mm ...
# Running kkp2_2_LJLJp_6p5mm_7p5mm ...
# Running kkp2_2_LJLJp_7mm_1p5mm ...
# Running kkp2_2_LJLJp_7mm_2mm ...
# Running kkp2_2_LJLJp_7mm_2p5mm ...
# Running kkp2_2_LJLJp_7mm_3mm ...
# Running kkp2_2_LJLJp_7mm_3p5mm ...
# Running kkp2_2_LJLJp_7mm_4mm ...
# Running kkp2_2_LJLJp_7mm_4p5mm ...
# Running kkp2_2_LJLJp_7mm_5mm ...
# Running kkp2_2_LJLJp_7mm_5p5mm ...
# Running kkp2_2_LJLJp_7mm_6mm ...
# Running kkp2_2_LJLJp_7mm_6p5mm ...
# Running kkp2_2_LJLJp_7mm_7mm ...
# Running kkp2_2_LJLJp_7mm_7p5mm ...
# Running kkp2_2_LJLJp_7p5mm_1p5mm ...
# Running kkp2_2_LJLJp_7p5mm_2mm ...
# Running kkp2_2_LJLJp_7p5mm_2p5mm ...
# Running kkp2_2_LJLJp_7p5mm_3mm ...
# Running kkp2_2_LJLJp_7p5mm_3p5mm ...
# Running kkp2_2_LJLJp_7p5mm_4mm ...
# Running kkp2_2_LJLJp_7p5mm_4p5mm ...
# Running kkp2_2_LJLJp_7p5mm_5mm ...
# Running kkp2_2_LJLJp_7p5mm_5p5mm ...
# Running kkp2_2_LJLJp_7p5mm_6mm ...
# Running kkp2_2_LJLJp_7p5mm_6p5mm ...
# Running kkp2_2_LJLJp_7p5mm_7mm ...
# Running kkp2_2_LJLJp_7p5mm_7p5mm ...
# overlap_matrix_points(): 1333.56 s

# %%
len(Akkp)

# %%
Akkpcopy = Akkp.copy()

# %% [markdown]
# ## Repair the $A_{kk'}$ and $B_{kk'}$ matrices

# %%
A34 = np.zeros([len(Lj_vals), len(Lj_vals)])
A43 = np.zeros([len(Lj_vals), len(Lj_vals)])

for k in range(Nmodes):
    for kp in range(Nmodes):
        for idx in range(len(Lj_vals)):
            for idx0 in range(len(Lj_vals)):
                if k != kp:
                    key34 = f'kkp{k}_{kp}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                    key43 = f'kkp{kp}_{k}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                    A34[idx, idx0] = Akkpcopy[key34]
                    A43[idx, idx0] = Akkpcopy[key43]
                    Akkp[key34] = (A34[idx, idx0] - A43[idx, idx0]) / 2
                    Akkp[key43] = (A43[idx, idx0] - A34[idx, idx0]) / 2

# %%
Akkpcopy[key43]

# %%
Akkpcopy['kkp3_4_LJLJp_100nH_100nH']

# %%
ww, qq = eprh.solutions.eigenmodes()

# %%
ww
# Out:
# [6.86066621436, 7.46513592816]

# %%
qq
# Out:
# [2.49447976082e-08, 2.49091417578e-05]

# %% [markdown]
# ## Get the eigenmode frequencies and losses
# * Note that frequencies are in GHz here

# %%
wk = {}; Qk = {};
for idx, v in enumerate(eprh.variations):
    # Set the variation
    eprh.set_variation(v)
    lv = eprh._get_lv(v)
    print(f'Eigenmodes for variation {vstrs[idx]} ...')
    ww, qq = eprh.solutions.eigenmodes(lv=lv)
    key = f'{vstrs[idx]}'
    wk.update({key : ww})
    Qk.update({key : [ww1/qq1 for ww1, qq1 in zip(ww, qq)]})
# Out:
# Eigenmodes for variation rcoupler_1p5mm ...
# Eigenmodes for variation rcoupler_2mm ...
# Eigenmodes for variation rcoupler_2p5mm ...
# Eigenmodes for variation rcoupler_3mm ...
# Eigenmodes for variation rcoupler_3p5mm ...
# Eigenmodes for variation rcoupler_4mm ...
# Eigenmodes for variation rcoupler_4p5mm ...
# Eigenmodes for variation rcoupler_5mm ...
# Eigenmodes for variation rcoupler_5p5mm ...
# Eigenmodes for variation rcoupler_6mm ...
# Eigenmodes for variation rcoupler_6p5mm ...
# Eigenmodes for variation rcoupler_7mm ...
# Eigenmodes for variation rcoupler_7p5mm ...

# %%
wk
# Out:
# {'rcoupler_1p5mm': [5.94268705798,
#   5.94339801194,
#   6.21500604574,
#   6.21832648486],
#  'rcoupler_2mm': [5.93715096565, 5.93732339023, 6.21569410069, 6.21750006603],
#  'rcoupler_2p5mm': [5.92174677483,
#   5.92880491048,
#   6.21549436468,
#   6.21669699038],
#  'rcoupler_3mm': [5.8797085543, 5.91013842283, 6.21260512737, 6.2175741503],
#  'rcoupler_3p5mm': [5.9420750869, 5.94211566954, 6.21476494685, 6.2204402612],
#  'rcoupler_4mm': [5.93345664505, 5.93590422133, 6.21631485963, 6.21653487682],
#  'rcoupler_4p5mm': [5.90591809987, 5.92102873977, 6.2162648543, 6.21930957311],
#  'rcoupler_5mm': [5.94130983417, 5.9413823425, 6.21773663894, 6.21845490383],
#  'rcoupler_5p5mm': [5.94184559023, 5.942016003, 6.21484175583, 6.2203597778],
#  'rcoupler_6mm': [5.93623238071, 5.93822166372, 6.21543611959, 6.21790662113],
#  'rcoupler_6p5mm': [5.92991154979,
#   5.93384520002,
#   6.21595700899,
#   6.21680201074],
#  'rcoupler_7mm': [5.91557536608, 5.92642145799, 6.21552038553, 6.21974893156],
#  'rcoupler_7p5mm': [5.8940811634, 5.91628286928, 6.21344150993, 6.21960000166]}

# %%
Qk
# Out:
# {'rcoupler_1p5mm': [1877821.6425143569,
#   1872072.0855832282,
#   46.27724904587548,
#   46.552201568348345],
#  'rcoupler_2mm': [1709907.6060022595,
#   1774874.833504158,
#   46.33699748014971,
#   46.76202297788418],
#  'rcoupler_2p5mm': [499833.3718750389,
#   842547.0772602275,
#   46.42141490345665,
#   46.58241662113054],
#  'rcoupler_3mm': [88760.65656485986,
#   265539.9767018589,
#   46.846685849049095,
#   47.00932458200446],
#  'rcoupler_3p5mm': [1867683.8105982034,
#   1888879.3424938696,
#   46.25830717489279,
#   46.66402889314619],
#  'rcoupler_4mm': [1151098.409621718,
#   1370446.4782818127,
#   46.609263908130536,
#   46.467962371957114],
#  'rcoupler_4p5mm': [212927.28417091168,
#   513956.84236579743,
#   46.70237662330712,
#   46.88202755599294],
#  'rcoupler_5mm': [1895091.5077197086,
#   1894003.7450654944,
#   46.57387969528831,
#   47.07347361349111],
#  'rcoupler_5p5mm': [1806683.679673254,
#   1853598.5654918426,
#   46.2674640902717,
#   46.64771412929301],
#  'rcoupler_6mm': [1441566.3651396094,
#   1568895.4710744543,
#   46.55292578237309,
#   46.819490893798104],
#  'rcoupler_6p5mm': [776905.1818128402,
#   1113409.551606515,
#   46.59751468188927,
#   46.429580873098836],
#  'rcoupler_7mm': [317187.1418182656,
#   682672.9980920578,
#   46.574807661976564,
#   46.81629809032984],
#  'rcoupler_7p5mm': [132233.88349293807,
#   367725.6720493118,
#   46.897373353809435,
#   47.000612120087574]}

# %%
LJ_dict = dict({k : v for k, v in zip(Ljstrs, Lj_vals)})

# %%
LJ_dict
# Out:
# {'1p5mm': 1.5,
#  '2mm': 2.0,
#  '2p5mm': 2.5,
#  '3mm': 3.0,
#  '3p5mm': 3.5,
#  '4mm': 4.0,
#  '4p5mm': 4.5,
#  '5mm': 5.0,
#  '5p5mm': 5.5,
#  '6mm': 6.0,
#  '6p5mm': 6.5,
#  '7mm': 7.0,
#  '7p5mm': 7.5}

# %% [markdown]
# ## Plot the modes vs. inductances

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
dstr = datetime.datetime.today().strftime('%y%m%d')
fsize = 20
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
idx_start = 4
Nmodes = 2
for k in range(Nmodes):
    wppp = np.array([wk[f'{vstr}_{key}'][k] for key in Ljstrs])
    ax.plot(Lj_vals, wppp,
            'o-', label=r'Mode-%d' % (k + 1),
            color=cycle[k%clen])
    #ax.plot(LJs/1e-9, [wp0[idx]/(2*np.pi*fscale)] * len(LJs),
    #        '--', color=cycle[idx%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'Eigenfrequencies [GHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
#ax.set_ylim([5.88, 5.95])
set_axes_fonts(ax, fsize)
leg = set_leg_outside(ax, lsize)
ax.set_xscale('log')
fig.savefig(f'../figs/modes_bare_remesh2_nondegen_{dstr}.pdf', 
            format='pdf', bbox_extra_artists=(leg, ), bbox_inches='tight',
           transparent=True)

# %% [markdown]
# ## Q of the modes

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
fscale = 1e9
fscale2 = 1e6
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
T1trans = 100
for k in range(Nmodes):
    Q = np.array([Qk[f'{vstr}_{key}'][k] for key in Ljstrs])
    wppp = 2*np.pi*np.array([wk[f'{vstr}_{key}'][k] for key in Ljstrs])*fscale
    T1nom = wppp / Q
    T1tot = T1nom * T1trans / (T1nom + T1trans)
    ax.plot(Lj_vals, Q,
            'o-', label=r'Mode-%d' % (k + 1),
            color=cycle[k%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$Q$', fontsize=fsize)
# ax.plot(LJs/1e-9, np.ones(LJs.size) * dw/(fscale2), 'k--')
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
#ax.set_ylim([1e-2, 350])
#ax.set_xlim([0.5, 2.2])
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/T1_modes_coupled_remesh2_eigenmode_{dstr}.pdf',
            format='pdf')

# %% [markdown]
# # Plot the eigenmode $T_1$ values

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
fscale = 1e9
fscale2 = 1e6
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
T1trans = 100
for k in range(Nmodes):
    Q = np.array([Qk[f'{vstr}_{key}'][k] for key in Ljstrs])
    wppp = 2*np.pi*np.array([wk[f'{vstr}_{key}'][k] for key in Ljstrs])*fscale
    T1nom = 1e6 * Q / wppp
    T1tot = T1nom * T1trans / (T1nom + T1trans)
    ax.plot(Lj_vals, T1nom,
            'o-', label=r'Mode-%d' % (k + 1),
            color=cycle[k%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$T_1$ [$\mu$s]', fontsize=fsize)
# ax.plot(LJs/1e-9, np.ones(LJs.size) * dw/(fscale2), 'k--')
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
#ax.set_ylim([1e-2, 350])
#ax.set_xlim([0.5, 2.2])
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/T1_modes_coupled_remesh2_eigenmode_{dstr}.pdf',
            format='pdf')

# %% [markdown]
# ## Compute the $g_{kk'}$ and $\widetilde{\omega}_{k}$ from $A_{kk'}$

# %%
"""
Compute the couplings from Akk, wk values
"""
# Iterate over all modes and inductances
gkk = {}
idx_start = 2; idx_stop = -1
Nmodes = 2
for k in range(Nmodes):
    for kp in range(Nmodes):
        for idx, LJ in enumerate(Lj_vals):
            
            # Outside sqrt(wk wk') factor
            wkey = f'{vstr}_{Ljstrs[idx]}'
            wkwkp = np.sqrt(wk[wkey][k] * wk[wkey][kp])
            
            for idx0, LJ0 in enumerate(Lj_vals):
                
                # Key to index gkk'
                gkey = f'kkp{k+1}_{kp+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                Akkpsum = 0
                print(f'Computing g at {gkey}, wkwkp: {wkwkp:.2e} ...')
                for kpp in range(Nmodes):
                    key = f'kkp{kpp+1}_{k+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                    keyp = f'kkp{kpp+1}_{kp+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                    Akppk = Akkp[key]
                    Akppkp = Akkp[keyp]
                    Akkpsum += Akppk * Akppkp

                # Store the results
                if (k != kp):
                    gkk.update({gkey : wkwkp * Akkpsum})
# Out:
# Computing g at kkp1_1_LJLJp_1p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_1p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_2p5mm_7p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_1p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_2mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_2p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_3mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_3p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_4mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_4p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_5p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_6mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_6p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_7mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3mm_7p5mm, wkwkp: 5.88e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_3p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_4p5mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_5p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_6p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7mm_7p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_1p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_2mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_2p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_3mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_3p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_4mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_4p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_5p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_6mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_6p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_7mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_1_LJLJp_7p5mm_7p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_1p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_2p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_1p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_2mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_2p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_3mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_3p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_4mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_4p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_5p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_6mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_6p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_7mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3mm_7p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_3p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_4p5mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_5p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_6p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7mm_7p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp1_2_LJLJp_7p5mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_1p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_2p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_1p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_2mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_2p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_3mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_3p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_4mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_4p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_5p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_6mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_6p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_7mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3mm_7p5mm, wkwkp: 5.89e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_3p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_4p5mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_5p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_6p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7mm_7p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_1_LJLJp_7p5mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_1p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_2p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_1p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_2mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_2p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_3mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_3p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_4mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_4p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_5p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_6mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_6p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_7mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3mm_7p5mm, wkwkp: 5.91e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_3p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_4p5mm_7p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_5p5mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_1p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_2mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_2p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_3mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_3p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_4mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_4p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_5p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_6mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_6p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_7mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6mm_7p5mm, wkwkp: 5.94e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_6p5mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_1p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_2mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_2p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_3mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_3p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_4mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_4p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_5p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_6mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_6p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_7mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7mm_7p5mm, wkwkp: 5.93e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_1p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_2mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_2p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_3mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_3p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_4mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_4p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_5p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_6mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_6p5mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_7mm, wkwkp: 5.92e+00 ...
# Computing g at kkp2_2_LJLJp_7p5mm_7p5mm, wkwkp: 5.92e+00 ...

# %%
'kkp1_1_LJLJp_0p10000000000000001nH_0p10000000000000001nH' in gkk.keys()
# Out:
# False

# %% [markdown]
# ### Collect the results as a matrix

# %%
gkk_matrix = np.zeros([Nmodes, Nmodes, len(Lj_vals), len(Lj_vals)])
for k in range(Nmodes):
    for kp in range(Nmodes):
        for idx, LJ in enumerate(Lj_vals):
            for idx0, LJ0 in enumerate(Lj_vals):
                if k != kp:
                    gkey = f'kkp{k+1}_{kp+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                    gkk_matrix[k, kp, idx, idx0] = gkk[gkey]

# %%
gkk_matrix
# Out:
# array([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00]],
#
#         [[-2.12907914e-06, -3.50262295e-02, -3.42872140e-02,
#            1.60826532e-02,  1.32933760e-02, -2.74152279e-02,
#            2.09526331e-02,  2.80092217e-03,  1.33407970e-02,
#           -8.11804299e-03, -1.73709592e-03,  8.51040002e-03,
#            9.14835919e-03],
#          [ 3.48689905e-02, -1.84571413e-04, -2.94620330e-02,
#            1.44238982e-02,  1.85945070e-02, -2.25937094e-02,
#            1.55446739e-02, -3.04519180e-03,  8.98027366e-03,
#           -3.61434504e-03, -9.74560443e-04,  2.94559764e-03,
#            9.29533158e-03],
#          [ 3.38305169e-02, -2.94124828e-02, -1.98958303e-03,
#            1.90241818e-02,  2.42176656e-02, -3.29363351e-02,
#            1.91694262e-02, -8.51374736e-04,  8.90292380e-03,
#           -6.77097987e-03, -3.90556133e-03,  5.63547493e-03,
#            8.75657085e-03],
#          [ 3.38335999e-02, -2.33868740e-02, -3.55070865e-02,
#           -1.43919132e-03,  1.16604695e-02, -2.86882086e-02,
#            1.46745311e-02, -2.73814280e-03,  1.08886095e-02,
#           -4.64798645e-04, -4.07322391e-03,  7.69304726e-04,
#            8.02170325e-03],
#          [ 3.15262753e-02, -3.79216489e-02, -4.01089737e-02,
#            1.01684958e-02, -1.39215383e-02, -3.05918989e-02,
#            2.38092777e-02, -5.14034162e-03,  1.54911713e-02,
#           -5.73060992e-03,  4.43128310e-04,  5.20084577e-03,
#            1.49579698e-02],
#          [ 2.94745836e-02, -2.49179469e-02, -3.59244148e-02,
#            1.83339806e-02,  1.47285819e-02, -1.13503903e-03,
#            1.53450679e-02, -2.50486397e-03,  1.33751939e-02,
#           -3.22774919e-03,  1.21718284e-03,  4.71965623e-03,
#            3.41790197e-03],
#          [ 3.48232614e-02, -3.45000269e-02, -4.03531788e-02,
#            1.60172977e-02,  1.95219346e-02, -3.24979032e-02,
#            3.15537167e-04, -5.66397360e-03,  1.12624071e-02,
#           -1.78587084e-03, -1.06565133e-03,  5.62237365e-03,
#            1.08292732e-02],
#          [ 2.70306308e-02, -2.63889152e-02, -3.60439356e-02,
#            1.70943030e-02,  1.47156177e-02, -3.17822707e-02,
#            1.81977235e-02,  4.63889116e-03,  8.77038212e-03,
#           -4.53935310e-03,  2.97171573e-03,  4.52776242e-03,
#            8.13279376e-03],
#          [ 3.60879585e-02, -3.11802888e-02, -3.07288198e-02,
#            1.69711306e-02,  2.46110157e-02, -2.94472343e-02,
#            2.10536192e-02, -5.71660450e-03, -1.66155831e-02,
#           -5.24968607e-03,  5.43732201e-03,  2.54189146e-03,
#            6.55209141e-03],
#          [ 3.21403957e-02, -2.93766324e-02, -3.00622227e-02,
#            1.74065010e-02,  2.84292110e-02, -2.76468652e-02,
#            1.66206109e-02, -5.12526583e-03,  1.01934298e-02,
#            1.24432715e-02, -5.69550808e-04,  5.10236074e-03,
#            2.40007747e-03],
#          [ 3.01169723e-02, -3.20690614e-02, -3.42618315e-02,
#            1.10347550e-02,  1.18930201e-02, -2.46877796e-02,
#            1.73370830e-02, -2.23885728e-03,  4.08711606e-03,
#           -1.64211499e-03, -1.45565929e-02,  9.15554524e-04,
#            1.06330086e-02],
#          [ 3.35290029e-02, -3.09786346e-02, -2.60132338e-02,
#            1.85764700e-02,  1.73419953e-02, -1.96445740e-02,
#            1.26469406e-02,  1.13023709e-03,  5.39295949e-03,
#           -3.11254779e-03,  6.14363837e-04,  6.34958964e-03,
#            4.51791668e-03],
#          [ 1.97177455e-02, -1.95187042e-02, -2.29183825e-02,
#            6.25622057e-03,  1.36720964e-02, -1.94417545e-02,
#            1.09872492e-02, -1.39898316e-03,  9.63149488e-03,
#           -1.15308800e-04,  1.34659730e-03, -7.14778774e-04,
#            2.41564481e-03]]],
#
#
#        [[[-2.12907914e-06, -3.50262295e-02, -3.42872140e-02,
#            1.60826532e-02,  1.32933760e-02, -2.74152279e-02,
#            2.09526331e-02,  2.80092217e-03,  1.33407970e-02,
#           -8.11804299e-03, -1.73709592e-03,  8.51040002e-03,
#            9.14835919e-03],
#          [ 3.48689905e-02, -1.84571413e-04, -2.94620330e-02,
#            1.44238982e-02,  1.85945070e-02, -2.25937094e-02,
#            1.55446739e-02, -3.04519180e-03,  8.98027366e-03,
#           -3.61434504e-03, -9.74560443e-04,  2.94559764e-03,
#            9.29533158e-03],
#          [ 3.38305169e-02, -2.94124828e-02, -1.98958303e-03,
#            1.90241818e-02,  2.42176656e-02, -3.29363351e-02,
#            1.91694262e-02, -8.51374736e-04,  8.90292380e-03,
#           -6.77097987e-03, -3.90556133e-03,  5.63547493e-03,
#            8.75657085e-03],
#          [ 3.38335999e-02, -2.33868740e-02, -3.55070865e-02,
#           -1.43919132e-03,  1.16604695e-02, -2.86882086e-02,
#            1.46745311e-02, -2.73814280e-03,  1.08886095e-02,
#           -4.64798645e-04, -4.07322391e-03,  7.69304726e-04,
#            8.02170325e-03],
#          [ 3.15262753e-02, -3.79216489e-02, -4.01089737e-02,
#            1.01684958e-02, -1.39215383e-02, -3.05918989e-02,
#            2.38092777e-02, -5.14034162e-03,  1.54911713e-02,
#           -5.73060992e-03,  4.43128310e-04,  5.20084577e-03,
#            1.49579698e-02],
#          [ 2.94745836e-02, -2.49179469e-02, -3.59244148e-02,
#            1.83339806e-02,  1.47285819e-02, -1.13503903e-03,
#            1.53450679e-02, -2.50486397e-03,  1.33751939e-02,
#           -3.22774919e-03,  1.21718284e-03,  4.71965623e-03,
#            3.41790197e-03],
#          [ 3.48232614e-02, -3.45000269e-02, -4.03531788e-02,
#            1.60172977e-02,  1.95219346e-02, -3.24979032e-02,
#            3.15537167e-04, -5.66397360e-03,  1.12624071e-02,
#           -1.78587084e-03, -1.06565133e-03,  5.62237365e-03,
#            1.08292732e-02],
#          [ 2.70306308e-02, -2.63889152e-02, -3.60439356e-02,
#            1.70943030e-02,  1.47156177e-02, -3.17822707e-02,
#            1.81977235e-02,  4.63889116e-03,  8.77038212e-03,
#           -4.53935310e-03,  2.97171573e-03,  4.52776242e-03,
#            8.13279376e-03],
#          [ 3.60879585e-02, -3.11802888e-02, -3.07288198e-02,
#            1.69711306e-02,  2.46110157e-02, -2.94472343e-02,
#            2.10536192e-02, -5.71660450e-03, -1.66155831e-02,
#           -5.24968607e-03,  5.43732201e-03,  2.54189146e-03,
#            6.55209141e-03],
#          [ 3.21403957e-02, -2.93766324e-02, -3.00622227e-02,
#            1.74065010e-02,  2.84292110e-02, -2.76468652e-02,
#            1.66206109e-02, -5.12526583e-03,  1.01934298e-02,
#            1.24432715e-02, -5.69550808e-04,  5.10236074e-03,
#            2.40007747e-03],
#          [ 3.01169723e-02, -3.20690614e-02, -3.42618315e-02,
#            1.10347550e-02,  1.18930201e-02, -2.46877796e-02,
#            1.73370830e-02, -2.23885728e-03,  4.08711606e-03,
#           -1.64211499e-03, -1.45565929e-02,  9.15554524e-04,
#            1.06330086e-02],
#          [ 3.35290029e-02, -3.09786346e-02, -2.60132338e-02,
#            1.85764700e-02,  1.73419953e-02, -1.96445740e-02,
#            1.26469406e-02,  1.13023709e-03,  5.39295949e-03,
#           -3.11254779e-03,  6.14363837e-04,  6.34958964e-03,
#            4.51791668e-03],
#          [ 1.97177455e-02, -1.95187042e-02, -2.29183825e-02,
#            6.25622057e-03,  1.36720964e-02, -1.94417545e-02,
#            1.09872492e-02, -1.39898316e-03,  9.63149488e-03,
#           -1.15308800e-04,  1.34659730e-03, -7.14778774e-04,
#            2.41564481e-03]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            0.00000000e+00]]]])

# %%
"""
Compute the couplings from Akk, wk values
"""
# Iterate over all modes and inductances
wkt = {}
idx_start = 2; idx_stop = -1
Nmodes = 2
for k in range(Nmodes):
    for idx, LJ in enumerate(Lj_vals):

        # Outside wk factor
        wkey = f'{vstr}_{Ljstrs[idx]}'
        wkp = wk[wkey][k]

        for idx0, LJ0 in enumerate(Lj_vals):

            # Key to index gkk'
            wwkey = f'kkp{k+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
            Akkpsum = 0
            # print(f'Computing wkp at {wwkey}, wkwkp: {wkp:.2e} ...')
            for kpp in range(Nmodes):
                key = f'kkp{kpp+1}_{k+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
                Akppk = Akkp[key]
                Akkpsum += Akppk**2

            # Store the results
            wkt.update({wwkey : wkp * Akkpsum})

# %%
len(wkt)

# %%
wkt_matrix = np.zeros([Nmodes, len(Lj_vals), len(Lj_vals)])

# %% [markdown]
# ## Compute the $\widetilde{\omega}_k(L_J, L_{J_0})$ matrix

# %%
for k in range(Nmodes):
    for idx, LJ in enumerate(Lj_vals):
        for idx0, LJ0 in enumerate(Lj_vals):
            wwkkey = f'kkp{k+1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'
            wkt_matrix[k, idx, idx0] = wkt[wwkkey]

# %% [markdown]
# ### Sort the frequencies for each $(L_J, L_{J_0})$ pair

# %%
wkt_matrix_sorted = np.sort(wkt_matrix, axis=0)
wkt_sort_idx = np.argsort(wkt_matrix, axis=0)

gkk_sort_idx = wkt_sort_idx[np.newaxis, :, :, :]

# %%
gkk_sort_idx.shape

# %%
gkk_matrix_sorted = gkk_matrix[gkk_sort_idx]

# %%
gkk_matrix_sorted.shape

# %% [markdown]
# ## Plot the sorted $\widetilde{\omega}_k(L_J, L_{J_0})$ values

# %%
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)

for idx_fixed in range(len(Lj_vals)):
    print(f'LJ0-{idx_fixed} ...')
    fig, ax = plt.subplots(1, 1, tight_layout=True)
    for k in range(Nmodes):
        ax.plot(Lj_vals, wkt_matrix_sorted[k, :, idx_fixed],
            'o-', label=r'Mode-%d' % (k + 1),
            color=cycle[k%clen])
    ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
    ax.set_ylabel(r'$\widetilde{\omega}/2\pi$ [GHz]', fontsize=fsize)
    set_xaxis_rot(ax, 45)
    set_axes_fonts(ax, fsize)
    leg = set_leg_outside(ax, lsize)
    ax.set_xscale('log')
    fig.savefig(f'../figs/modes_eigenmode_remesh2_modified_LJ0_{Ljstrs[idx_fixed]}_{dstr}.pdf', 
                format='pdf', bbox_extra_artists=(leg, ), bbox_inches='tight',
               transparent=True)
# Out:
# LJ0-0 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 8
#       6 fig, ax = plt.subplots(1, 1, tight_layout=True)
#       7 for k in range(Nmodes):
# ----> 8     ax.plot(Lj_vals, wkt_matrix_sorted[k, :, idx_fixed],
#       9         'o-', label=r'Mode-%d' % (k + 1),
#      10         color=cycle[k%clen])
#      11 ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
#      12 ax.set_ylabel(r'$\widetilde{\omega}/2\pi$ [GHz]', fontsize=fsize)
#
# NameError: name 'wkt_matrix_sorted' is not defined

# %%
'kkp1_LJLJp_0p10000000000000001nH_56p234132519034901nH' in wkt.keys()

# %% [markdown]
# ## Plot $g_{k_1,k_2}$ vs. $L_J, L_{J_0}$

# %%
gmax = np.max(np.array(list(gkk.values()))) * 1e3
gmin = np.min(np.array(list(gkk.values()))) * 1e3

# %%
gmax
# Out:
# 36.08795852310704

# %%
gmin
# Out:
# -40.35317877332784

# %%
#plot_2d_cmap(ydata/ymax,
#    zdata/zmax,
for k1 in [1,2]:
    for k2 in [1, 2]:
        if k1 != k2:
            gkk12 = np.array([[gkk[f'kkp{k1}_{k2}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'] \
                               for idx in range(len(Lj_vals))] \
                               for idx0 in range(len(Lj_vals))])*1e3
            plot_2d_cmap(# LJs/1e-9,
                #Lj_vals[idx_start:idx_stop],
                #Lj_vals[idx_start:idx_stop],
                Lj_vals,
                Lj_vals,
                np.abs(gkk12),
                # gkk_matrix_sorted[k1, k2, :, :],
                f'../figs/g{k1}_{k2}_remesh2_sorted_vs_rr0_{dd}.pdf',
                xstr=r'$r_{0}$ [mm]',
                ystr=r'$r$ [mm]',
                tstr='',
                xyscales={'x' : 'linear', 'y' : 'linear'},
                cbar_str=r'$g_{%d%d}$ [MHz]' % (k1, k2),
                interp_zeros=False,
                interp_std_dev=3,
                image_rot_angle=0,
                norm_type='ref',
                zref=[0, gmax],
                fsize=40,
                tsize=46)
# Out:
# Writing ../figs/g1_2_remesh2_sorted_vs_rr0_230719.pdf ...
# Writing ../figs/g2_1_remesh2_sorted_vs_rr0_230719.pdf ...

# %% [markdown]
# ## Plot $B_{k_1,k_2}(L_{J}, L_{J_0})$ vs. $L_J, L_{J_0}$

# %%
# Amax = np.max(list(Akkp.values()))
# Amin = np.min(list(Akkp.values()))

Bmax = np.max(np.abs(list(Bkkp.values())))
Bmin = np.min(np.abs(list(Bkkp.values())))

# %%
Ljstrs
# Out:
# array(['1p5mm', '2mm', '2p5mm', '3mm', '3p5mm', '4mm', '4p5mm', '5mm',
#        '5p5mm', '6mm', '6p5mm', '7mm', '7p5mm'], dtype='<U5')

# %%
Bmin, Bmax
# Out:
# (1.212105516343721e-07, 1.0000000000001685)

# %%
Amax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 Amax
#
# NameError: name 'Amax' is not defined

# %%
Amin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 Amin
#
# NameError: name 'Amin' is not defined

# %%
for k1 in range(1, Nmodes+1):
    for k2 in range(1, Nmodes+1):

        Akk12 = np.array([[Bkkp[f'kkp{k1}_{k2}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'] \
                           for idx in range(len(Lj_vals))] \
                           for idx0 in range(len(Lj_vals))])
        
        
        plot_2d_cmap(
            Lj_vals,
            Lj_vals,
            np.abs(Akk12),
            f'../figs/B{k1}_{k2}_two_post_coupler_only_vs_LJLJ0_{dd}.pdf',
            xstr=r'$L_{J_0}$ [nH]',
            ystr=r'$L_{J}$ [nH]',
            tstr='',
            cmap=cm.viridis,
            xyscales={'x' : 'linear', 'y' : 'linear'},
            cbar_str=r'$|B_{%d%d}|$' % (k1, k2),
            interp_zeros=False,
            interp_std_dev=3,
            image_rot_angle=0,
            norm_type='log',
            zref=[Bmin, Bmax],
            fsize=40,
            tsize=46)
# Out:
# Writing ../figs/B1_1_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/B1_2_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/B2_1_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/B2_2_two_post_coupler_only_vs_LJLJ0_230719.pdf ...

# %%
Amax = np.max(np.abs(list(Akkp.values())))
Amin = np.min(np.abs(list(Akkp.values())))
for k1 in range(1, Nmodes+1):
    for k2 in range(1, Nmodes+1):

        Akk12 = np.array([[Akkp[f'kkp{k1}_{k2}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'] \
                           for idx in range(len(Lj_vals))] \
                           for idx0 in range(len(Lj_vals))])
        
        
        plot_2d_cmap(
            Lj_vals,
            Lj_vals,
            np.abs(Akk12),
            f'../figs/A{k1}_{k2}_two_post_coupler_only_vs_LJLJ0_{dd}.pdf',
            xstr=r'$L_{J_0}$ [nH]',
            ystr=r'$L_{J}$ [nH]',
            tstr='',
            cmap=cm.viridis,
            xyscales={'x' : 'linear', 'y' : 'linear'},
            cbar_str=r'$|A_{%d%d}|$' % (k1, k2),
            interp_zeros=False,
            interp_std_dev=3,
            image_rot_angle=0,
            norm_type='log',
            zref=[Amin, Amax],
            fsize=40,
            tsize=46)
# Out:
# Writing ../figs/A1_1_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/A1_2_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/A2_1_two_post_coupler_only_vs_LJLJ0_230719.pdf ...
# Writing ../figs/A2_2_two_post_coupler_only_vs_LJLJ0_230719.pdf ...

# %%
Imax = np.max(np.abs(Ikkp))
Imin = np.min(np.abs(Ikkp))
for k1 in range(Nmodes):
    for k2 in range(Nmodes):

        Akk12 = Ikkp[:, :, k1, k2]
        
        plot_2d_cmap(
            Lj_vals,
            Lj_vals,
            np.abs(Akk12),
            f'../figs/I{k1}_{k2}_two_post_coupler_only_vs_LJLJ0_{dd}.pdf',
            xstr=r'$L_{J_0}$ [nH]',
            ystr=r'$L_{J}$ [nH]',
            tstr='',
            cmap=cm.viridis,
            xyscales={'x' : 'log', 'y' : 'log'},
            cbar_str=r'$|I_{%d}I_{%d}|$' % (k1+1, k2+1),
            interp_zeros=False,
            interp_std_dev=3,
            image_rot_angle=0,
            norm_type='log',
            zref=[Imin, Imax],
            fsize=40,
            tsize=46)
# Out:
# INFO 12:30PM [__del__]: Disconnected from Ansys HFSS
# Warning! 9 COM references still alive
# HFSS will likely refuse to shut down
# Writing ../figs/I0_0_two_post_coupler_only_vs_LJLJ0_230613.pdf ...
# Writing ../figs/I0_1_two_post_coupler_only_vs_LJLJ0_230613.pdf ...
# Writing ../figs/I1_0_two_post_coupler_only_vs_LJLJ0_230613.pdf ...
# Writing ../figs/I1_1_two_post_coupler_only_vs_LJLJ0_230613.pdf ...

# %%
wmax = np.max(np.array(list(wkt.values())))
wmin = np.min(np.array(list(wkt.values())))

wmax

wmin

#plot_2d_cmap(ydata/ymax,
#    zdata/zmax,
# for k1 in [1,2,3,4]:
for k1 in range(Nmodes):
        # wkk12 = np.array([[wkt[f'kkp{k1}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'] \
        #                   for idx in range(len(Lj_vals))] \
        #                   for idx0 in range(len(Lj_vals))])
        plot_2d_cmap(# LJs/1e-9,
            Lj_vals,
            Lj_vals,
            #wkk12,
            wkt_matrix_sorted[k1, :, :],
            # f'../figs/w_{k1}_vs_LJLJ0_{dd}.pdf',
            f'../figs/w_{k1+1}_remesh2_sorted_vs_LJLJ0_{dd}.pdf',
            xstr=r'$L_{J_0}$ [nH]',
            ystr=r'$L_{J}$ [nH]',
            tstr='',
            xyscales={'x' : 'log', 'y' : 'log'},
            cbar_str=r'$\omega_{%d}$ [GHz]' % (k1),
            interp_zeros=False,
            interp_std_dev=3,
            image_rot_angle=0,
            norm_type='ref',
            zref=[wmin, wmax],
            fsize=40,
            tsize=46)

## Compute the derivatives to estimate the driven coupling strengths

dLJ = 1 # 10 nH as a possible driving point
for k1 in [1,2,3,4]:
    for k2 in [1, 2, 3, 4]:
        if k1 != k2:
            gkk12 = np.array([[gkk[f'kkp{k1}_{k2}_LJLJp_{Ljstrs[idx]}_{Ljstrs[idx0]}'] \
                               for idx in range(len(Lj_vals))] \
                               for idx0 in range(len(Lj_vals))])
            gkk12_grad = np.array([np.gradient(gkk12[:, j], Lj_vals) for j in range(len(Lj_vals))])
            epskk = gkk12_grad * dLJ * 1e3
            # Write the results to file
            plot_2d_cmap(# LJs/1e-9,
            Lj_vals,
            Lj_vals,
            epskk,
            f'../figs/eps_{k1}_{k2}_remesh2_vs_LJLJ0_{dd}.pdf',
            xstr=r'$L_{J_0}$ [nH]',
            ystr=r'$L_{J}$ [nH]',
            tstr='',
            xyscales={'x' : 'log', 'y' : 'log'},
            cbar_str=r'$\epsilon_{g_{%d %d}}$ [MHz]' % (k1, k2),
            interp_zeros=False,
            interp_std_dev=3,
            image_rot_angle=0,
            norm_type='ref',
            zref=[gmin, gmax],
            fsize=40,
            tsize=46)

## Plot $g_{12}$ for a fixed $L_{J_0}$

LJidx0 = 0
dLJ = 10 # 10 nH as a possible driving point
k1 = 1; k2 = 2

fig, ax = plt.subplots(1, 1, tight_layout=True)
dstr = datetime.datetime.today().strftime('%y%m%d')
fsize = 20
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
idx_start = 4
cidx = 0
for idx0 in [8, 10, 12, 14]:
    gkk12 = np.array([gkk[f'kkp{k1}_{k2}_LJLJp_{Ljstrs[idx]}_{Ljstrs[LJidx0]}'] \
                               for idx in range(len(Lj_vals))])
    gkk12_grad = np.gradient(gkk12, Lj_vals)
    epskk = gkk12_grad * Lj_vals[idx0] * 1e3
    ax.plot(Lj_vals, epskk / 2,
        'o-', color=cycle[cidx%clen],
           label=r'$\delta L_{J}$ = %.2f nH' % Lj_vals[idx0])
    cidx += 1

ax.axhline(y=0, color='k', ls='--')
ax.set_title(r'$L_{J_0} = %.2f$ nH' % Lj_vals[LJidx0],
             fontsize=fsize)
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$\frac{1}{2}\epsilon_{g_{%d%d}}$ [MHz]' % (k1, k2), fontsize=fsize)
set_xaxis_rot(ax, 45)
#ax.set_ylim([-0.5, 1.5])
set_axes_fonts(ax, fsize)
ax.set_xscale('log')
leg = set_leg_outside(ax, lsize)
fig.savefig(f'../figs/epsg_{k1}{k2}_bbq_1_10_100nH_remesh2_{dstr}.pdf', 
            bbox_extra_artists=(leg, ), bbox_inches='tight',
            format='pdf', transparent=True)

# %% [markdown]
# ### Get the interpolating sweep data to estimate resonance positions

# %%
fsweep_interp = HFSS.HfssFrequencySweep(DM_setup, 'Interpolating_0')

report_im = fsweep_interp.create_report('Interpolating_0', expr='im(Y(1,1))')
yim = report_im.get_arrays()

# Identify the zero crossings as resonances
zero_xing_idxs = np.where(np.diff(np.sign(yim[1,:])) > 0)[0]
resonances = yim[0,zero_xing_idxs]

print(f'resonances: {resonances}')
# Out:
# resonances: [12.4936]

# %%
# Plot the results, save the figure(s)
fsize = 20
fscale = 1e9
#wp, Lp, Cp, Qp, fcpy, ycpy, yp, pl, pc, gD, chippp = \
#get_wp_Cp_Lp(fdata, ydata, LJ0=None, CJ0=None, fscale=1e9, use_Zq=False)

fig, ax = plt.subplots(1, 1, tight_layout=True)
ax.plot(yim[0,:], yim[1,:], '-', label='Zero Crossings')
ax.plot(resonances,
        yim[1,zero_xing_idxs],
        'o', label='Zero Crossings')
# ax.set_xlim([5.8, 6.1])
ax.set_ylim([-0.1, 0.1])
ax.axhline(y=0, ls='--', color='k')
# ax.plot(fdata, ydata.imag)
set_xaxis_rot(ax, 45)
ax.set_ylabel(r'Im $Y(\omega)$', fontsize=fsize)
ax.set_xlabel(r'Frequency [GHz]', fontsize=fsize)
set_axes_fonts(ax, fsize)

# %%
resonances
# Out:
# array([12.4936])

# %% [markdown]
# #### Bypass the interpolating sweep if frequencies already known

# %%
# resonances = np.array([ 6.0928,  6.1684,  6.1692,  6.2692,  7.3356,  7.3816,  7.4712,
#        7.506 ,  9.3064,  9.3292,  9.588 ,  9.6076, 11.5804, 11.6684,
#       11.7568, 11.95  , 12.604 , 12.6944, 12.8012, 12.8048])
# resonances = np.array([ 6.0928,  6.1692,  6.2692,  7.3816,  7.4712,
#        7.506 , 9.3292,  9.588 ,  9.6076, 11.5804, 
#       11.7568, 11.95, 12.6944, 12.8048])

# Use half the minimum spacing between resonances as a the bandwidth
Nmodes = 10
# resonances = resonances[0:Nmodes]
df = 0.8 * np.diff(np.hstack((f1, resonances, f2))).min()

# %%
df
# Out:
# 0.4051199999999995

# %% [markdown]
# ### Discrete sweep to resolve resonances

# %%
if solution_type == 'driven_modal':
    # Setup the driven-modal simulation
    if not DM_setup:
        DM_setup = EM_design.create_dm_setup()
        
    # Discrete count
    count2 = 201
    count1 = 51
    
    ## This should resolve the issue of overlapping sweeps
    ## We advance the left boundary by a small amount away
    ## from the previous right boundary
    dff = df / count
    
    # Identify resonances from interpolating sweep manually (for now)
    ## Start at the first sweep frequency
    f1r = f1
    
    # df  = 0.01 # 10 MHz window
    # Iteratve over all resonances and shift the discrete
    # sweep window from f1r to f2r
    rlen = len(resonances)
    fdata = np.array([])
    ydata = np.array([])
    for ridx, fr in enumerate(resonances):
        try:
            # First sweep from f1 to fr_j - df / 2
            f2r = fr - df / 2
            print(f'[{2*ridx} / {2*rlen}] Discrete sweep from {f1r} to {f2r} GHz ...')
            DM_setup.insert_sweep(f1r, f2r,
                                  count=count1,
                                  save_fields=True,
                                  name=f'Discrete_Sweep_{2*ridx}',
                                  type='Discrete')
            DM_setup.solve()

            # Get data from first sweep
            print(f'Creating even reports ...')
            fsweep = HFSS.HfssFrequencySweep(DM_setup, f'Discrete_Sweep_{2*ridx}')
            # report_re = fsweep.create_report(f'Discrete_Sweep_{2*ridx}', expr='re(Y(LumpPort,LumpPort))')
            # report_im = fsweep.create_report(f'Discrete_Sweep_{2*ridx}', expr='im(Y(LumpPort,LumpPort))')
            report_re = fsweep.create_report(f'Discrete_Sweep_{2*ridx}', expr='re(Y(1, 1))')
            report_im = fsweep.create_report(f'Discrete_Sweep_{2*ridx}', expr='im(Y(1, 1))')
            yre = report_re.get_arrays()
            yim = report_im.get_arrays()
            fdata = np.hstack((fdata, yre[0,:]))
            ydata = np.hstack((ydata, yre[1,:]+1j*yim[1,:]))    

            # Backup data to file
            print(f'Backing up even reports ...')
            with open(f'../data/ydata_{dd}_sweep_{2*ridx}.csv', 'w') as fid:
                fid.write('\n'.join([f'{ff}, {yi}, {yr}'\
                                     for ff, yi, yr in zip(yre[0,:], yre[1,:], yim[1,:])]))

            # Second sweep from fr_j - df / 2 to fr_j + df / 2
            f1r = f2r + dff
            f2r = fr + df / 2
            print(f'[{2*ridx+1} / {2*rlen}] Discrete sweep from {f1r} to {f2r} GHz ...')
            DM_setup.insert_sweep(f1r, f2r,
                                  count=count2,
                                  save_fields=True,
                                  name=f'Discrete_Sweep_{2*ridx+1}',
                                  type='Discrete')
            DM_setup.solve()

            # Get data from first sweep
            print(f'Creating odd reports ...')
            fsweep = HFSS.HfssFrequencySweep(DM_setup, f'Discrete_Sweep_{2*ridx+1}')
            # report_re = fsweep.create_report(f'Discrete_Sweep_{2*ridx+1}', expr='re(Y(LumpPort,LumpPort))')
            # report_im = fsweep.create_report(f'Discrete_Sweep_{2*ridx+1}', expr='im(Y(LumpPort,LumpPort))')
            report_re = fsweep.create_report(f'Discrete_Sweep_{2*ridx+1}', expr='re(Y(1, 1))')
            report_im = fsweep.create_report(f'Discrete_Sweep_{2*ridx+1}', expr='im(Y(1, 1))')
            yre = report_re.get_arrays()
            yim = report_im.get_arrays()
            fdata = np.hstack((fdata, yre[0,:]))
            ydata = np.hstack((ydata, yre[1,:]+1j*yim[1,:]))    

            # Backup data to file
            print(f'Backing up even reports ...')
            with open(f'../data/ydata_{dd}_sweep_{2*ridx+1}.csv', 'w') as fid:
                fid.write('\n'.join([f'{ff}, {yi}, {yr}'\
                                     for ff, yi, yr in zip(yre[0,:], yre[1,:], yim[1,:])]))

            # Next sweep from fr_j + df / 2 to fr_j+1 - df / 2
            f1r = f2r + dff
    
        except Exception as e:
            print(f'Exception on run {ridx}:\n{e}')
            continue
    
    # Last frequency band from fr_j + df / 2 to f2
    f2r = f2
    print(f'[{2*rlen} / {2*rlen}] Discrete sweep from {f1r} to {f2r} GHz ...')
    DM_setup.insert_sweep(f1r, f2r,
                          count=count1,
                          save_fields=True,
                          name=f'Discrete_Sweep_{2*rlen}',
                          type='Discrete')
    DM_setup.solve()
    
    # Get data from first sweep
    print(f'Creating last report ...')
    fsweep = HFSS.HfssFrequencySweep(DM_setup, f'Discrete_Sweep_{2*rlen}')
    # report_re = fsweep.create_report(f'Discrete_Sweep_{2*rlen}', expr='re(Y(LumpPort,LumpPort))')
    # report_im = fsweep.create_report(f'Discrete_Sweep_{2*rlen}', expr='im(Y(LumpPort,LumpPort))')
    report_re = fsweep.create_report(f'Discrete_Sweep_{2*rlen}', expr='re(Y(1, 1))')
    report_im = fsweep.create_report(f'Discrete_Sweep_{2*rlen}', expr='im(Y(1, 1))')
    yre = report_re.get_arrays()
    yim = report_im.get_arrays()
    fdata = np.hstack((fdata, yre[0,:]))
    ydata = np.hstack((ydata, yre[1,:]+1j*yim[1,:]))

    # Backup data to file
    print(f'Backing up even reports ...')
    with open(f'../data/ydata_{dd}_sweep_{2*rlen}.csv', 'w') as fid:
        fid.write('\n'.join([f'{ff}, {yi}, {yr}'\
                             for ff, yi, yr in zip(yre[0,:], yre[1,:], yim[1,:])]))
# Out:
# [0 / 2] Discrete sweep from 5 to 12.29104 GHz ...
# Creating even reports ...
# Backing up even reports ...
# [1 / 2] Discrete sweep from 12.29106025498725 to 12.69616 GHz ...
# Creating odd reports ...
# Backing up even reports ...
# [2 / 2] Discrete sweep from 12.696180254987251 to 13.0 GHz ...
# Creating last report ...
# Backing up even reports ...

# %% [markdown]
# ## --------------------------------------------------------

# %% [markdown]
# ## Postprocessing, blackbox quantization

# %%
def get_wp_Cp_Lp(f, y, LJ0=10e-9, CJ0=2e-15, fscale=1e9, use_Zq=False,
                GJ0=7.748e-10):
    """
    Converts frequency-dependent imaginary parts
    of the admittance data to poles,
    capacitances, and inductances
    """
    # Add the junction inductance and capacitance to the
    # total admittance
    # Compute the zero crossings
    fcpy = np.copy(f * fscale)
    ycpy = np.copy(np.complex128(y))
    if LJ0:
        ycpy += (1. / (1j * fcpy * 2 * np.pi * LJ0)) \
          + 1j * fcpy * 2 * np.pi * CJ0
    if LJ0 and GJ0:
        ycpy += (1. / (1j * fcpy * 2 * np.pi * LJ0)) \
             + 1j * fcpy * 2 * np.pi * CJ0 \
             + GJ0
    yim = ycpy.imag
    zero_xing_idxs = np.where(np.diff(np.sign(yim))>0)[0]
    wp = 2 * np.pi * fcpy[zero_xing_idxs]
    yp = yim[zero_xing_idxs]

    # Compute the capacitances from the derivatives
    ypp = np.gradient(ycpy, 2*np.pi*(fcpy[1]-fcpy[0]))
    Cp = 0.5 * np.abs(ypp.imag[zero_xing_idxs])
    Lp = 1. / (wp**2 * Cp)
    Zp = np.sqrt(Lp / Cp)
    Rp = 1. / np.abs(np.real(ycpy[zero_xing_idxs]))
    Qp = wp * Rp * Cp
    
    # Physical constants
    h    = 6.62607015e-34 
    hbar = h / (2 * np.pi)
    e    = 1.602176634e-19
    Phi0 = h / (2 * e)
    
    # Compute Ej, Ec
    if LJ0 and CJ0:
        # Compute the Josephson inductive and charging energies
        Ej = (Phi0 / (2 * np.pi))**2 / LJ0
        Ec = e**2 / (2 * (sum(Cp)+CJ0))

        # Compute inductive energies, EL
        EL = 0.5 * Phi0**2 / Lp

        # Compute the phase zero point fluctuations
        GQ = 2 * e**2 / h
        phip2 = 2 * np.pi * GQ * Zp

        # Compute the participations
        # p = phi2 * 2 * Ej / (hbar * wp)
        pl = Lp / LJ0
        pc = Cp / CJ0

        # Compute the gs / Ds
        Zq = np.sqrt(LJ0 / CJ0)
        gD = np.sqrt(Zp / Zq)

        # Compute the g's in units of Hz, divide by h to get v, Ej = hv
        gpq = (2 * np.pi * GQ * Ej / 24.) * sum(phip2) * np.asarray([[
            np.sqrt(Zpp * Zqq) / h for p, Zpp in enumerate(Zp)]
                               for q, Zqq in enumerate(Zp) ])
        gpq = gpq.reshape([len(gpq), len(gpq)])
        
        # Compute the chis, anharmonicities
        # In units of Hz
        chipp  = -Ec * gD**2 / h
        chippp = np.asarray([-2 * np.sqrt(chipp[p] * chipp[q]) 
                             for p in range(len(chipp))
                             for q in range(len(chipp))])
        chippp = chippp.reshape([len(chipp), len(chipp)])

        return wp, Lp, Cp, Qp, fcpy, ycpy, yp, pl, pc, gpq, chippp
    
    else:
        return wp, Lp, Cp, Qp, fcpy, ycpy, yp, None, None, None, None

# %%
def FtoMHz(C):
    """
    Converts Farads to MHz
    """
    MHz  = 1e6
    h    = 6.62607015e-34 
    e    = 1.602176634e-19
    Ec   = e**2 / (2 * C)
    return Ec / h / MHz

# %%
def HtoGHz(L):
    """
    Converts Henrys to GHz
    """
    GHz  = 1e9
    h    = 6.62607015e-34 
    e    = 1.602176634e-19
    Phi0 = h / (2 * e)
    EJ   = (Phi0 / (2 * np.pi))**2 / L
    return EJ / h / GHz

# %% [markdown]
# ## Load y-data from files if not-overwrite

# %%
def load_ydata_from_sweeps(resonances):
    fdata = np.array([])
    ydata = np.array([], dtype=complex)

    # Iterate over all discrete frequency sweeps
    for i in range(2*len(resonances)+1):
        report_re = fsweep_interp.create_report(f'Discrete_Sweep_{i}', expr='re(Y(LumpPort,LumpPort))')
        report_im = fsweep_interp.create_report(f'Discrete_Sweep_{i}', expr='im(Y(LumpPort,LumpPort))')
        yre = report_re.get_arrays()
        yim = report_im.get_arrays()

        fdata = np.hstack((fdata, yre[0,:]))
        ydata = np.hstack((ydata, yre[1,:]+1j*yim[1,:]))
    
    return fdata, ydata

# %%
def load_ydata_from_txt(filenames, delimiter=','):
    fdata = np.array([])
    ydata = np.array([], dtype=complex)
    # Iterate over all discrete frequency sweeps
    for fname in filenames:
        print(f'Reading {fname} ...')
        data = np.genfromtxt(fname, delimiter=delimiter).T
        f   = data[0]
        yre = data[1]
        yim = data[2]

        fdata = np.hstack((fdata, f))
        ydata = np.hstack((ydata, yre + 1j*yim))
    return fdata, ydata

# %%
if not overwrite:
    res_in = np.zeros(21)
    fdata, ydata = load_ydata_from_files(res_in)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 if not overwrite:
#       2     res_in = np.zeros(21)
# ----> 3     fdata, ydata = load_ydata_from_files(res_in)
#
# NameError: name 'load_ydata_from_files' is not defined

# %%
filenames = [f'../data/ydata_230418_sweep_{i}.csv' for i in range(3)]
#for f in [f'../data/ydata_230326_sweep_{i}.csv' for i in range(3)]:
#    filenames.append(f)
fdata1, ydata1 = load_ydata_from_txt(filenames)
# Out:
# Reading ../data/ydata_230418_sweep_0.csv ...
# Reading ../data/ydata_230418_sweep_1.csv ...
# Reading ../data/ydata_230418_sweep_2.csv ...

# %%
ydata1
# Out:
# array([1.54699253e-11-3.32600703e-02j, 1.59584146e-11-3.22445261e-02j,
#        1.64505209e-11-3.12826472e-02j, 1.69464465e-11-3.03700889e-02j,
#        1.74463599e-11-2.95029587e-02j, 1.79504966e-11-2.86777587e-02j,
#        1.84590276e-11-2.78913362e-02j, 1.89721394e-11-2.71408422e-02j,
#        1.94900851e-11-2.64236950e-02j, 2.00130845e-11-2.57375492e-02j,
#        2.05413708e-11-2.50802688e-02j, 2.10752504e-11-2.44499038e-02j,
#        2.16149121e-11-2.38446700e-02j, 2.21607288e-11-2.32629314e-02j,
#        2.27129870e-11-2.27031837e-02j, 2.32719999e-11-2.21640414e-02j,
#        2.38380937e-11-2.16442253e-02j, 2.44116949e-11-2.11425516e-02j,
#        2.49931609e-11-2.06579222e-02j, 2.55829513e-11-2.01893162e-02j,
#        2.61815347e-11-1.97357819e-02j, 2.67893530e-11-1.92964299e-02j,
#        2.74070211e-11-1.88704263e-02j, 2.80350987e-11-1.84569869e-02j,
#        2.86742063e-11-1.80553714e-02j, 2.93250890e-11-1.76648781e-02j,
#        2.99884861e-11-1.72848389e-02j, 3.06652825e-11-1.69146137e-02j,
#        3.13564674e-11-1.65535856e-02j, 3.20630433e-11-1.62011548e-02j,
#        3.27862948e-11-1.58567334e-02j, 3.35275341e-11-1.55197380e-02j,
#        3.42883943e-11-1.51895823e-02j, 3.50706875e-11-1.48656675e-02j,
#        3.58765850e-11-1.45473703e-02j, 3.67086617e-11-1.42340283e-02j,
#        3.75699716e-11-1.39249194e-02j, 3.84642973e-11-1.36192346e-02j,
#        3.93963706e-11-1.33160396e-02j, 4.03721678e-11-1.30142188e-02j,
#        4.13994861e-11-1.27123926e-02j, 4.24888347e-11-1.24087900e-02j,
#        4.36547598e-11-1.21010442e-02j, 4.49184512e-11-1.17858534e-02j,
#        4.63136379e-11-1.14583853e-02j, 4.79077078e-11-1.11111695e-02j,
#        4.99651343e-11-1.07318739e-02j, 5.66393848e-11-1.02983921e-02j,
#        1.44613003e-09-9.76647853e-03j, 2.01362927e-10-9.03228255e-03j,
#        6.37016779e-10-7.77996835e-03j, 6.37198305e-10-7.77972447e-03j,
#        6.55994085e-10-7.75486928e-03j, 6.75635313e-10-7.72970045e-03j,
#        6.96167210e-10-7.70421112e-03j, 7.17637883e-10-7.67839426e-03j,
#        7.40098437e-10-7.65224261e-03j, 7.63603182e-10-7.62574872e-03j,
#        7.88209979e-10-7.59890489e-03j, 8.13980336e-10-7.57170321e-03j,
#        8.40979782e-10-7.54413551e-03j, 8.69278190e-10-7.51619338e-03j,
#        8.98949870e-10-7.48786817e-03j, 9.30074258e-10-7.45915092e-03j,
#        9.62735970e-10-7.43003243e-03j, 9.97025350e-10-7.40050317e-03j,
#        1.03303893e-09-7.37055336e-03j, 1.07087974e-09-7.34017285e-03j,
#        1.11065799e-09-7.30935119e-03j, 1.15249157e-09-7.27807761e-03j,
#        1.19650646e-09-7.24634093e-03j, 1.24283769e-09-7.21412966e-03j,
#        1.29162979e-09-7.18143189e-03j, 1.34303761e-09-7.14823532e-03j,
#        1.39722719e-09-7.11452723e-03j, 1.45437662e-09-7.08029446e-03j,
#        1.51467693e-09-7.04552341e-03j, 1.57833332e-09-7.01019999e-03j,
#        1.64556607e-09-6.97430963e-03j, 1.71661197e-09-6.93783723e-03j,
#        1.79172552e-09-6.90076716e-03j, 1.87118054e-09-6.86308321e-03j,
#        1.95527155e-09-6.82476859e-03j, 2.04431573e-09-6.78580591e-03j,
#        2.13865456e-09-6.74617710e-03j, 2.23865601e-09-6.70586344e-03j,
#        2.34471664e-09-6.66484549e-03j, 2.45726404e-09-6.62310307e-03j,
#        2.57675938e-09-6.58061523e-03j, 2.70370026e-09-6.53736019e-03j,
#        2.83862366e-09-6.49331532e-03j, 2.98210924e-09-6.44845710e-03j,
#        3.13478291e-09-6.40276107e-03j, 3.29732060e-09-6.35620176e-03j,
#        3.47045239e-09-6.30875267e-03j, 3.65496678e-09-6.26038620e-03j,
#        3.85171562e-09-6.21107362e-03j, 4.06161892e-09-6.16078496e-03j,
#        4.28567035e-09-6.10948897e-03j, 4.52494279e-09-6.05715309e-03j,
#        4.78059445e-09-6.00374329e-03j, 5.05387504e-09-5.94922409e-03j,
#        5.34613231e-09-5.89355839e-03j, 5.65881897e-09-5.83670745e-03j,
#        5.99349941e-09-5.77863074e-03j, 6.35185686e-09-5.71928587e-03j,
#        6.73570036e-09-5.65862849e-03j, 7.14697148e-09-5.59661213e-03j,
#        7.58775095e-09-5.53318813e-03j, 8.06026454e-09-5.46830546e-03j,
#        8.56688818e-09-5.40191060e-03j, 9.11015204e-09-5.33394738e-03j,
#        9.69274304e-09-5.26435682e-03j, 1.03175055e-08-5.19307694e-03j,
#        1.09874394e-08-5.12004257e-03j, 1.17056957e-08-5.04518516e-03j,
#        1.24755682e-08-4.96843253e-03j, 1.33004806e-08-4.88970864e-03j,
#        1.41839701e-08-4.80893334e-03j, 1.51296636e-08-4.72602207e-03j,
#        1.61412493e-08-4.64088555e-03j, 1.72224406e-08-4.55342947e-03j,
#        1.83769331e-08-4.46355410e-03j, 1.96083546e-08-4.37115394e-03j,
#        2.09202068e-08-4.27611723e-03j, 2.23158019e-08-4.17832554e-03j,
#        2.37981918e-08-4.07765325e-03j, 2.53700944e-08-3.97396695e-03j,
#        2.70338172e-08-3.86712489e-03j, 2.87911825e-08-3.75697630e-03j,
#        3.06434574e-08-3.64336063e-03j, 3.25912917e-08-3.52610677e-03j,
#        3.46346712e-08-3.40503218e-03j, 3.67728879e-08-3.27994188e-03j,
#        3.90045348e-08-3.15062742e-03j, 4.13275274e-08-3.01686564e-03j,
#        4.37391561e-08-2.87841740e-03j, 4.62361719e-08-2.73502609e-03j,
#        4.88149034e-08-2.58641605e-03j, 5.14714059e-08-2.43229069e-03j,
#        5.42016356e-08-2.27233054e-03j, 5.70016469e-08-2.10619098e-03j,
#        5.98678020e-08-1.93349968e-03j, 6.27969894e-08-1.75385382e-03j,
#        6.57868407e-08-1.56681685e-03j, 6.88359428e-08-1.37191489e-03j,
#        7.19440383e-08-1.16863271e-03j, 7.51122152e-08-9.56409038e-04j,
#        7.83430841e-08-7.34631359e-04j, 8.16409472e-08-5.02629904e-04j,
#        8.50119652e-08-2.59670809e-04j, 8.84643277e-08-4.94825612e-06j,
#        9.20084378e-08+2.62424563e-04j, 9.56571196e-08+5.43425887e-04j,
#        9.94258603e-08+8.39137479e-04j, 1.03333098e-07+1.15075869e-03j,
#        1.07400567e-07+1.47962290e-03j, 1.11653723e-07+1.82721674e-03j,
#        1.16122251e-07+2.19520280e-03j, 1.20840699e-07+2.58544644e-03j,
#        1.25849245e-07+3.00004769e-03j, 1.31194652e-07+3.44137932e-03j,
#        1.36931452e-07+3.91213260e-03j, 1.43123422e-07+4.41537268e-03j,
#        1.49845446e-07+4.95460572e-03j, 1.57185872e-07+5.53386129e-03j,
#        1.65249528e-07+6.15779375e-03j, 1.74161601e-07+6.83180822e-03j,
#        1.84072685e-07+7.56221840e-03j, 1.95165406e-07+8.35644577e-03j,
#        2.07663204e-07+9.22327370e-03j, 2.21842121e-07+1.01731749e-02j,
#        2.38046816e-07+1.12187382e-02j, 2.56712627e-07+1.23752312e-02j,
#        2.78396454e-07+1.36613528e-02j, 3.03820719e-07+1.51002551e-02j,
#        3.33937171e-07+1.67209523e-02j, 3.70021490e-07+1.85603019e-02j,
#        4.13817007e-07+2.06658469e-02j, 4.67759080e-07+2.30999906e-02j,
#        5.35336548e-07+2.59462953e-02j, 6.21695366e-07+2.93192802e-02j,
#        7.34690013e-07+3.33802204e-02j, 8.86808165e-07+3.83637217e-02j,
#        1.09891079e-06+4.46247438e-02j, 1.40805230e-06+5.27271332e-02j,
#        1.88540960e-06+6.36237850e-02j, 2.68262457e-06+7.90621412e-02j,
#        4.17288694e-06+1.02630423e-01j, 7.49693398e-06+1.43048054e-01j,
#        1.77112354e-05+2.28441385e-01j, 8.78157118e-05+5.28066376e-01j,
#        1.32388359e-03-2.12683635e+00j, 3.67472875e-05-3.67278711e-01j,
#        1.06995713e-05-2.05266775e-01j, 4.94433275e-06-1.44421222e-01j,
#        2.80602179e-06-1.12528875e-01j, 1.78997440e-06-9.28950231e-02j,
#        1.23154395e-06-7.95908350e-02j, 8.93467799e-07-6.99799845e-02j,
#        6.74163091e-07-6.27117156e-02j, 5.24333724e-07-5.70223775e-02j,
#        4.17751296e-07-5.24477073e-02j, 3.39438887e-07-4.86892087e-02j,
#        2.80351206e-07-4.55462302e-02j, 2.34770409e-07-4.28789110e-02j,
#        1.98942575e-07-4.05867797e-02j, 1.70323160e-07-3.85958000e-02j,
#        1.47139598e-07-3.68502128e-02j, 1.28127555e-07-3.53072242e-02j,
#        1.12366382e-07-3.39334441e-02j, 9.91733664e-08-3.27024377e-02j,
#        8.80339824e-08-3.15930040e-02j, 7.85548076e-08-3.05879417e-02j,
#        7.04310777e-08-2.96731483e-02j, 6.34239120e-08-2.88369527e-02j,
#        5.73440569e-08-2.80696125e-02j, 5.20401044e-08-2.73629317e-02j,
#        4.73898349e-08-2.67099653e-02j, 4.32937743e-08-2.61047896e-02j,
#        3.96703438e-08-2.55423211e-02j, 3.64521671e-08-2.50181725e-02j,
#        3.35832337e-08-2.45285376e-02j, 3.10166971e-08-2.40700982e-02j,
#        2.87131521e-08-2.36399480e-02j, 2.66392760e-08-2.32355312e-02j,
#        2.47667495e-08-2.28545906e-02j, 2.30713916e-08-2.24951257e-02j,
#        2.15324645e-08-2.21553569e-02j, 2.01321083e-08-2.18336959e-02j,
#        1.88548818e-08-2.15287208e-02j, 1.76873848e-08-2.12391547e-02j,
#        1.66179471e-08-2.09638479e-02j, 1.56363717e-08-2.07017621e-02j,
#        1.47337197e-08-2.04519577e-02j, 1.39021320e-08-2.02135817e-02j,
#        1.31346783e-08-1.99858586e-02j, 1.24252309e-08-1.97680814e-02j,
#        1.17683574e-08-1.95596044e-02j, 1.11592295e-08-1.93598364e-02j,
#        1.05935458e-08-1.91682356e-02j, 1.00674649e-08-1.89843040e-02j,
#        9.57754937e-09-1.88075833e-02j, 9.12071616e-09-1.86376510e-02j,
#        8.69419457e-09-1.84741171e-02j, 8.29548974e-09-1.83166208e-02j,
#        7.92235103e-09-1.81648280e-02j, 7.57274421e-09-1.80184287e-02j,
#        7.24482755e-09-1.78771350e-02j, 6.93693083e-09-1.77406793e-02j,
#        6.64753683e-09-1.76088122e-02j, 6.37526506e-09-1.74813012e-02j,
#        6.37265768e-09-1.74800631e-02j, 5.64696785e-09-1.71216853e-02j,
#        5.03604357e-09-1.67954749e-02j, 4.51792477e-09-1.64971883e-02j,
#        4.07553403e-09-1.62232970e-02j, 3.69545153e-09-1.59708433e-02j,
#        3.36703003e-09-1.57373287e-02j, 3.08174719e-09-1.55206289e-02j,
#        2.83272545e-09-1.53189257e-02j, 2.61437254e-09-1.51306541e-02j,
#        2.42210906e-09-1.49544595e-02j, 2.25216039e-09-1.47891636e-02j,
#        2.10139611e-09-1.46337366e-02j, 1.96720520e-09-1.44872746e-02j,
#        1.84739800e-09-1.43489808e-02j, 1.74012904e-09-1.42181502e-02j,
#        1.64383547e-09-1.40941565e-02j, 1.55718798e-09-1.39764420e-02j,
#        1.47905102e-09-1.38645077e-02j, 1.40845084e-09-1.37579063e-02j,
#        1.34454935e-09-1.36562355e-02j, 1.28662268e-09-1.35591326e-02j,
#        1.23404359e-09-1.34662695e-02j, 1.18626700e-09-1.33773490e-02j,
#        1.14281782e-09-1.32921008e-02j, 1.10328097e-09-1.32102790e-02j,
#        1.06729289e-09-1.31316591e-02j, 1.03453459e-09-1.30560359e-02j,
#        1.00472549e-09-1.29832213e-02j, 9.77618618e-10-1.29130426e-02j,
#        9.52996099e-10-1.28453412e-02j, 9.30665682e-10-1.27799708e-02j,
#        9.10457573e-10-1.27167965e-02j, 8.92221745e-10-1.26556935e-02j,
#        8.75825754e-10-1.25965465e-02j, 8.61152635e-10-1.25392484e-02j,
#        8.48099304e-10-1.24837001e-02j, 8.36575117e-10-1.24298091e-02j,
#        8.26500609e-10-1.23774895e-02j, 8.17806256e-10-1.23266614e-02j,
#        8.10431648e-10-1.22772499e-02j, 8.04324740e-10-1.22291854e-02j,
#        7.99440845e-10-1.21824025e-02j, 7.95742262e-10-1.21368402e-02j,
#        7.93197505e-10-1.20924412e-02j, 7.91780917e-10-1.20491517e-02j,
#        7.91472091e-10-1.20069213e-02j, 7.92255473e-10-1.19657026e-02j,
#        7.94119905e-10-1.19254509e-02j, 7.97058198e-10-1.18861241e-02j,
#        8.01066704e-10-1.18476828e-02j])

# %%
fdata1
# Out:
# array([ 5.       ,  5.1458208,  5.2916416,  5.4374624,  5.5832832,
#         5.729104 ,  5.8749248,  6.0207456,  6.1665664,  6.3123872,
#         6.458208 ,  6.6040288,  6.7498496,  6.8956704,  7.0414912,
#         7.187312 ,  7.3331328,  7.4789536,  7.6247744,  7.7705952,
#         7.916416 ,  8.0622368,  8.2080576,  8.3538784,  8.4996992,
#         8.64552  ,  8.7913408,  8.9371616,  9.0829824,  9.2288032,
#         9.374624 ,  9.5204448,  9.6662656,  9.8120864,  9.9579072,
#        10.103728 , 10.2495488, 10.3953696, 10.5411904, 10.6870112,
#        10.832832 , 10.9786528, 11.1244736, 11.2702944, 11.4161152,
#        11.561936 , 11.7077568, 11.8535776, 11.9993984, 12.1452192,
#        12.29104  , 12.29106  , 12.2930855, 12.295111 , 12.2971365,
#        12.299162 , 12.3011875, 12.303213 , 12.3052385, 12.307264 ,
#        12.3092895, 12.311315 , 12.3133405, 12.315366 , 12.3173915,
#        12.319417 , 12.3214425, 12.323468 , 12.3254935, 12.327519 ,
#        12.3295445, 12.33157  , 12.3335955, 12.335621 , 12.3376465,
#        12.339672 , 12.3416975, 12.343723 , 12.3457485, 12.347774 ,
#        12.3497995, 12.351825 , 12.3538505, 12.355876 , 12.3579015,
#        12.359927 , 12.3619525, 12.363978 , 12.3660035, 12.368029 ,
#        12.3700545, 12.37208  , 12.3741055, 12.376131 , 12.3781565,
#        12.380182 , 12.3822075, 12.384233 , 12.3862585, 12.388284 ,
#        12.3903095, 12.392335 , 12.3943605, 12.396386 , 12.3984115,
#        12.400437 , 12.4024625, 12.404488 , 12.4065135, 12.408539 ,
#        12.4105645, 12.41259  , 12.4146155, 12.416641 , 12.4186665,
#        12.420692 , 12.4227175, 12.424743 , 12.4267685, 12.428794 ,
#        12.4308195, 12.432845 , 12.4348705, 12.436896 , 12.4389215,
#        12.440947 , 12.4429725, 12.444998 , 12.4470235, 12.449049 ,
#        12.4510745, 12.4531   , 12.4551255, 12.457151 , 12.4591765,
#        12.461202 , 12.4632275, 12.465253 , 12.4672785, 12.469304 ,
#        12.4713295, 12.473355 , 12.4753805, 12.477406 , 12.4794315,
#        12.481457 , 12.4834825, 12.485508 , 12.4875335, 12.489559 ,
#        12.4915845, 12.49361  , 12.4956355, 12.497661 , 12.4996865,
#        12.501712 , 12.5037375, 12.505763 , 12.5077885, 12.509814 ,
#        12.5118395, 12.513865 , 12.5158905, 12.517916 , 12.5199415,
#        12.521967 , 12.5239925, 12.526018 , 12.5280435, 12.530069 ,
#        12.5320945, 12.53412  , 12.5361455, 12.538171 , 12.5401965,
#        12.542222 , 12.5442475, 12.546273 , 12.5482985, 12.550324 ,
#        12.5523495, 12.554375 , 12.5564005, 12.558426 , 12.5604515,
#        12.562477 , 12.5645025, 12.566528 , 12.5685535, 12.570579 ,
#        12.5726045, 12.57463  , 12.5766555, 12.578681 , 12.5807065,
#        12.582732 , 12.5847575, 12.586783 , 12.5888085, 12.590834 ,
#        12.5928595, 12.594885 , 12.5969105, 12.598936 , 12.6009615,
#        12.602987 , 12.6050125, 12.607038 , 12.6090635, 12.611089 ,
#        12.6131145, 12.61514  , 12.6171655, 12.619191 , 12.6212165,
#        12.623242 , 12.6252675, 12.627293 , 12.6293185, 12.631344 ,
#        12.6333695, 12.635395 , 12.6374205, 12.639446 , 12.6414715,
#        12.643497 , 12.6455225, 12.647548 , 12.6495735, 12.651599 ,
#        12.6536245, 12.65565  , 12.6576755, 12.659701 , 12.6617265,
#        12.663752 , 12.6657775, 12.667803 , 12.6698285, 12.671854 ,
#        12.6738795, 12.675905 , 12.6779305, 12.679956 , 12.6819815,
#        12.684007 , 12.6860325, 12.688058 , 12.6900835, 12.692109 ,
#        12.6941345, 12.69616  , 12.69618  , 12.7022564, 12.7083328,
#        12.7144092, 12.7204856, 12.726562 , 12.7326384, 12.7387148,
#        12.7447912, 12.7508676, 12.756944 , 12.7630204, 12.7690968,
#        12.7751732, 12.7812496, 12.787326 , 12.7934024, 12.7994788,
#        12.8055552, 12.8116316, 12.817708 , 12.8237844, 12.8298608,
#        12.8359372, 12.8420136, 12.84809  , 12.8541664, 12.8602428,
#        12.8663192, 12.8723956, 12.878472 , 12.8845484, 12.8906248,
#        12.8967012, 12.9027776, 12.908854 , 12.9149304, 12.9210068,
#        12.9270832, 12.9331596, 12.939236 , 12.9453124, 12.9513888,
#        12.9574652, 12.9635416, 12.969618 , 12.9756944, 12.9817708,
#        12.9878472, 12.9939236, 13.       ])

# %%
fdata.size
# Out:
# 303

# %%
ydata.size
# Out:
# 303

# %% [markdown]
# ## Plot the zero crossings

# %%
# Plot the results, save the figure(s)
fsize = 20
fscale = 1e9
dstr = datetime.datetime.today().strftime('%y%m%d')
wp, Lp, Cp, Qp, fcpy, ycpy, yp, pl, pc, gD, chippp = \
get_wp_Cp_Lp(fdata1, ydata1, LJ0=100e-9, CJ0=2e-15, fscale=1e9, use_Zq=False)

fig, ax = plt.subplots(1, 1, tight_layout=True)
ax.plot(fdata1, ydata1.imag)
ax.plot(wp/(2*np.pi*fscale), yp.imag, 'o', label='Zero Crossings')
ax.set_ylabel(r'Im $Y(\omega)$', fontsize=fsize)
ax.set_xlabel(r'Frequency [GHz]', fontsize=fsize)
set_axes_fonts(ax, fsize)
set_xaxis_rot(ax, 45.)
#ax.set_xlim([None, 10])
#ax.set_xlim([5.88, 5.95])
ax.set_ylim([-0.05, 0.05])
ax.axhline(y=0, color='k', ls='--')
fig.savefig(f'../figs/zeros_term_bbq_inductive_50um_15mm_{dstr}.pdf', format='pdf')

# %% [markdown]
# ## Iterate over all coupler offset values, fix LJ=10 nH

# %%
def get_bbq_params(fdata, ydata, NLJ=25, Nmodes=6, LJvals=[0.1e-9, 100e-9]):
    wps = []
    pcs = []
    pls = []
    gDs = []
    Cps = []
    Lps = []
    Qps = []
    chis = []

    # Whether or not to use the largest impedance mode
    # as the junction mode in the calculations
    use_Zq = False
    print_results = True

    LJs = np.logspace(np.log10(LJvals[0]), np.log10(LJvals[1]), NLJ)
    #for idx, x in enumerate(xdata):
    for LJ in LJs:
        wpp, Lp, Cp, Qp, _, _, _, pl, pc, gD, chip \
        = get_wp_Cp_Lp(fdata, ydata, LJ0=LJ, fscale=fscale, use_Zq=use_Zq)
        wps.append(np.sort(wpp[0:Nmodes]))
        #wps.append(wpp[0:Nmodes])
        pls.append(pl[0:Nmodes])
        pcs.append(pc[0:Nmodes])
        gDs.append(gD[0:Nmodes, 0:Nmodes])
        Lps.append(Lp[0:Nmodes])
        Cps.append(Cp[0:Nmodes])
        Qps.append(Qp[0:Nmodes])
        chis.append(chip[0:Nmodes, 0:Nmodes])
        if print_results:
            print(f'wps: {wps}')
        # wps.append(wpp)
        # print(f'LJ: {LJ}, wpp: {wpp}')
    wps = np.asarray(wps).T
    pls  = np.asarray(pls).T
    pcs  = np.asarray(pls).T
    gDs = np.asarray(gDs).T
    Lps = np.asarray(Lps).T
    Cps = np.asarray(Cps).T
    Qps = np.asarray(Qps).T
    chis = np.asarray(chis).T

    return wps, pls, pcs, gDs, Lps, Cps, Qps, chis

# %%
wp0,_ , _, _, _, _, _, _, _, _, _ = get_wp_Cp_Lp(fdata, ydata, fscale=fscale, LJ0=None)

# %%
wps1, pls1, pcs1, gDs1, Lps1, Cps1, Qps1, chis1 = get_bbq_params(fdata, ydata, Nmodes=1, LJvals=[1e-9,100e-9])
# Out:
# wps: [array([7.88560114e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10]), array([7.84996668e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10]), array([7.84996668e+10]), array([7.84996668e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10]), array([7.84996668e+10]), array([7.84996668e+10]), array([7.84996668e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10]), array([7.84996668e+10]), array([7.84996668e+10]), array([7.84996668e+10]), array([7.84869402e+10])]
# wps: [array([7.88560114e+10]), array([7.88305582e+10]), array([7.88178316e+10]), array([7.87923784e+10]), array([7.87669252e+10]), array([7.8741472e+10]), array([7.87160188e+10]), array([7.86905657e+10]), array([7.86651125e+10]), array([7.86396593e+10]), array([7.86142061e+10]), array([7.86014795e+10]), array([7.85887529e+10]), array([7.85632997e+10]), array([7.85505732e+10]), array([7.85378466e+10]), array([7.85378466e+10]), array([7.852512e+10]), array([7.85123934e+10]), array([7.85123934e+10]), array([7.84996668e+10]), array([7.84996668e+10]), array([7.84996668e+10]), array([7.84869402e+10]), array([7.84869402e+10])]

# %%
Cps1
# Out:
# array([[1.44308735e-12, 1.07827865e-12, 9.45661219e-13, 7.44837344e-13,
#         6.01921114e-13, 4.96599704e-13, 4.16750039e-13, 3.54771733e-13,
#         3.05702734e-13, 2.66191512e-13, 2.33907944e-13, 2.19910544e-13,
#         2.07143616e-13, 1.84792212e-13, 1.74944322e-13, 1.65871546e-13,
#         1.65849436e-13, 1.57476256e-13, 1.49728680e-13, 1.49716238e-13,
#         1.42535546e-13, 1.42527067e-13, 1.42520069e-13, 1.35852760e-13,
#         1.35847990e-13]])

# %%
FtoMHz(Cps1[0])
# Out:
# array([ 13.42276984,  17.96402941,  20.48326498,  26.0059857 ,
#         32.18067764,  39.0057206 ,  46.47925016,  54.59913381,
#         63.36295746,  72.76802022,  82.81133578,  88.08231288,
#         93.51110926, 104.82167545, 110.7222522 , 116.77849376,
#        116.79406192, 123.00412633, 129.36886487, 129.37961543,
#        135.89753459, 135.90561919, 135.91229298, 142.58252328,
#        142.58752936])

# %% [markdown]
# ## Plot the $E_C$ of the coupler mode

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
dstr = datetime.datetime.today().strftime('%y%m%d')
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
NLJ = 25
LJs = np.logspace(np.log10(1e-9), np.log10(100e-9), NLJ)
ax2 = ax.twinx()
for idx, wppp in enumerate(wps1):
    ax.plot(LJs/1e-9, FtoMHz(Cps1[0]),
            'o',
            color=cycle[idx%clen], label=r'$E_C$ [MHz]')
    ax2.plot(LJs/1e-9, HtoGHz(LJs),
           '*', color=cycle[(idx+1)%clen],
            label=r'$E_J$ [GHz]')
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$E_C$ [MHz]', fontsize=fsize)
ax2.set_ylabel(r'$E_J$ [GHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
# ax.set_ylim([7.165, 7.2])
set_axes_fonts(ax, fsize)
set_axes_fonts(ax2, fsize)
ax.set_xscale('log')
fig.savefig(f'../figs/modes_term_bbq_inductive_planar_sapphire_{dstr}.pdf',
            transparent=True, format='pdf')

# %%
wps1[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 wps1[2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 1

# %%
wps1[:, 0]
# Out:
# array([7.88560114e+10])

# %%
wps1[:, -1]
# Out:
# array([7.84869402e+10])

# %%
wps1_sort = np.sort(wps1, axis=0)
wps1_sort
# Out:
# array([[7.88560114e+10, 7.88305582e+10, 7.88178316e+10, 7.87923784e+10,
#         7.87669252e+10, 7.87414720e+10, 7.87160188e+10, 7.86905657e+10,
#         7.86651125e+10, 7.86396593e+10, 7.86142061e+10, 7.86014795e+10,
#         7.85887529e+10, 7.85632997e+10, 7.85505732e+10, 7.85378466e+10,
#         7.85378466e+10, 7.85251200e+10, 7.85123934e+10, 7.85123934e+10,
#         7.84996668e+10, 7.84996668e+10, 7.84996668e+10, 7.84869402e+10,
#         7.84869402e+10]])

# %% [markdown]
# ## Plot the modes of coupled structure

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
dstr = datetime.datetime.today().strftime('%y%m%d')
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
NLJ = 25
LJs = np.logspace(np.log10(1e-9), np.log10(100e-9), NLJ)
for idx, wppp in enumerate(wps1):
    ax.plot(LJs/1e-9, wppp/(2*np.pi*fscale),
            'o', label=r'Mode-%d' % (idx + 1),
            color=cycle[idx%clen])
    ax.plot(LJs/1e-9, [wp0[idx]/(2*np.pi*fscale)] * len(LJs),
            '--', color=cycle[idx%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'Eigenfrequencies [GHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
# ax.set_ylim([7.165, 7.2])
set_axes_fonts(ax, fsize)
leg = set_leg_outside(ax, lsize)
ax.set_xscale('log')
fig.savefig(f'../figs/modes_term_bbq_inductive_planar_sapphire_{dstr}.pdf',
             bbox_extra_artists=(leg, ), bbox_inches='tight',
            transparent=True, format='pdf')

# %% [markdown]
# ## Plot the splittings of the lowest modes vs LJ

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
fscale2 = 1e6
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
ax.plot(LJs/1e-9, (wps1[1]-wps1[0])/(2*np.pi*fscale2),
           'o-',
            color=cycle[0%clen])
# ax.plot(LJs/1e-9, np.ones(LJs.size) * dw/(fscale2), 'k--')
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'Mode Splitting (1,2) [MHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
#ax.set_ylim([0, 150])
#ax.set_xlim([0.5, 2.2])
ax.set_xscale('log')
fig.savefig(f'../figs/modes_splitting_term_bbq_inductive_planar_sapphire_{dstr}.pdf',
            format='pdf')

# %% [markdown]
# ## Mode losses

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
for idx, Q in enumerate(Qps1):
    ax.plot(LJs/1e-9, 1./Q,
            'o-', label=r'Mode-%d' % (idx + 1),
            color=cycle[idx%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$Q_p^{-1}$', fontsize=fsize)
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/mode_losses_term_bbq_inductive_planar_sapphire_{dstr}.pdf', format='pdf')

# %% [markdown]
# ## Mode $T_1$'s

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
fscale2 = 1e6
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
for idx, Q in enumerate(Qps1):
    ax.plot(LJs/1e-9, 1e6 * Q / wps1[idx],
            'o-', label=r'Mode-%d' % (idx + 1),
            color=cycle[idx%clen])
ax.plot(LJs/1e-9, 100*np.ones(LJs.size), 'k:',
        lw=2, label=r'100 $\mu$s $T_1$')
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$T_1$ [$\mu$s]', fontsize=fsize)
# ax.plot(LJs/1e-9, np.ones(LJs.size) * dw/(fscale2), 'k--')
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
#ax.set_ylim([1e-2, 350])
#ax.set_xlim([0.5, 2.2])
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/T1_modes_coupled_{dstr}.pdf',
            format='pdf')

# %% [markdown]
# ## Black box results

# %% [markdown]
# ### $\alpha_p$ and $\chi_{pq}$

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
Nmodes = 4
fscale3 = 1e3
for idx in range(Nmodes):
    ax.plot(LJs/1e-9, 0.5 * np.abs(chis1[idx, idx, :]) / fscale3,
            'o-', label=r'Mode-%d' % (idx + 1),
            color=cycle[idx%clen])
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$|\alpha_p|$ [kHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/mode_alpha_term_bbq_inductive_planar_sapphire_{dstr}.pdf', format='pdf')

# %%
# Chi, lower triangle
chiT = np.array([np.triu(chis1[:,:,i]) for i in range(len(LJs))]).T
gT = np.array([np.triu(gDs1[:,:,i]) for i in range(len(LJs))]).T
NM = 4
chiT[0:NM,0:NM,0]

fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
NM = 4
idx = 0
for i in range(NM):
    for j in range(NM):
        if (i != j) and np.any(chiT[i, j, :] != 0.):
            ax.plot(LJs/1e-9, np.abs(chiT[i, j, :]) / fscale3,
                'o-', label=r'$\chi_{%d,%d}$' % (i + 1, j + 1),
                color=cycle[idx%clen])
            idx += 1
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$|\chi_{pq}|$ [kHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/mode_chi_term_bbq_inductive_planar_sapphire_{dstr}.pdf', format='pdf')

# %%
fig, ax = plt.subplots(1, 1, tight_layout=True)
lsize = 14
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
clen = len(cycle)
NM = 4
idx = 0
for i in range(NM):
    for j in range(NM):
        if (i != j) and np.any(gT[i, j, :] != 0.):
            ax.plot(LJs/1e-9, np.abs(gT[i, j, :]) / fscale2,
                'o-', label=r'$g_{%d,%d}$' % (i + 1, j + 1),
                color=cycle[idx%clen])
            idx += 1
ax.set_xlabel(r'$L_J$ [nH]', fontsize=fsize)
ax.set_ylabel(r'$|g_{pq}|$ [MHz]', fontsize=fsize)
set_xaxis_rot(ax, 45)
set_axes_fonts(ax, fsize)
set_leg_outside(ax, lsize)
ax.set_xscale('log')
ax.set_yscale('log')
fig.savefig(f'../figs/mode_g_term_bbq_inductive_planar_sapphire_{dstr}.pdf', format='pdf')
