# %% [markdown]
# # Metall Tutorial

# %% [markdown]
# ## Recommended Flow
#
# ![tutorial_flow.png](attachment:tutorial_flow.png)

# %% [markdown]
# ## Lauch Terminal
#
# 1. [Launch another binder session](https://mybinder.org/v2/gh/LLNL/metall-tutorial/HEAD).
#
# 2. Open a terminal by clicking \[New\] -> \[Terminal\].
# ![open_terminal.png](attachment:open_terminal.png)
#
#
# ## Build
#
# Metall depends on [Boost C++ Libraries](https://www.boost.org/) and requires GCC 8.1 or more.
# They are already installed in the home direcotry for you.
#
# Here is how to build a tutorial example.
#
# ```bash
#
# # Metall's git repository is available in the home direcotry.
# cd $HOME/metall/tutorial/hands_on
#
# # Build an example
# g++-8 -std=c++17 [tutorial_example.cpp, e.g., t1-1.cpp] -lstdc++fs -pthread -I../../include -I$HOME/boost
#
# # All tutorial programs do not take command-line options
# ./a.out
#
# ```
