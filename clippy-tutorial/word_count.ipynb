# %%
from clippy import Clippy

# %%
w = Clippy({'wordcounter': '/tmp/clippy/clippy-cpp/build/examples/wordcounter'}, cmd_prefix='', loglevel=0)

# %%
w.wordcounter.count_words(path="./seuss", words=['one', 'fish', 'two', 'fish', 'red', 'fish', 'blue', 'fish'])

# %%
w.wordcounter.count_words(path="./seuss", words=['black', 'fish', 'blue', 'fish', 'old', 'fish', 'new', 'fish'])

# %%
w.wordcounter.top_k_words(path="./seuss", k=1)
