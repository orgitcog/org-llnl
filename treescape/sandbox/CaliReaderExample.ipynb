# %%
import sys
import time

sys.path.append("../python")
sys.path.append("../viz")

from MyTimer import MyTimer
from StackedLine import StackedLine
from CaliReader import CaliReader
from TreeScapeModel import TreeScapeModel

m = MyTimer("start")

cali_loc = "/Users/aschwanden1/lulesh_gen/100/"
cali_loc = "/Users/aschwanden1/lulesh_gen/10000b/"

caliReader = CaliReader("launchdate", cali_loc, 15 )

mod = TreeScapeModel(caliReader)
mod.setDrillLevel(['main'])

sl = StackedLine()
sl.render( model=mod, drill_level=['main'] )
m.mark("finish render")
m.print()
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.
# after multiprocess
# after res.
# combining --------------------------
# model: <TreeScapeModel.TreeScapeModel object at 0x7facb0582f10>
# drill_level: ['main']
# <link rel="stylesheet" href="../stacked.css">
# simple                                          7.033348083496094e-05
# finish render                                   4.39088773727417
# Total Elapsed time                              4.390985012054443
# Error in callback <bound method RoundTrip.manage_jupter_change of <hatchet.external.roundtrip.roundtrip.manager.RoundTrip object at 0x7facb83f4250>> (for post_run_cell), with arguments args (<ExecutionResult object at 7facb0582fa0, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7facb0582f70, raw_cell="import sys
# import time
#
# sys.path.append("../python.." store_history=True silent=False shell_futures=True cell_id=None> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: manage_jupter_change() takes 1 positional argument but 2 were given

# %%
import sys
import time

sys.path.append("../python")
sys.path.append("../viz")

from MyTimer import MyTimer
from StackedLine import StackedLine
from CaliReader import CaliReader
from TreeScapeModel import TreeScapeModel

m = MyTimer("start")

cali_loc = "/Users/aschwanden1/lulesh_gen/1000b/"

caliReader = CaliReader("launchdate", cali_loc, 8 )

mod = TreeScapeModel(caliReader)
mod.setDrillLevel(['main'])
#mod.setYMin(500)
#mod.setYMax(2000)
mod.setXAggregation("max")

sl = StackedLine()
sl.render( model=mod, drill_level=['main'] )
m.mark("finish render")
m.print()
# Out:
# after multiprocess
# after res.
# combining --------------------------
# model: <TreeScapeModel.TreeScapeModel object at 0x7facb0582ee0>
# drill_level: ['main']
# <link rel="stylesheet" href="../stacked.css">
# simple                                          5.2928924560546875e-05
# finish render                                   0.614436149597168
# Total Elapsed time                              0.6145179271697998
# Error in callback <bound method RoundTrip.manage_jupter_change of <hatchet.external.roundtrip.roundtrip.manager.RoundTrip object at 0x7facb83f4250>> (for post_run_cell), with arguments args (<ExecutionResult object at 7facb8647700, execution_count=2 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7facb86476d0, raw_cell="import sys
# import time
#
# sys.path.append("../python.." store_history=True silent=False shell_futures=True cell_id=None> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: manage_jupter_change() takes 1 positional argument but 2 were given
