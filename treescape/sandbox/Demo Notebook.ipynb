# %%
cali_loc = "/usr/gapps/spot/datasets/newdemo"
filter_meta = "launchday"
xaxis = 'launchday'

import sys
import time
 
sys.path.append("/usr/gapps/spot/treescape/python")
sys.path.append("/usr/gapps/spot/treescape/viz")
 
from StackedLine import StackedLine
from TreeScapeModel import TreeScapeModel
from CaliReader import CaliReader
 
caliReader = CaliReader( cali_loc, 15 )
 
tsm = TreeScapeModel( caliReader )
 
# Assuming TreeScapeModel behaves like a list of dictionaries
newlist = [run for run in tsm if run.metadata["test"] == "tiny"]
 
sorted_new = sorted( newlist, key=lambda run:run.metadata[filter_meta])
tsm.update( sorted_new )
 
sl = StackedLine()
sl.setYMin(0)
sl.setXAxis(xaxis) # launchday
 
sl.render(tsm)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 15
#      12 from TreeScapeModel import TreeScapeModel
#      13 from CaliReader import CaliReader
# ---> 15 caliReader = CaliReader( cali_loc, 15 )
#      17 tsm = TreeScapeModel( caliReader )
#      19 # Assuming TreeScapeModel behaves like a list of dictionaries
#
# File ~/stacked/sandbox/../python/CaliReader.py:57, in CaliReader.__init__(self, path, pool_size)
#      52 self.inclusive_strings = ["min#inclusive#sum#time.duration",
#      53                           "max#inclusive#sum#time.duration",
#      54                           "avg#inclusive#sum#time.duration",
#      55                           "avg#inclusive#sum#time.duration"]
#      56 self.xy_idx_by_drill_level = {}
# ---> 57 self.init()
#
# File ~/stacked/sandbox/../python/CaliReader.py:129, in CaliReader.init(self)
#     126 #PATH = '/Users/aschwanden1/lulesh_gen/1000b/'
#     127 profiles = [y for x in os.walk(PATH) for y in glob(os.path.join(x[0], '*.cali'))]
# --> 129 self.first_profile = profiles[0]
#     131 self.r = cr.CaliperReader()
#     132 self.r.read( self.first_profile )
#
# IndexError: list index out of range
# Error in callback <bound method RoundTrip.manage_jupter_change of <hatchet.external.roundtrip.roundtrip.manager.RoundTrip object at 0x7febea76f310>> (for post_run_cell), with arguments args (<ExecutionResult object at 7febe9b61ee0, execution_count=3 error_before_exec=None error_in_exec=list index out of range info=<ExecutionInfo object at 7febe9a58a90, raw_cell="cali_loc = "/usr/gapps/spot/datasets/newdemo"
# filt.." store_history=True silent=False shell_futures=True cell_id=None> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: manage_jupter_change() takes 1 positional argument but 2 were given
