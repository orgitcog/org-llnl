# %% [markdown]
# # Generate Plots for Few Shot Learning

# %% [markdown]
# These experiments are trying to quantify the "learning-efficiency" of the HD approaches...would be agood idea to repeat for DUDE and dockstring

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import pandas as pd

# %%
def main(result_path, test_size=-1):
    df = pd.read_csv(result_path, sep='\t')
    df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
    sns.catplot(x="classifier_type", y="acc", hue="kshot", data=df, jitter=False,palette="ch:.25", size=5, aspect=1.5)
    sns.catplot(x="classifier_type", y="recall", hue="kshot", data=df, jitter=False,palette="ch:.25", size=5, aspect=1.5)
    sns.catplot(x="classifier_type", y="train_time", hue="kshot", data=df,palette="ch:.25", jitter=False, aspect=1.5)
    sns.catplot(x="classifier_type", y="test_time", hue="kshot", data=df,palette="ch:.25", size=5, aspect=1.5)

# %% [markdown]
# ## PDBBind

# %%
main(result_path="/usr/WS1/jones289/hd-cuda-master/hdpy/hdpy/fsl/fsl_morganfp_pdbbind_results.csv")
# Out:
# <ipython-input-2-2f52e2175019>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
# ...

# %%
main(result_path="/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/fsl_morganfp_postera_results.csv",
    test_size=128)
# Out:
# <ipython-input-2-2f52e2175019>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
# ...

# %% [markdown]
# ## Postera.ai

# %%
# main(result_path="/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/fsl_morganfp_postera_results.csv",
#     test_size=128)
from pathlib import Path
postera_result_path = Path("/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/results/postera")
for result_path in postera_result_path.glob("**/*.csv"):
    print(result_path)
    main(result_path=result_path, test_size=128)
# Out:
# /g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/results/postera/ecfp/test_results.csv
# <ipython-input-2-2f52e2175019>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## DUD-E

# %%
main(result_path="/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/results/dude/ace/ecfp/test_results.csv")
# Out:
# <ipython-input-2-2f52e2175019>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
# ...

# %%
main(result_path="/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/fsl/results/dude/ace/maacs/test_results.csv")
# Out:
# <ipython-input-2-2f52e2175019>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["kshot"][df.loc[:, 'kshot'] == -1]= test_size
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/workspace/wsa/jones289/miniconda3/envs/md/lib/python3.8/site-packages/seaborn/categorical.py:3737: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
# ...
